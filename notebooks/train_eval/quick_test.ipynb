# %% [markdown]
# # Notebook for quick model testing

# %%
import gym
import highway_env
from stable_baselines3 import PPO
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
ABS_PATH = '/home/elios/pighetti/HighwayDRL'

# Visualisation
import sys
sys.path.append(ABS_PATH)
from ipywidgets import interact, widgets
import glob

# %% [markdown]
# ### Choose the environment to exploit the model in

# %%
env_id = widgets.Text()
def f(input_env):
    env_id.value = str(input_env)
interact(f, input_env=['dm-multi-agent-v0','dm-env-v0','jam-dm-env-v0','overtaken-dm-env-v0','singleO-dm-env-v0','multipleO-dm-env-v0', 'highway-v0'])
# Out:
# interactive(children=(Dropdown(description='input_env', options=('dm-multi-agent-v0', 'dm-env-v0', 'jam-dm-env…
# <function __main__.f(input_env)>

# %% [markdown]
# ### Choose the model

# %%
model_id = widgets.Text()

def m(input_model):
    model_id.value = str(input_model)
interact(m, input_model=glob.glob(f"{ABS_PATH}/final_models/*.zip"))
# Out:
# interactive(children=(Dropdown(description='input_model', options=('/home/elios/pighetti/HighwayDRL/final_mode…
# <function __main__.m(input_model)>

# %%
env = gym.make(env_id.value)
model = PPO.load(model_id.value)

env.configure({
    "simulation_frequency": 30,
    "screen_width": 1500,
    "screen_height": 250
})

crashes = 0
episode_num = 3

for episode in range(episode_num):
    if episode == 10:
        print('episode num:', episode, "number of crashes:", crashes)

    obs, done = env.reset(), False

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(int(action))
        # print(obs, obs.shape, type(obs), done, info)
        if(env.vehicle.crashed):
            crashes +=1
        env.render()
        # print('fr:', env.final_reward, 'sr:', env.sparse_reward, 'dr:', env.dense_reward)
    

env.close()
# print('episode num:', episode_num, "number of crashes:", crashes)
