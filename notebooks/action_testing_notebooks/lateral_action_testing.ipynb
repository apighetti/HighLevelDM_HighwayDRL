# %%
# %pip install .
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
import gym
import highway_env

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width": 1250,
    "simulation_frequency": 20
    
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored
env.close()
# Out:
# IDMVehicle #616: [441.63220637   8.        ]
#
# gap: 5.923570471647537
# IDMVehicle #616: [442.70472236   8.        ]
#
# gap: 5.9213023926868384
# IDMVehicle #616: [443.77720783   8.        ]
#
# gap: 5.897756537039228
# IDMVehicle #616: [444.84966335   8.        ]
#
# gap: 5.889640855027066
# IDMVehicle #616: [445.92208947   8.        ]
#
# gap: 5.881634841831952
# IDMVehicle #616: [446.99448671   8.        ]
#
# gap: 5.873574935109458
# IDMVehicle #616: [448.06685559   8.        ]
#
# gap: 5.865499528214773
# IDMVehicle #616: [449.13919663   8.        ]
#
# gap: 5.857409479396349
# IDMVehicle #616: [450.21151032   8.        ]
#
# gap: 5.849304928691254
# IDMVehicle #616: [451.28379713   8.        ]
#
# gap: 5.8411861415202235
# IDMVehicle #616: [452.35605755   8.        ]
#
# gap: 5.833053393082899
# IDMVehicle #616: [453.42829202   8.        ]
#
# gap: 5.8249069349883875
# IDMVehicle #616: [454.50050099   8.        ]
#
# gap: 5.81674700726408
# IDMVehicle #616: [455.5726849   8.       ]
#
# gap: 5.8085738530682764
# IDMVehicle #616: [456.64484417   8.        ]
#
# gap: 5.800387721681533
# IDMVehicle #616: [457.71697921   8.        ]
#
# gap: 5.7921888605453535
# IDMVehicle #616: [458.78909043   8.        ]
#
# gap: 5.783977505533171
# IDMVehicle #616: [459.86117821   8.        ]
#
# gap: 5.775753887839235
# IDMVehicle #616: [460.93324294   8.        ]
#
# gap: 5.767518239475823
# IDMVehicle #616: [462.00528499   8.        ]
#
# gap: 5.759270780761055
# IDMVehicle #616: [463.07730472   8.        ]
#
# gap: 5.751011740427099
# IDMVehicle #616: [464.14930247   8.        ]
#
# gap: 5.742741332527737
# IDMVehicle #616: [465.2212786   8.       ]
#
# gap: 5.73445978031442
# IDMVehicle #616: [466.29323342   8.        ]
#
# gap: 5.726167301391905
# IDMVehicle #616: [467.36516727   8.        ]
#
# gap: 5.7178641092254825
# IDMVehicle #616: [468.43708047   8.        ]
#
# gap: 5.709550413974275
# IDMVehicle #616: [469.50897331   8.        ]
#
# gap: 5.701226423976477
# IDMVehicle #616: [470.58084609   8.        ]
#
# gap: 5.6928923407744385
# IDMVehicle #616: [471.65269911   8.        ]
#
# gap: 5.684548351408392
# IDMVehicle #616: [472.72453263   8.        ]
#
# gap: 5.676194670474679
# IDMVehicle #616: [473.79634695   8.        ]
#
# gap: 5.667831496116349
# IDMVehicle #616: [474.86814231   8.        ]
#
# gap: 5.659459025520347
# IDMVehicle #616: [475.93991898   8.        ]
#
# gap: 5.651077450738905
# IDMVehicle #616: [477.01167721   8.        ]
#
# gap: 5.642686959456009
# IDMVehicle #616: [478.08341724   8.        ]
#
# gap: 5.634287742438545
# IDMVehicle #616: [479.15513931   8.        ]
#
# gap: 5.6258799842574465
# IDMVehicle #616: [480.22684364   8.        ]
#
# gap: 5.617463870038854
# IDMVehicle #616: [481.29853046   8.        ]
#
# gap: 5.609039578051338
# IDMVehicle #616: [482.37019999   8.        ]
#
# gap: 5.60060728927764
# IDMVehicle #616: [483.44185242   8.        ]
#
# gap: 5.5921671735670095
# IDMVehicle #616: [484.51348797   8.        ]
#
# gap: 5.5837194115111455
# IDMVehicle #616: [485.58510683   8.        ]
#
# gap: 5.575264176196377
# IDMVehicle #616: [486.65670918   8.        ]
#
# gap: 5.566801636990537
# IDMVehicle #616: [487.72829523   8.        ]
#
# gap: 5.558331961874632
# IDMVehicle #616: [488.79986513   8.        ]
#
# gap: 5.549855318148829
# IDMVehicle #616: [489.87141908   8.        ]
#
# gap: 5.541371869731931
# IDMVehicle #616: [490.94295723   8.        ]
#
# gap: 5.532881786425039
# IDMVehicle #616: [492.01447974   8.        ]
#
# gap: 5.524385214786767
# IDMVehicle #616: [493.08598678   8.        ]
#
# gap: 5.515882290040958
# IDMVehicle #616: [494.1574785   8.       ]
#
# gap: 5.50737320149806
# IDMVehicle #616: [495.22895504   8.        ]
#
# gap: 5.498857892448596
# IDMVehicle #616: [496.30041654   8.        ]
#
# gap: 5.490336731102376
# IDMVehicle #616: [497.37186315   8.        ]
#
# gap: 5.481809681330468
# IDMVehicle #616: [498.44329499   8.        ]
#
# gap: 5.473277080298841
# IDMVehicle #616: [499.51471219   8.        ]
#
# gap: 5.464739080650867
# IDMVehicle #616: [500.58611488   8.        ]
#
# gap: 5.4561958242718855
# IDMVehicle #616: [501.65750318   8.        ]
#
# gap: 5.4476474435469555
# IDMVehicle #616: [502.72887721   8.        ]
#
# gap: 5.439094025202808
# IDMVehicle #616: [503.80023707   8.        ]
#
# gap: 5.430535784876319
# IDMVehicle #616: [504.87158287   8.        ]
#
# gap: 5.421972859138455
# IDMVehicle #616: [505.94291471   8.        ]
#
# gap: 5.413405389718177
# IDMVehicle #616: [507.0142327   8.       ]
#
# gap: 5.404833514019071
# IDMVehicle #616: [508.08553694   8.        ]
#
# gap: 5.3962573733674954
# IDMVehicle #616: [509.1568275   8.       ]
#
# gap: 5.3876771026843535
# IDMVehicle #616: [510.22810449   8.        ]
#
# gap: 5.379092834447976
# IDMVehicle #616: [511.29936799   8.        ]
#
# gap: 5.37050470295131
# IDMVehicle #616: [512.37061809   8.        ]
#
# gap: 5.361912839675258
# IDMVehicle #616: [513.44185485   8.        ]
#
# gap: 5.3533173704067245
# IDMVehicle #616: [514.51307836   8.        ]
#
# gap: 5.344718406739604
# IDMVehicle #616: [515.58428869   8.        ]
#
# gap: 5.336116095455303
# IDMVehicle #616: [516.65548591   8.        ]
#
# gap: 5.327510565935725
# IDMVehicle #616: [517.7266701   8.       ]
#
# gap: 5.3189019437251
# IDMVehicle #616: [518.7978413   8.       ]
#
# gap: 5.310290351755423
# IDMVehicle #616: [519.86899959   8.        ]
#
# gap: 5.301675842480629
# IDMVehicle #616: [520.94014502   8.        ]
#
# gap: 5.293058608793887
# IDMVehicle #616: [522.01127765   8.        ]
#
# gap: 5.2844387694542405
# IDMVehicle #616: [523.08239753   8.        ]
#
# gap: 5.275816445303201
# IDMVehicle #616: [524.15350472   8.        ]
#
# gap: 5.267191753253204
# IDMVehicle #616: [525.22459927   8.        ]
#
# gap: 5.2585648077550236
# IDMVehicle #616: [526.29568121   8.        ]
#
# gap: 5.249935722895419
# IDMVehicle #616: [527.36675061   8.        ]
#
# gap: 5.241304615791718
# IDMVehicle #616: [528.43780749   8.        ]
#
# gap: 5.232671602199666
# IDMVehicle #616: [529.5088519   8.       ]
#
# gap: 5.224036791927542
# IDMVehicle #616: [530.57988388   8.        ]
#
# gap: 5.215400295706663
# IDMVehicle #616: [531.65090346   8.        ]
#
# gap: 5.206762225529156
# IDMVehicle #616: [532.72191068   8.        ]
#
# gap: 5.198122689773692
# IDMVehicle #616: [533.79290557   8.        ]
#
# gap: 5.1894818005745424
# IDMVehicle #616: [534.86388816   8.        ]
#
# gap: 5.180839660810914
# IDMVehicle #616: [535.93485848   8.        ]
#
# gap: 5.172196362963442
# IDMVehicle #616: [537.00581656   8.        ]
#
# gap: 5.163552027164336
# IDMVehicle #616: [538.07676242   8.        ]
#
# gap: 5.15490676118131
# IDMVehicle #616: [539.14769609   8.        ]
#
# gap: 5.146260669011939
# IDMVehicle #616: [540.21861759   8.        ]
#
# gap: 5.137613850090901
# IDMVehicle #616: [541.28952694   8.        ]
#
# gap: 5.128966406846812
# IDMVehicle #616: [542.36042415   8.        ]
#
# gap: 5.120318441244157
# IDMVehicle #616: [543.43130926   8.        ]
#
# gap: 5.111670054214343
# IDMVehicle #616: [544.50218226   8.        ]
#
# gap: 5.103021344853179
# IDMVehicle #616: [545.57304319   8.        ]
#
# gap: 5.094372405290722
# IDMVehicle #616: [546.64389205   8.        ]
#
# gap: 5.08572334022077
# IDMVehicle #616: [547.71472885   8.        ]
#
# gap: 5.077074242938757
# IDMVehicle #616: [548.78555361   8.        ]
#
# gap: 5.068425211667424
# IDMVehicle #616: [549.85636633   8.        ]
#
# gap: 5.059776343211796
# IDMVehicle #616: [550.92716703   8.        ]
#
# gap: 5.051127730014812
# IDMVehicle #616: [551.99795571   8.        ]
#
# gap: 5.042479467898241
# IDMVehicle #616: [553.06873239   8.        ]
#
# gap: 5.03383164961995
# IDMVehicle #616: [554.13949706   8.        ]
#
# gap: 5.025184363111581
# IDMVehicle #616: [555.21024973   8.        ]
#
# gap: 5.016537703112219
# IDMVehicle #616: [556.2809904   8.       ]
#
# gap: 5.007891761401263
# IDMVehicle #616: [557.35171909   8.        ]
#
# gap: 4.999246618779026
# IDMVehicle #616: [558.42243578   8.        ]
#
# gap: 4.990602374267004
# IDMVehicle #616: [559.49314048   8.        ]
#
# gap: 4.981959118380763
# IDMVehicle #616: [560.5638332   8.       ]
#
# gap: 4.973316938857502
# IDMVehicle #616: [561.63451392   8.        ]
#
# gap: 4.964675922626735
# IDMVehicle #616: [562.70518266   8.        ]
#
# gap: 4.956036155129574
# IDMVehicle #616: [563.7758394   8.       ]
#
# gap: 4.947397722954413
# IDMVehicle #616: [564.84648415   8.        ]
#
# gap: 4.938760711522215
# IDMVehicle #616: [565.91711689   8.        ]
#
# gap: 4.930125208186396
# IDMVehicle #616: [566.98773764   8.        ]
#
# gap: 4.921491296945922
# IDMVehicle #616: [568.05834638   8.        ]
#
# gap: 4.912859062972976
# IDMVehicle #616: [569.1289431   8.       ]
#
# gap: 4.904228586707595
# IDMVehicle #616: [570.1995278   8.       ]
#
# gap: 4.895599952941937
# IDMVehicle #616: [571.27010048   8.        ]
#
# gap: 4.886973244034433
# IDMVehicle #616: [572.34066112   8.        ]
#
# gap: 4.878348540118916
# IDMVehicle #616: [573.41120973   8.        ]
#
# gap: 4.869725919923681
# IDMVehicle #616: [574.48174628   8.        ]
#
# gap: 4.861105466009939
# IDMVehicle #616: [575.55227078   8.        ]
#
# gap: 4.852487257285152
# IDMVehicle #616: [576.62278321   8.        ]
#
# gap: 4.843871375986971
# IDMVehicle #616: [577.69328356   8.        ]
#
# gap: 4.835257899867966
# IDMVehicle #616: [578.76377183   8.        ]
#
# gap: 4.8266468981272155
# IDMVehicle #616: [579.834248   8.      ]
#
# gap: 4.818038458887616
# IDMVehicle #616: [580.90471207   8.        ]
#
# gap: 4.80943266048958
# IDMVehicle #616: [581.97516401   8.        ]
#
# gap: 4.8008295783477655
# IDMVehicle #616: [583.04560382   8.        ]
#
# gap: 4.792229286282538
# IDMVehicle #616: [584.1160315   8.       ]
#
# gap: 4.783631859000659
# IDMVehicle #616: [585.18644701   8.        ]
#
# gap: 4.775037373504842
# IDMVehicle #616: [586.25685036   8.        ]
#
# gap: 4.7664459053982595
# IDMVehicle #616: [587.32724153   8.        ]
#
# gap: 4.757857530204128
# IDMVehicle #616: [588.39762051   8.        ]
#
# gap: 4.749272321841555
# IDMVehicle #616: [589.46798728   8.        ]
#
# gap: 4.740690354718545
# IDMVehicle #616: [590.53834183   8.        ]
#
# gap: 4.732111699206577
# IDMVehicle #616: [591.60868414   8.        ]
#
# gap: 4.723536429501137
# IDMVehicle #616: [592.67901421   8.        ]
#
# gap: 4.7149646166618675
# IDMVehicle #616: [593.74933201   8.        ]
#
# gap: 4.706396331997756
# IDMVehicle #616: [594.81963754   8.        ]
#
# gap: 4.697831646046396
# IDMVehicle #616: [595.88993078   8.        ]
#
# gap: 4.689270632870029
# IDMVehicle #616: [596.96021171   8.        ]
#
# gap: 4.680713363727624
# IDMVehicle #616: [598.03048031   8.        ]
#
# gap: 4.672159909790339
# IDMVehicle #616: [599.10073658   8.        ]
#
# gap: 4.663610339389952
# IDMVehicle #616: [600.1709805   8.       ]
#
# gap: 4.655064713232311
# IDMVehicle #616: [601.24121205   8.        ]
#
# gap: 4.646523108495616
# IDMVehicle #616: [602.31143122   8.        ]
#
# gap: 4.637985593249169
# IDMVehicle #616: [603.38163798   8.        ]
#
# gap: 4.6294522370895175
# IDMVehicle #616: [604.45183233   8.        ]
#
# gap: 4.620923106508607
# IDMVehicle #616: [605.52201425   8.        ]
#
# gap: 4.612398268443299
# IDMVehicle #616: [606.59218373   8.        ]
#
# gap: 4.603877791428047
# IDMVehicle #616: [607.66234074   8.        ]
#
# gap: 4.595361742938766
# IDMVehicle #616: [608.73248527   8.        ]
#
# gap: 4.586850190665796
# IDMVehicle #616: [609.8026173   8.       ]
#
# gap: 4.578343198686815
# IDMVehicle #616: [610.87273683   8.        ]
#
# gap: 4.5698408342546655
# IDMVehicle #616: [611.94284382   8.        ]
#
# gap: 4.561343160868056
# IDMVehicle #616: [613.01293827   8.        ]
#
# gap: 4.552850243672636
# IDMVehicle #616: [614.08302016   8.        ]
#
# gap: 4.544362146690152
# IDMVehicle #616: [615.15308947   8.        ]
#
# gap: 4.535878936038863
# IDMVehicle #616: [616.22314619   8.        ]
#
# gap: 4.527400675202703
# IDMVehicle #616: [617.2931903   8.       ]
#
# gap: 4.518927429466802
# IDMVehicle #616: [618.36322178   8.        ]
#
# gap: 4.5104592619299435
# IDMVehicle #616: [619.43324061   8.        ]
#
# gap: 4.501996236671272
# IDMVehicle #616: [620.50324679   8.        ]
#
# gap: 4.493538416445926
# IDMVehicle #616: [621.57324029   8.        ]
#
# gap: 4.485085855993764
# IDMVehicle #616: [622.64322109   8.        ]
#
# gap: 4.476638624633383
# IDMVehicle #616: [623.71318919   8.        ]
#
# gap: 4.468196783682002
# IDMVehicle #616: [624.78314456   8.        ]
#
# gap: 4.459760397214153
# IDMVehicle #616: [625.85308719   8.        ]
#
# gap: 4.451329526119782
# IDMVehicle #616: [626.92301706   8.        ]
#
# gap: 4.442904230903294
# IDMVehicle #616: [627.99293416   8.        ]
#
# gap: 4.43448457399369
# IDMVehicle #616: [629.06283846   8.        ]
#
# gap: 4.426070615851194
# IDMVehicle #616: [630.13272996   8.        ]
#
# gap: 4.417662417498999
# IDMVehicle #616: [631.20260864   8.        ]
#
# gap: 4.409260038895091
# IDMVehicle #616: [632.27247447   8.        ]
#
# gap: 4.400863539807596
# IDMVehicle #616: [633.34232745   8.        ]
#
# gap: 4.3924729770643145
# IDMVehicle #616: [634.41216755   8.        ]
#
# gap: 4.3840884126446635
# IDMVehicle #616: [635.48199477   8.        ]
#
# gap: 4.375709906951974
# IDMVehicle #616: [636.55180909   8.        ]
#
# gap: 4.36733751844958
# IDMVehicle #616: [637.62161048   8.        ]
#
# gap: 4.358971305827721
# IDMVehicle #616: [638.69139894   8.        ]
#
# gap: 4.3506113283414445
# IDMVehicle #616: [639.76117445   8.        ]
#
# gap: 4.342257643951499
# IDMVehicle #616: [640.83093699   8.        ]
#
# gap: 4.333910312209809
# IDMVehicle #616: [641.90068655   8.        ]
#
# gap: 4.325569387985394
# IDMVehicle #616: [642.97042312   8.        ]
#
# gap: 4.317234922827311
# IDMVehicle #616: [644.04014667   8.        ]
#
# gap: 4.308906981719688
# IDMVehicle #616: [645.10985719   8.        ]
#
# gap: 4.300585622819639
# IDMVehicle #616: [646.17955467   8.        ]
#
# gap: 4.292270903411099
# IDMVehicle #616: [647.24923909   8.        ]
#
# gap: 4.2839628793879605
# IDMVehicle #616: [648.31891044   8.        ]
#
# gap: 4.2756616065923225
# IDMVehicle #616: [649.3885687   8.       ]
#
# gap: 4.26736714314205
# IDMVehicle #616: [650.45821385   8.        ]
#
# gap: 4.259079544628171
# IDMVehicle #616: [651.52784589   8.        ]
#
# gap: 4.250798867425476
# IDMVehicle #616: [652.5974648   8.       ]
#
# gap: 4.242525166648744
# IDMVehicle #616: [653.66707056   8.        ]
#
# gap: 4.2342584988571215
# IDMVehicle #616: [654.73666316   8.        ]
#
# gap: 4.225998918374093
# IDMVehicle #616: [655.80624258   8.        ]
#
# gap: 4.217746481607471
# IDMVehicle #616: [656.87580882   8.        ]
#
# gap: 4.209501243551848
# IDMVehicle #616: [657.94536185   8.        ]
#
# gap: 4.201263258594509
# IDMVehicle #616: [659.01490166   8.        ]
#
# gap: 4.193032581734179
# IDMVehicle #616: [660.08442825   8.        ]
#
# gap: 4.184809234913076
# IDMVehicle #616: [661.15394158   8.        ]
#
# gap: 4.176593303273867
# IDMVehicle #616: [662.22344166   8.        ]
#
# gap: 4.168384843165796
# IDMVehicle #616: [663.29292847   8.        ]
#
# gap: 4.160183908976061
# IDMVehicle #616: [664.36240199   8.        ]
#
# gap: 4.15199054861527
# IDMVehicle #616: [665.43186221   8.        ]
#
# gap: 4.143804821126803
# IDMVehicle #616: [666.50130912   8.        ]
#
# gap: 4.135626781300099
# IDMVehicle #616: [667.57074271   8.        ]
#
# gap: 4.127456482372505
# IDMVehicle #616: [668.64016296   8.        ]
#
# gap: 4.119293976920297
# IDMVehicle #616: [669.70956986   8.        ]
#
# gap: 4.111139316843784
# IDMVehicle #616: [670.77896339   8.        ]
#
# gap: 4.102992556330178
# IDMVehicle #616: [671.84834355   8.        ]
#
# gap: 4.094853747864806
# IDMVehicle #616: [672.91771032   8.        ]
#
# gap: 4.086722945344498
# IDMVehicle #616: [673.98706368   8.        ]
#
# gap: 4.078600200887112
# IDMVehicle #616: [675.05640364   8.        ]
#
# gap: 4.070485566767194
# IDMVehicle #616: [676.12573017   8.        ]
#
# gap: 4.062379094381186
# IDMVehicle #616: [677.19504326   8.        ]
#
# gap: 4.05428083701664
# IDMVehicle #616: [678.26434291   8.        ]
#
# gap: 4.046190846387426
# IDMVehicle #616: [679.33362909   8.        ]
#
# gap: 4.0381091726835505
# IDMVehicle #616: [680.4029018   8.       ]
#
# gap: 4.0300358677130665
# IDMVehicle #616: [681.47216103   8.        ]
#
# gap: 4.021970984535517
# IDMVehicle #616: [682.54140676   8.        ]
#
# gap: 4.013914574067563
# IDMVehicle #616: [683.61063898   8.        ]
#
# gap: 4.0058666887804355
# IDMVehicle #616: [684.67985769   8.        ]
#
# gap: 3.9978273795424846
# IDMVehicle #616: [685.74906287   8.        ]
#
# gap: 3.989796691439219
# IDMVehicle #616: [686.81825451   8.        ]
#
# gap: 3.981774681283772
# IDMVehicle #616: [687.8874326   8.       ]
#
# gap: 3.9737614001044346
# IDMVehicle #616: [688.95659712   8.        ]
#
# gap: 3.965756898711139
# IDMVehicle #616: [690.02574808   8.        ]
#
# gap: 3.957761226124229
# IDMVehicle #616: [691.09488545   8.        ]
#
# gap: 3.9497744334883143
# IDMVehicle #616: [692.16400923   8.        ]
#
# gap: 3.941796572378765
# IDMVehicle #616: [693.23311941   8.        ]
#
# gap: 3.933827692721568
# IDMVehicle #616: [694.30221597   8.        ]
#
# gap: 3.925867845236521
# IDMVehicle #616: [695.37129891   8.        ]
#
# gap: 3.9179170796050196
# IDMVehicle #616: [696.44036822   8.        ]
#
# gap: 3.9099754456373406
# IDMVehicle #616: [697.50942389   8.        ]
#
# gap: 3.902042992428946
# IDMVehicle #616: [698.5784659   8.       ]
#
# gap: 3.8941197697777072
# IDMVehicle #616: [699.64749426   8.        ]
#
# gap: 3.88620582728476
# IDMVehicle #616: [700.71650894   8.        ]
#
# gap: 3.8783012147760436
# IDMVehicle #616: [701.78550994   8.        ]
#
# gap: 3.8704059818289567
# IDMVehicle #616: [702.85449725   8.        ]
#
# gap: 3.862520178473508
# IDMVehicle #616: [703.92347086   8.        ]
#
# gap: 3.8546438535024947
# IDMVehicle #616: [704.99243077   8.        ]
#
# gap: 3.846777056476885
# IDMVehicle #616: [706.06137696   8.        ]
#
# gap: 3.838919836050538
# IDMVehicle #616: [707.13030942   8.        ]
#
# gap: 3.8310722368022185
# IDMVehicle #616: [708.19922815   8.        ]
#
# gap: 3.8232343119113636
# IDMVehicle #616: [709.26813314   8.        ]
#
# gap: 3.8154061104824937
# IDMVehicle #616: [710.33702438   8.        ]
#
# gap: 3.807587681396747
# IDMVehicle #616: [711.40590185   8.        ]
#
# gap: 3.799779073393913
# IDMVehicle #616: [712.47476556   8.        ]
#
# gap: 3.7919803345499536
# IDMVehicle #616: [713.5436155   8.       ]
#
# gap: 3.784191514029742
# IDMVehicle #616: [714.61245165   8.        ]
#
# gap: 3.776412660042828
# IDMVehicle #616: [715.68127401   8.        ]
#
# gap: 3.7686438213255355
# IDMVehicle #616: [716.75008258   8.        ]
#
# gap: 3.7608850452235556
# IDMVehicle #616: [717.81887733   8.        ]
#
# gap: 3.753136380725402
# IDMVehicle #616: [718.88765827   8.        ]
#
# gap: 3.7453978738180123
# IDMVehicle #616: [719.9564254   8.       ]
#
# gap: 3.7376695729717397
# IDMVehicle #616: [721.02517869   8.        ]
#
# gap: 3.729951527599055
# IDMVehicle #616: [722.09391814   8.        ]
#
# gap: 3.7222437846844407
# IDMVehicle #616: [723.16264376   8.        ]
#
# gap: 3.714546392389475
# IDMVehicle #616: [724.23135552   8.        ]
#
# gap: 3.7068593983808764
# IDMVehicle #616: [725.30005343   8.        ]
#
# gap: 3.6991828503845623
# IDMVehicle #616: [726.36873747   8.        ]
#
# gap: 3.6915167968762157
# IDMVehicle #616: [727.43740764   8.        ]
#
# gap: 3.6838612850790806
# IDMVehicle #616: [728.50606393   8.        ]
#
# gap: 3.6762163575518425
# IDMVehicle #616: [729.57470634   8.        ]
#
# gap: 3.668582064868957
# IDMVehicle #616: [730.64333487   8.        ]
#
# gap: 3.6609584557814703
# IDMVehicle #616: [731.71194949   8.        ]
#
# gap: 3.6533455778116393
# IDMVehicle #616: [732.78055021   8.        ]
#
# gap: 3.6457434773881277
# IDMVehicle #616: [733.84913702   8.        ]
#
# gap: 3.638152201366352
# IDMVehicle #616: [734.91770992   8.        ]
#
# gap: 3.630571797727936
# IDMVehicle #616: [735.9862689   8.       ]
#
# gap: 3.623002313427661
# IDMVehicle #616: [737.05481395   8.        ]
#
# gap: 3.6154437955325545
# IDMVehicle #616: [738.12334507   8.        ]
#
# gap: 3.60789628965919
# IDMVehicle #616: [739.19186225   8.        ]
#
# gap: 3.600359842938392
# IDMVehicle #616: [740.26036549   8.        ]
#
# gap: 3.592834501753118
# IDMVehicle #616: [741.32885478   8.        ]
#
# gap: 3.5853203139594765
# IDMVehicle #616: [742.39733011   8.        ]
#
# gap: 3.5778173263714113
# IDMVehicle #616: [743.46579149   8.        ]
#
# gap: 3.5703255854015534
# IDMVehicle #616: [744.53423889   8.        ]
#
# gap: 3.5628451381042625
# IDMVehicle #616: [745.60267233   8.        ]
#
# gap: 3.555376031469196
# IDMVehicle #616: [746.6710918   8.       ]
#
# gap: 3.547918310913307
# IDMVehicle #616: [747.73949728   8.        ]
#
# gap: 3.5404720224680535
# IDMVehicle #616: [748.80788878   8.        ]
#
# gap: 3.533037213212154
# IDMVehicle #616: [749.8762663   8.       ]
#
# gap: 3.5256139258936425
# IDMVehicle #616: [750.94462981   8.        ]
#
# gap: 3.5182022109715385
# IDMVehicle #616: [752.01297933   8.        ]
#
# gap: 3.510802114674103
# IDMVehicle #616: [753.08131485   8.        ]
#
# gap: 3.503413682925248
# IDMVehicle #616: [754.14963635   8.        ]
#
# gap: 3.4960369618775173
# IDMVehicle #616: [755.21794385   8.        ]
#
# gap: 3.4886719975186864
# IDMVehicle #616: [756.28623733   8.        ]
#
# gap: 3.4813188362247454
# IDMVehicle #616: [757.35451679   8.        ]
#
# gap: 3.473977523590083
# IDMVehicle #616: [758.42278222   8.        ]
#
# gap: 3.4666481055812737
# IDMVehicle #616: [759.49103363   8.        ]
#
# gap: 3.4593306282654757
# IDMVehicle #616: [760.559271   8.      ]
#
# gap: 3.4520251384270333
# IDMVehicle #616: [761.62749434   8.        ]
#
# gap: 3.4447316807428594
# IDMVehicle #616: [762.69570364   8.        ]
#
# gap: 3.437450301833125
# IDMVehicle #616: [763.76389889   8.        ]
#
# gap: 3.4301810478339494
# IDMVehicle #616: [764.8320801   8.       ]
#
# gap: 3.4229239640356335
# IDMVehicle #616: [765.90024725   8.        ]
#
# gap: 3.4156790962377386
# IDMVehicle #616: [766.96840036   8.        ]
#
# gap: 3.4084464897303315
# IDMVehicle #616: [768.0365394   8.       ]
#
# gap: 3.401226190067381
# IDMVehicle #616: [769.10466438   8.        ]
#
# gap: 3.394018243802045
# IDMVehicle #616: [770.1727753   8.       ]
#
# gap: 3.3868226961832306
# IDMVehicle #616: [771.24087216   8.        ]
#
# gap: 3.379639589651263
# IDMVehicle #616: [772.30895494   8.        ]
#
# gap: 3.3724689728459802
# IDMVehicle #616: [773.37702365   8.        ]
#
# gap: 3.365310891432493
# IDMVehicle #616: [774.44507828   8.        ]
#
# gap: 3.3581653911935145
# IDMVehicle #616: [775.51311883   8.        ]
#
# gap: 3.351032517216323
# IDMVehicle #616: [776.5811453   8.       ]
#
# gap: 3.3439123140262197
# IDMVehicle #616: [777.64915769   8.        ]
#
# gap: 3.3368048274241353
# IDMVehicle #616: [778.71715599   8.        ]
#
# gap: 3.329710102821931
# IDMVehicle #616: [779.7851402   8.       ]
#
# gap: 3.3226281861007125
# IDMVehicle #616: [780.85311032   8.        ]
#
# gap: 3.315559122576329
# IDMVehicle #616: [781.92106634   8.        ]
#
# gap: 3.3085029576123057
# IDMVehicle #616: [782.98900827   8.        ]
#
# gap: 3.3014597358833155
# IDMVehicle #616: [784.05693609   8.        ]
#
# gap: 3.2944295030368087
# IDMVehicle #616: [785.12484982   8.        ]
#
# gap: 3.2874123041969296
# IDMVehicle #616: [786.19274944   8.        ]
#
# gap: 3.2804081836704997
# IDMVehicle #616: [787.26063495   8.        ]
#
# gap: 3.273417186764009
# IDMVehicle #616: [788.32850636   8.        ]
#
# gap: 3.266439358916786
# IDMVehicle #616: [789.39636365   8.        ]
#
# gap: 3.259474745298415
# IDMVehicle #616: [790.46420684   8.        ]
#
# gap: 3.2525233910614864
# IDMVehicle #616: [791.53203591   8.        ]
#
# gap: 3.245585341516647
# IDMVehicle #616: [792.59985087   8.        ]
#
# gap: 3.238660638842606
# IDMVehicle #616: [793.6676517   8.       ]
#
# gap: 3.2317493303699614
# IDMVehicle #616: [794.73543842   8.        ]
#
# gap: 3.2248514616440778
# IDMVehicle #616: [795.80321102   8.        ]
#
# gap: 3.2179670770579945
# IDMVehicle #616: [796.8709695   8.       ]
#
# gap: 3.2110962212882734
# IDMVehicle #616: [797.93871385   8.        ]
#
# gap: 3.204238938938569
# IDMVehicle #616: [799.00644408   8.        ]
#
# gap: 3.1973952755145243
# IDMVehicle #616: [800.07416018   8.        ]
#
# gap: 3.1905652663585604
# IDMVehicle #616: [801.14186215   8.        ]
#
# gap: 3.18374896589103
# IDMVehicle #616: [802.20955   8.     ]
#
# gap: 3.1769464185517133
# IDMVehicle #616: [803.27722371   8.        ]
#
# gap: 3.170157669698944
# IDMVehicle #616: [804.34488329   8.        ]
#
# gap: 3.1633827626817244
# IDMVehicle #616: [805.41252874   8.        ]
#
# gap: 3.156621742623276
# IDMVehicle #616: [806.48016006   8.        ]
#
# gap: 3.1498746544360756
# IDMVehicle #616: [807.54777724   8.        ]
#
# gap: 3.143141543249067
# IDMVehicle #616: [808.61538029   8.        ]
#
# gap: 3.136422453789404
# IDMVehicle #616: [809.6829692   8.       ]
#
# gap: 3.1297174309205413
# IDMVehicle #616: [810.75054398   8.        ]
#
# gap: 3.123026518973079
# IDMVehicle #616: [811.81810462   8.        ]
#
# gap: 3.116349762826596
# IDMVehicle #616: [812.88565112   8.        ]
#
# gap: 3.1096872068959724
# IDMVehicle #616: [813.95318348   8.        ]
#
# gap: 3.103038893360482
# IDMVehicle #616: [815.0207017   8.       ]
#
# gap: 3.0964048689753207
# IDMVehicle #616: [816.08820578   8.        ]
#
# gap: 3.0897851783880883
# IDMVehicle #616: [817.15569572   8.        ]
#
# gap: 3.0831798661973897
# IDMVehicle #616: [818.22317152   8.        ]
#
# gap: 3.076588976683487
# IDMVehicle #616: [819.29063317   8.        ]
#
# gap: 3.0700125543724575
# IDMVehicle #616: [820.35808069   8.        ]
#
# gap: 3.0634506439741935
# IDMVehicle #616: [821.42551406   8.        ]
#
# gap: 3.0569032895651986
# IDMVehicle #616: [822.49293329   8.        ]
#
# gap: 3.0503705359827116
# IDMVehicle #616: [823.56033838   8.        ]
#
# gap: 3.043852427089523
# IDMVehicle #616: [824.62772933   8.        ]
#
# gap: 3.0373490075584577
# IDMVehicle #616: [825.69510613   8.        ]
#
# gap: 3.030860321155653
# IDMVehicle #616: [826.7624688   8.       ]
#
# gap: 3.0243864128459546
# IDMVehicle #616: [827.82981731   8.        ]
#
# gap: 3.017927327008892
# IDMVehicle #616: [828.89715169   8.        ]
#
# gap: 3.0114831076999957
# IDMVehicle #616: [829.96447192   8.        ]
#
# gap: 3.0050537991734627
# IDMVehicle #616: [831.03177802   8.        ]
#
# gap: 2.998639445883767
# IDMVehicle #616: [832.09906997   8.        ]
#
# gap: 2.99224009195697
# IDMVehicle #616: [833.16634777   8.        ]
#
# gap: 2.985855781623841
# IDMVehicle #616: [834.23361144   8.        ]
#
# gap: 2.9794865590769177
# IDMVehicle #616: [835.30086096   8.        ]
#
# gap: 2.973132466326857
# IDMVehicle #616: [836.36809635   8.        ]
#
# gap: 2.9667935495730005
# IDMVehicle #616: [837.43531759   8.        ]
#
# gap: 2.960469853624769
# IDMVehicle #616: [838.50252469   8.        ]
#
# gap: 2.9541614223604684
# IDMVehicle #616: [839.56971766   8.        ]
#
# gap: 2.9478682995034946
# IDMVehicle #616: [840.63689648   8.        ]
#
# gap: 2.9415905290490336
# IDMVehicle #616: [841.70406117   8.        ]
#
# gap: 2.935328155430679
# IDMVehicle #616: [842.77121172   8.        ]
#
# gap: 2.929081222201016
# IDMVehicle #616: [843.83834813   8.        ]
#
# gap: 2.922849773591903
# IDMVehicle #616: [844.9054704   8.       ]
#
# gap: 2.916633853528884
# IDMVehicle #616: [845.97257854   8.        ]
#
# gap: 2.9104335065065596
# IDMVehicle #616: [847.03967255   8.        ]
#
# gap: 2.9042487759554225
# IDMVehicle #616: [848.10675242   8.        ]
#
# gap: 2.898079706223778
# IDMVehicle #616: [849.17381816   8.        ]
#
# gap: 2.89192634115697
# IDMVehicle #616: [850.24086976   8.        ]
#
# gap: 2.885788724536745
# IDMVehicle #616: [851.30790724   8.        ]
#
# gap: 2.8796669000494592
# IDMVehicle #616: [852.37493058   8.        ]
#
# gap: 2.873560911622932
# IDMVehicle #616: [853.4419398   8.       ]
#
# gap: 2.8674708027465208
# IDMVehicle #616: [854.50893489   8.        ]
#
# gap: 2.8613966179949673
# IDMVehicle #616: [855.57591585   8.        ]
#
# gap: 2.855338400950843
# IDMVehicle #616: [856.64288268   8.        ]
#
# gap: 2.8492961935737
# IDMVehicle #616: [857.70983539   8.        ]
#
# gap: 2.8432700414520085
# IDMVehicle #616: [858.77677398   8.        ]
#
# gap: 2.8372599884644476
# IDMVehicle #616: [859.84369845   8.        ]
#
# gap: 2.831266078351172
# IDMVehicle #616: [860.91060879   8.        ]
#
# gap: 2.825288354545343
# IDMVehicle #616: [861.97750502   8.        ]
#
# gap: 2.81932686018122
# IDMVehicle #616: [863.04438712   8.        ]
#
# gap: 2.813381639291695
# IDMVehicle #616: [864.11125511   8.        ]
#
# gap: 2.807452735355252
# IDMVehicle #616: [865.17810899   8.        ]
#
# gap: 2.8015401922797833
# IDMVehicle #616: [866.24494875   8.        ]
#
# gap: 2.7956440534073863
# IDMVehicle #616: [867.3117744   8.       ]
#
# gap: 2.789764362460584
# IDMVehicle #616: [868.37858594   8.        ]
#
# gap: 2.783901162673767
# IDMVehicle #616: [869.44538337   8.        ]
#
# gap: 2.7780544979925628
# IDMVehicle #616: [870.51216669   8.        ]
#
# gap: 2.7722244116367465
# IDMVehicle #616: [871.57893591   8.        ]
#
# gap: 2.766410946682795
# IDMVehicle #616: [872.64569102   8.        ]
#
# gap: 2.7606141465114797
# IDMVehicle #616: [873.71243203   8.        ]
#
# gap: 2.754834054627281
# IDMVehicle #616: [874.77915894   8.        ]
#
# gap: 2.7490707144567006
# IDMVehicle #616: [875.84587175   8.        ]
#
# gap: 2.743324169686576
# IDMVehicle #616: [876.91257047   8.        ]
#
# gap: 2.7375944632917264
# IDMVehicle #616: [877.97925508   8.        ]
#
# gap: 2.7318816370277608
# IDMVehicle #616: [879.04592561   8.        ]
#
# gap: 2.7261857357529227
# IDMVehicle #616: [880.11258205   8.        ]
#
# gap: 2.7205068025519576
# IDMVehicle #616: [881.17922439   8.        ]
#
# gap: 2.714844880522949
# IDMVehicle #616: [882.24585265   8.        ]
#
# gap: 2.7092000123527837
# IDMVehicle #616: [883.31246682   8.        ]
#
# gap: 2.703572241147554
# IDMVehicle #616: [884.37906691   8.        ]
#
# gap: 2.6979616104395516
# IDMVehicle #616: [885.44565292   8.        ]
#
# gap: 2.6923681631174423
# IDMVehicle #616: [886.51222485   8.        ]
#
# gap: 2.686791942242473
# IDMVehicle #616: [887.5787827   8.       ]
#
# gap: 2.6812329907573673
# IDMVehicle #616: [888.64532647   8.        ]
#
# gap: 2.6756913517626773
# IDMVehicle #616: [889.71185618   8.        ]
#
# gap: 2.6701670677272613
# IDMVehicle #616: [890.77837181   8.        ]
#
# gap: 2.6646601814634465
# IDMVehicle #616: [891.84487338   8.        ]
#
# gap: 2.659170735741074
# IDMVehicle #616: [892.91136088   8.        ]
#
# gap: 2.6536987735277497
# IDMVehicle #616: [893.97783432   8.        ]
#
# gap: 2.6482443375936437
# IDMVehicle #616: [895.04429369   8.        ]
#
# gap: 2.6428074706102196
# IDMVehicle #616: [896.11073901   8.        ]
#
# gap: 2.637388215139639
# IDMVehicle #616: [897.17717027   8.        ]
#
# gap: 2.6319866141100725
# IDMVehicle #616: [898.24358747   8.        ]
#
# gap: 2.6266027099797773
# IDMVehicle #616: [899.30999063   8.        ]
#
# gap: 2.6212365438991005
# IDMVehicle #616: [900.37637973   8.        ]
#
# gap: 2.615888159601572
# IDMVehicle #616: [901.44275479   8.        ]
#
# gap: 2.610557599393874
# IDMVehicle #616: [902.50911581   8.        ]
#
# gap: 2.6052449060252467
# IDMVehicle #616: [903.57546278   8.        ]
#
# gap: 2.599950121739644
# IDMVehicle #616: [904.64179571   8.        ]
#
# gap: 2.594673288610453
# IDMVehicle #616: [905.70811461   8.        ]
#
# gap: 2.5894144492716205
# IDMVehicle #616: [906.77441948   8.        ]
#
# gap: 2.584173645878864
# IDMVehicle #616: [907.84071031   8.        ]
#
# gap: 2.5789509207571086
# IDMVehicle #616: [908.90698712   8.        ]
#
# gap: 2.573746315920334
# IDMVehicle #616: [909.9732499   8.       ]
#
# gap: 2.568559873372288
# IDMVehicle #616: [911.03949865   8.        ]
#
# gap: 2.563391634623514
# IDMVehicle #616: [912.10573339   8.        ]
#
# gap: 2.5582416421701195
# IDMVehicle #616: [913.17195411   8.        ]
#
# gap: 2.553109938164506
# IDMVehicle #616: [914.23816082   8.        ]
#
# gap: 2.5479965641460574
# IDMVehicle #616: [915.30435351   8.        ]
#
# gap: 2.5429015619659365
# IDMVehicle #616: [916.37053219   8.        ]
#
# gap: 2.537824973490893
# IDMVehicle #616: [917.43669687   8.        ]
#
# gap: 2.532766840464083
# IDMVehicle #616: [918.50284755   8.        ]
#
# gap: 2.527727204686596
# IDMVehicle #616: [919.56898423   8.        ]
#
# gap: 2.52270610739599
# IDMVehicle #616: [920.63510691   8.        ]
#
# gap: 2.517703588882786
# IDMVehicle #616: [921.70121559   8.        ]
#
# gap: 2.5127196920876536
# IDMVehicle #616: [922.76731029   8.        ]
#
# gap: 2.5077544583431637
# IDMVehicle #616: [923.83339099   8.        ]
#
# gap: 2.502807929295164
# IDMVehicle #616: [924.89945772   8.        ]
#
# gap: 2.4978801460295585
# IDMVehicle #616: [925.96551046   8.        ]
#
# gap: 2.4929711496596667
# IDMVehicle #616: [927.03154922   8.        ]
#
# gap: 2.4880809816686273
# IDMVehicle #616: [928.09757401   8.        ]
#
# gap: 2.4832096832432784
# IDMVehicle #616: [929.16358482   8.        ]
#
# gap: 2.478357295254579
# IDMVehicle #616: [930.22958166   8.        ]
#
# gap: 2.4735238582984653
# IDMVehicle #616: [931.29556454   8.        ]
#
# gap: 2.4687094136915784
# IDMVehicle #616: [932.36153346   8.        ]
#
# gap: 2.4639140020264607
# IDMVehicle #616: [933.42748842   8.        ]
#
# gap: 2.4591376643336726
# IDMVehicle #616: [934.49342942   8.        ]
#
# gap: 2.4543804413898567
# IDMVehicle #616: [935.55935646   8.        ]
#
# gap: 2.449642373637629
# IDMVehicle #616: [936.62526956   8.        ]
#
# gap: 2.444923501688086
# IDMVehicle #616: [937.69116871   8.        ]
#
# gap: 2.4402238661190205
# IDMVehicle #616: [938.75705392   8.        ]
#
# gap: 2.4355435002621686
# IDMVehicle #616: [939.82292519   8.        ]
#
# gap: 2.430882451488216
# IDMVehicle #616: [940.88878252   8.        ]
#
# gap: 2.4262407599629663
# IDMVehicle #616: [941.95462592   8.        ]
#
# gap: 2.4216184647269348
# IDMVehicle #616: [943.02045539   8.        ]
#
# gap: 2.417015606782064
# IDMVehicle #616: [944.08627094   8.        ]
#
# gap: 2.4124322258326956
# IDMVehicle #616: [945.15207256   8.        ]
#
# gap: 2.407868362137428
# IDMVehicle #616: [946.21786027   8.        ]
#
# gap: 2.4033240551844397
# IDMVehicle #616: [947.28363405   8.        ]
#
# gap: 2.398799344793467
# IDMVehicle #616: [948.34939393   8.        ]
#
# gap: 2.3942942708183628
# IDMVehicle #616: [949.4151399   8.       ]
#
# gap: 2.3898088729443847
# IDMVehicle #616: [950.48087196   8.        ]
#
# gap: 2.385343190732642
# IDMVehicle #616: [951.54659013   8.        ]
#
# gap: 2.380897263826416
# IDMVehicle #616: [952.61229439   8.        ]
#
# gap: 2.376471131830953
# IDMVehicle #616: [953.67798476   8.        ]
#
# gap: 2.3720648337482375
# IDMVehicle #616: [954.74366124   8.        ]
#
# gap: 2.3676784089581515
# IDMVehicle #616: [955.80932384   8.        ]
#
# gap: 2.3633118965623634
# IDMVehicle #616: [956.87497255   8.        ]
#
# gap: 2.358965335012222
# IDMVehicle #616: [957.94060738   8.        ]
#
# gap: 2.35463876310841
# IDMVehicle #616: [959.00622834   8.        ]
#
# gap: 2.3503322194331453
# IDMVehicle #616: [960.07183543   8.        ]
#
# gap: 2.3460457425508503
# IDMVehicle #616: [961.13742864   8.        ]
#
# gap: 2.341779371910822
# IDMVehicle #616: [962.203008   8.      ]
#
# gap: 2.3375331460385773
# IDMVehicle #616: [963.26857349   8.        ]
#
# gap: 2.333307102498779
# IDMVehicle #616: [964.33412513   8.        ]
#
# gap: 2.329101280414081
# IDMVehicle #616: [965.39966291   8.        ]
#
# gap: 2.3249157181323126
# IDMVehicle #616: [966.46518685   8.        ]
#
# gap: 2.3207504535487384
# IDMVehicle #616: [967.53069694   8.        ]
#
# gap: 2.316605524584337
# IDMVehicle #616: [968.59619319   8.        ]
#
# gap: 2.312480969007556
# IDMVehicle #616: [969.6616756   8.       ]
#
# gap: 2.3083768247179544
# IDMVehicle #616: [970.72714418   8.        ]
#
# gap: 2.3042931293312936
# IDMVehicle #616: [971.79259894   8.        ]
#
# gap: 2.300229920370736
# IDMVehicle #616: [972.85803986   8.        ]
#
# gap: 2.296187235125503
# IDMVehicle #616: [973.92346697   8.        ]
#
# gap: 2.2921651108983383
# IDMVehicle #616: [974.98888025   8.        ]
#
# gap: 2.2881635846160995
# IDMVehicle #616: [976.05427973   8.        ]
#
# gap: 2.284182693304098
# IDMVehicle #616: [977.11966539   8.        ]
#
# gap: 2.2802224741362416
# IDMVehicle #616: [978.18503726   8.        ]
#
# gap: 2.2762829639136557
# IDMVehicle #616: [979.25039531   8.        ]
#
# gap: 2.272364199177134
# IDMVehicle #616: [980.31573958   8.        ]
#
# gap: 2.268466216612471
# IDMVehicle #616: [981.38107005   8.        ]
#
# gap: 2.264589052549593
# IDMVehicle #616: [982.44638673   8.        ]
#
# gap: 2.2607327434261233
# IDMVehicle #616: [983.51168963   8.        ]
#
# gap: 2.2568973252675457
# IDMVehicle #616: [984.57697874   8.        ]
#
# gap: 2.2530828332602137
# IDMVehicle #616: [985.64225408   8.        ]
#
# gap: 2.249289303843324
# IDMVehicle #616: [986.70751565   8.        ]
#
# gap: 2.245516772976435
# IDMVehicle #616: [987.77276345   8.        ]
#
# gap: 2.241765276324239
# IDMVehicle #616: [988.83799749   8.        ]
#
# gap: 2.238034849293232
# IDMVehicle #616: [989.90321776   8.        ]
#
# gap: 2.2343255271723566
# IDMVehicle #616: [990.96842429   8.        ]
#
# gap: 2.230637345212437
# IDMVehicle #616: [992.03361706   8.        ]
#
# gap: 2.2269703384925412
# IDMVehicle #616: [993.09879608   8.        ]
#
# gap: 2.2233245418773615
# IDMVehicle #616: [994.16396136   8.        ]
#
# gap: 2.21969998973748
# IDMVehicle #616: [995.22911291   8.        ]
#
# gap: 2.216096716880455
# IDMVehicle #616: [996.29425072   8.        ]
#
# gap: 2.212514757678182
# IDMVehicle #616: [997.3593748   8.       ]
#
# gap: 2.2089541465997797
# IDMVehicle #616: [998.42448516   8.        ]
#
# gap: 2.20541491764701
# IDMVehicle #616: [999.48958179   8.        ]
#
# gap: 2.2018971048329243
# IDMVehicle #616: [1000.55466471    8.        ]
#
# gap: 2.1984007420614953
# IDMVehicle #616: [1001.61973392    8.        ]
#
# gap: 2.1949258629916484
# IDMVehicle #616: [1002.68478942    8.        ]
#
# gap: 2.19147250107185
# IDMVehicle #616: [1003.74983122    8.        ]
#
# gap: 2.1880406898265434
# IDMVehicle #616: [1004.81485932    8.        ]
#
# gap: 2.1846304621606043
# IDMVehicle #616: [1005.87987372    8.        ]
#
# gap: 2.181241850417793
# IDMVehicle #616: [1006.94487444    8.        ]
#
# gap: 2.177874888205668
# IDMVehicle #616: [1008.00986147    8.        ]
#
# gap: 2.1745296081749803
# IDMVehicle #616: [1009.07483482    8.        ]
#
# gap: 2.171206042839742
# IDMVehicle #616: [1010.13979449    8.        ]
#
# gap: 2.167904224401748
# IDMVehicle #616: [1011.20474049    8.        ]
#
# gap: 2.16462418492965
# IDMVehicle #616: [1012.26967283    8.        ]
#
# gap: 2.161365956524576
# IDMVehicle #616: [1013.3345915    8.       ]
#
# gap: 2.158129570954448
# IDMVehicle #616: [1014.39949651    8.        ]
#
# gap: 2.154915059649812
# IDMVehicle #616: [1015.46438788    8.        ]
#
# gap: 2.1517224539926207
# IDMVehicle #616: [1016.52926559    8.        ]
#
# gap: 2.148551785216914
# IDMVehicle #616: [1017.59412966    8.        ]
#
# gap: 2.1454030843054372
# IDMVehicle #616: [1018.65898009    8.        ]
#
# gap: 2.1422763822418345
# IDMVehicle #616: [1019.72381688    8.        ]
#
# gap: 2.13917170964392
# IDMVehicle #616: [1020.78864004    8.        ]
#
# gap: 2.1360890968692274
# IDMVehicle #616: [1021.85344958    8.        ]
#
# gap: 2.1330285742557455
# IDMVehicle #616: [1022.9182455    8.       ]
#
# gap: 2.1299901717305803
# IDMVehicle #616: [1023.9830278    8.       ]
#
# gap: 2.126973918976078
# IDMVehicle #616: [1025.04779649    8.        ]
#
# gap: 2.1239798458664723
# IDMVehicle #616: [1026.11255158    8.        ]
#
# gap: 2.12100798182908
# IDMVehicle #616: [1027.17729306    8.        ]
#
# gap: 2.1180583555944903
# IDMVehicle #616: [1028.24202094    8.        ]
#
# gap: 2.1151309966420024
# IDMVehicle #616: [1029.30673523    8.        ]
#
# gap: 2.1122259338697598
# IDMVehicle #616: [1030.37143594    8.        ]
#
# gap: 2.1093431959004203
# IDMVehicle #616: [1031.43612306    8.        ]
#
# gap: 2.106482811023409
# IDMVehicle #616: [1032.5007966    8.       ]
#
# gap: 2.1036448072487683
# IDMVehicle #616: [1033.56545657    8.        ]
#
# gap: 2.1008292124094243
# IDMVehicle #616: [1034.63010297    8.        ]
#
# gap: 2.0980360544070766
# IDMVehicle #616: [1035.69473581    8.        ]
#
# gap: 2.0952653608395577
# IDMVehicle #616: [1036.75935509    8.        ]
#
# gap: 2.0925171588822913
# IDMVehicle #616: [1037.82396081    8.        ]
#
# gap: 2.0897914756213885
# IDMVehicle #616: [1038.88855299    8.        ]
#
# gap: 2.0870883377399183
# IDMVehicle #616: [1039.95313162    8.        ]
#
# gap: 2.084407771931023
# IDMVehicle #616: [1041.01769671    8.        ]
#
# gap: 2.0817498044848053
# IDMVehicle #616: [1042.08224827    8.        ]
#
# gap: 2.0791144613601578
# IDMVehicle #616: [1043.14678629    8.        ]
#
# gap: 2.0765017684724345
# IDMVehicle #616: [1044.2113108    8.       ]
#
# gap: 2.0739117514413037
# IDMVehicle #616: [1045.27581499    8.        ]
#
# gap: 2.071344145762424
# IDMVehicle #616: [1046.34028635    8.        ]
#
# gap: 2.0687984411759324
# IDMVehicle #616: [1047.40471309    8.        ]
#
# gap: 2.0662741583358377
# IDMVehicle #616: [1048.4690867    8.       ]
#
# gap: 2.0637709578157386
# IDMVehicle #616: [1049.53340246    8.        ]
#
# gap: 2.0612886635293934
# IDMVehicle #616: [1050.59765901    8.        ]
#
# gap: 2.0588272433887758
# IDMVehicle #616: [1051.66185763    8.        ]
#
# gap: 2.0563867765303794
# IDMVehicle #616: [1052.72600135    8.        ]
#
# gap: 2.0539674188875736
# IDMVehicle #616: [1053.79009432    8.        ]
#
# gap: 2.051569372831154
# IDMVehicle #616: [1054.85414223    8.        ]
#
# gap: 2.0491929075638176
# IDMVehicle #616: [1055.91815088    8.        ]
#
# gap: 2.0468382958728997
# IDMVehicle #616: [1056.98212587    8.        ]
#
# gap: 2.0445058023912877
# IDMVehicle #616: [1058.04607247    8.        ]
#
# gap: 2.042195676061751
# IDMVehicle #616: [1059.10999548    8.        ]
#
# gap: 2.0399081461533655
# IDMVehicle #616: [1060.17389921    8.        ]
#
# gap: 2.037643420387859
# IDMVehicle #616: [1061.2382464    8.       ]
#
# gap: 2.035421397738067
# IDMVehicle #616: [1062.30302609    8.        ]
#
# gap: 2.0332416531611672
# IDMVehicle #616: [1063.36822757    8.        ]
#
# gap: 2.031103720460636
# IDMVehicle #616: [1064.43384039    8.        ]
#
# gap: 2.0290071523913076
# IDMVehicle #616: [1065.49985434    8.        ]
#
# gap: 2.0269515120554127
# IDMVehicle #616: [1066.56625946    8.        ]
#
# gap: 2.024936372552423
# IDMVehicle #616: [1067.63304601    8.        ]
#
# gap: 2.0229613169264242
# IDMVehicle #616: [1068.70020448    8.        ]
#
# gap: 2.021025937652759
# IDMVehicle #616: [1069.76772562    8.        ]
#
# gap: 2.0191298363825636
# IDMVehicle #616: [1070.83560035    8.        ]
#
# gap: 2.017272622988612
# IDMVehicle #616: [1071.90381983    8.        ]
#
# gap: 2.01545391908924
# IDMVehicle #616: [1072.97237544    8.        ]
#
# gap: 2.0136733535234406
# IDMVehicle #616: [1074.04125875    8.        ]
#
# gap: 2.011930563641452
# IDMVehicle #616: [1075.11046154    8.        ]
#
# gap: 2.010225195144711
# IDMVehicle #616: [1076.17997578    8.        ]
#
# gap: 2.00855690194377
# IDMVehicle #616: [1077.24979363    8.        ]
#
# gap: 2.0069253459005383
# IDMVehicle #616: [1078.31990746    8.        ]
#
# gap: 2.00533019661112
# IDMVehicle #616: [1079.3903098    8.       ]
#
# gap: 2.003771131262072
# IDMVehicle #616: [1080.46099337    8.        ]
#
# gap: 2.0022478344830024
# IDMVehicle #616: [1081.53195106    8.        ]
#
# gap: 2.000759997969074
# IDMVehicle #616: [1082.60317595    8.        ]
#
# gap: 1.9993073207063237
# IDMVehicle #616: [1083.67466126    8.        ]
#
# gap: 1.997889508451033
# IDMVehicle #616: [1084.7464004    8.       ]
#
# gap: 1.9965062736558803
# IDMVehicle #616: [1085.81838692    8.        ]
#
# gap: 1.995157335318809
# IDMVehicle #616: [1086.89061454    8.        ]
#
# gap: 1.9938424188458663
# IDMVehicle #616: [1087.96307713    8.        ]
#
# gap: 1.9925612558647225
# IDMVehicle #616: [1089.03576871    8.        ]
#
# gap: 1.9913135840999363
# IDMVehicle #616: [1090.10868343    8.        ]
#
# gap: 1.9900991471062692
# IDMVehicle #616: [1091.18181562    8.        ]
#
# gap: 1.9889176939938888
# IDMVehicle #616: [1092.25515971    8.        ]
#
# gap: 1.9877689800297835
# IDMVehicle #616: [1093.32871028    8.        ]
#
# gap: 1.9866527657283966
# IDMVehicle #616: [1094.40246206    8.        ]
#
# gap: 1.985568816917758
# IDMVehicle #616: [1095.47640988    8.        ]
#
# gap: 1.9845169046137237
# IDMVehicle #616: [1096.55054873    8.        ]
#
# gap: 1.9834968048773636
# IDMVehicle #616: [1097.62487369    8.        ]
#
# gap: 1.9825082987740608
# IDMVehicle #616: [1098.69937998    8.        ]
#
# gap: 1.9815511721296053
# IDMVehicle #616: [1099.77406293    8.        ]
#
# gap: 1.9806252154774402
# IDMVehicle #616: [1100.848918    8.      ]
#
# gap: 1.9797302238656131
# IDMVehicle #616: [1101.92394075    8.        ]
#
# gap: 1.9788659968811304
# IDMVehicle #616: [1102.99912685    8.        ]
#
# gap: 1.9780323383275222
# IDMVehicle #616: [1104.07447207    8.        ]
#
# gap: 1.9772290563011863
# IDMVehicle #616: [1105.14997231    8.        ]
#
# gap: 1.976455962958088
# IDMVehicle #616: [1106.22562354    8.        ]
#
# gap: 1.975712874420518
# IDMVehicle #616: [1107.30142185    8.        ]
#
# gap: 1.9749996107084566
# IDMVehicle #616: [1108.37736342    8.        ]
#
# gap: 1.9743159955936944
# IDMVehicle #616: [1109.45344454    8.        ]
#
# gap: 1.9736618565341075
# IDMVehicle #616: [1110.52966157    8.        ]
#
# gap: 1.973037024546274
# IDMVehicle #616: [1111.60601096    8.        ]
#
# gap: 1.9724413341101208
# IDMVehicle #616: [1112.68248928    8.        ]
#
# gap: 1.971874622998775
# IDMVehicle #616: [1113.75909314    8.        ]
#
# gap: 1.9713367324526283
# IDMVehicle #616: [1114.83581928    8.        ]
#
# gap: 1.9708275068023164
# IDMVehicle #616: [1115.91266449    8.        ]
#
# gap: 1.9703467934556151
# IDMVehicle #616: [1116.98962565    8.        ]
#
# gap: 1.9698944428144678
# IDMVehicle #616: [1118.06669971    8.        ]
#
# gap: 1.9694703082095923
# IDMVehicle #616: [1119.14388372    8.        ]
#
# gap: 1.969074245835177
# IDMVehicle #616: [1120.22117478    8.        ]
#
# gap: 1.9687061145938065
# IDMVehicle #616: [1121.29857007    8.        ]
#
# gap: 1.9683657761138136
# IDMVehicle #616: [1122.37606685    8.        ]
#
# gap: 1.9680530945791874
# IDMVehicle #616: [1123.45366242    8.        ]
#
# gap: 1.9677679367175083
# IDMVehicle #616: [1124.53135419    8.        ]
#
# gap: 1.9675101716759418
# IDMVehicle #616: [1125.60913959    8.        ]
#
# gap: 1.9672796709871738
# IDMVehicle #616: [1126.68701616    8.        ]
#
# gap: 1.967076308474657
# IDMVehicle #616: [1127.76498146    8.        ]
#
# gap: 1.9668999601873818
# IDMVehicle #616: [1128.84303314    8.        ]
#
# gap: 1.9667505043324534
# IDMVehicle #616: [1129.9211689    8.       ]
#
# gap: 1.9666278212122474
# IDMVehicle #616: [1130.99938649    8.        ]
#
# gap: 1.9665317931614972
# IDMVehicle #616: [1132.07768373    8.        ]
#
# gap: 1.9664623044809284
# IDMVehicle #616: [1133.15605848    8.        ]
#
# gap: 1.9664192413626047
# IDMVehicle #616: [1134.23450868    8.        ]
#
# gap: 1.966402491833235
# IDMVehicle #616: [1135.31303228    8.        ]
#
# gap: 1.9664119457210658
# IDMVehicle #616: [1136.39162732    8.        ]
#
# gap: 1.9664474945653678
# IDMVehicle #616: [1137.47029188    8.        ]
#
# gap: 1.9665090315697942
# IDMVehicle #616: [1138.54902407    8.        ]
#
# gap: 1.9665964515494458
# IDMVehicle #616: [1139.62782207    8.        ]
#
# gap: 1.9667096508794337
# IDMVehicle #616: [1140.70668409    8.        ]
#
# gap: 1.966848527435519
# IDMVehicle #616: [1141.7856084    8.       ]
#
# gap: 1.9670129805441627
# IDMVehicle #616: [1142.86459331    8.        ]
#
# gap: 1.9672029109351579
# IDMVehicle #616: [1143.94363715    8.        ]
#
# gap: 1.9674182206924185
# IDMVehicle #616: [1145.02273833    8.        ]
#
# gap: 1.967658813199007
# IDMVehicle #616: [1146.10189528    8.        ]
#
# gap: 1.9679245931131453
# IDMVehicle #616: [1147.18110646    8.        ]
#
# gap: 1.9682154662807072
# IDMVehicle #616: [1148.26037038    8.        ]
#
# gap: 1.9685313397323227
# IDMVehicle #616: [1149.3396856    8.       ]
#
# gap: 1.96887212162813
# IDMVehicle #616: [1150.41905069    8.        ]
#
# gap: 1.9692377211904386
# IDMVehicle #616: [1151.49846428    8.        ]
#
# gap: 1.9696280486937656
# IDMVehicle #616: [1152.57792502    8.        ]
#
# gap: 1.9700430154014974
# IDMVehicle #616: [1153.6574316    8.       ]
#
# gap: 1.9704825335385845
# IDMVehicle #616: [1154.73698275    8.        ]
#
# gap: 1.9709465162610424
# IDMVehicle #616: [1155.81657721    8.        ]
#
# gap: 1.971434877656094
# IDMVehicle #616: [1156.89621377    8.        ]
#
# gap: 1.9719475325608329
# IDMVehicle #616: [1157.97589125    8.        ]
#
# gap: 1.9724843966646555
# IDMVehicle #616: [1159.0556085    8.       ]
#
# gap: 1.9730453864463477
# IDMVehicle #616: [1160.13536439    8.        ]
#
# gap: 1.973630419108706
# IDMVehicle #616: [1161.21515782    8.        ]
#
# gap: 1.9742394125785836
# IDMVehicle #616: [1162.29498774    8.        ]
#
# gap: 1.974872285438007
# IDMVehicle #616: [1163.37485309    8.        ]
#
# gap: 1.975528956930706
# IDMVehicle #616: [1164.45475287    8.        ]
#
# gap: 1.976209346887683
# IDMVehicle #616: [1165.53468609    8.        ]
#
# gap: 1.9769133757634414
# IDMVehicle #616: [1166.61465178    8.        ]
#
# gap: 1.977640964521914
# IDMVehicle #616: [1167.694649    8.      ]
#
# gap: 1.978392034723015
# IDMVehicle #616: [1168.77467684    8.        ]
#
# gap: 1.9791665083679693
# IDMVehicle #616: [1169.85473441    8.        ]
#
# gap: 1.9799643079097349
# IDMVehicle #616: [1170.93482083    8.        ]
#
# gap: 1.9807853562624045
# IDMVehicle #616: [1172.01493527    8.        ]
#
# gap: 1.9816295767510548
# IDMVehicle #616: [1173.09507689    8.        ]
#
# gap: 1.9824968931276903
# IDMVehicle #616: [1174.1752449    8.       ]
#
# gap: 1.9833872294733572
# IDMVehicle #616: [1175.2554385    8.       ]
#
# gap: 1.9843005102011286
# IDMVehicle #616: [1176.33565693    8.        ]
#
# gap: 1.9852366600736362
# IDMVehicle #616: [1177.41589945    8.        ]
#
# gap: 1.9861956042676843
# ...
#
# gap: 3.0402210002884624
# IDMVehicle #616: [1549.08758254    8.        ]
#
# gap: 3.0433440363042914
# IDMVehicle #616: [1550.16735663    8.        ]
#
# gap: 3.04645646586882
# IDMVehicle #616: [1551.24712604    8.        ]
#
# gap: 3.0495582293324963
# IDMVehicle #616: [1552.32689075    8.        ]
#
# gap: 3.0526492677529875
# IDMVehicle #616: [1553.40665077    8.        ]
#
# gap: 3.0557295227051178
# IDMVehicle #616: [1554.4864061    8.       ]
#
# gap: 3.058798936521634
# IDMVehicle #616: [1555.56615673    8.        ]
#
# gap: 3.061857452050681
# IDMVehicle #616: [1556.64590267    8.        ]
#
# gap: 3.0649050128140027
# IDMVehicle #616: [1557.72564391    8.        ]
#
# gap: 3.067941562829991
# IDMVehicle #616: [1558.80538045    8.        ]
#
# gap: 3.0709670468372003
# IDMVehicle #616: [1559.88511229    8.        ]
#
# gap: 3.073981410114463
# IDMVehicle #616: [1560.96483943    8.        ]
#
# gap: 3.076984598500344
# IDMVehicle #616: [1562.04456187    8.        ]
#
# gap: 3.0799765585146037
# IDMVehicle #616: [1563.12427961    8.        ]
#
# gap: 3.082957237290789
# IDMVehicle #616: [1564.20399264    8.        ]
#
# gap: 3.085926582479387
# IDMVehicle #616: [1565.28370097    8.        ]
#
# gap: 3.0888845424782874
# IDMVehicle #616: [1566.36340459    8.        ]
#
# gap: 3.09183106646237
# IDMVehicle #616: [1567.4431035    8.       ]
#
# gap: 3.094766103849069
# IDMVehicle #616: [1568.5227977    8.       ]
#
# gap: 3.0976896047519675
# IDMVehicle #616: [1569.60248719    8.        ]
#
# gap: 3.100601519927306
# IDMVehicle #616: [1570.68217197    8.        ]
#
# gap: 3.1035018008102515
# IDMVehicle #616: [1571.76185204    8.        ]
#
# gap: 3.106390399422761
# IDMVehicle #616: [1572.84152739    8.        ]
#
# gap: 3.1092672683121787
# IDMVehicle #616: [1573.92119803    8.        ]
#
# gap: 3.1121323606990208
# IDMVehicle #616: [1575.00086395    8.        ]
#
# gap: 3.1149856303615255
# IDMVehicle #616: [1576.08052515    8.        ]
#
# gap: 3.117827031761979
# IDMVehicle #616: [1577.16018163    8.        ]
#
# gap: 3.120656519927995
# IDMVehicle #616: [1578.23983339    8.        ]
#
# gap: 3.123474050613183
# IDMVehicle #616: [1579.31948043    8.        ]
#
# gap: 3.126279579953856
# IDMVehicle #616: [1580.39912275    8.        ]
#
# gap: 3.129073064762866
# IDMVehicle #616: [1581.47876034    8.        ]
#
# gap: 3.131854462506211
# IDMVehicle #616: [1582.55839321    8.        ]
#
# gap: 3.134623731224707
# IDMVehicle #616: [1583.63802136    8.        ]
#
# gap: 3.137380829599614
# IDMVehicle #616: [1584.71764477    8.        ]
#
# gap: 3.1401257168393526
# IDMVehicle #616: [1585.79726346    8.        ]
#
# gap: 3.1428583527849803
# IDMVehicle #616: [1586.87687741    8.        ]
#
# gap: 3.145578697995945
# IDMVehicle #616: [1587.95648664    8.        ]
#
# gap: 3.148286713795848
# IDMVehicle #616: [1589.03609113    8.        ]
#
# gap: 3.150982361495686
# IDMVehicle #616: [1590.11569089    8.        ]
#
# gap: 3.1536656032402366
# IDMVehicle #616: [1591.19528591    8.        ]
#
# gap: 3.1563364018977067
# IDMVehicle #616: [1592.2748762    8.       ]
#
# gap: 3.1589947209067404
# IDMVehicle #616: [1593.35446175    8.        ]
#
# gap: 3.1616405242787815
# IDMVehicle #616: [1594.43404256    8.        ]
#
# gap: 3.1642737766015596
# IDMVehicle #616: [1595.51361863    8.        ]
#
# gap: 3.166894443103277
# IDMVehicle #616: [1596.59318996    8.        ]
#
# gap: 3.169502489573685
# IDMVehicle #616: [1597.67275655    8.        ]
#
# gap: 3.1720978825025608
# IDMVehicle #616: [1598.7523184    8.       ]
#
# gap: 3.1746805887245433
# IDMVehicle #616: [1599.8318755    8.       ]
#
# gap: 3.17725057581736
# IDMVehicle #616: [1600.91142786    8.        ]
#
# gap: 3.1798078118937143
# IDMVehicle #616: [1601.99097547    8.        ]
#
# gap: 3.1823522656554832
# IDMVehicle #616: [1603.07051833    8.        ]
#
# gap: 3.1848839064320735
# IDMVehicle #616: [1604.15005644    8.        ]
#
# gap: 3.1874027040825155
# IDMVehicle #616: [1605.2295898    8.       ]
#
# gap: 3.1899086290667498
# IDMVehicle #616: [1606.30911841    8.        ]
#
# gap: 3.1924016525382033
# IDMVehicle #616: [1607.38864227    8.        ]
#
# gap: 3.194881746010462
# IDMVehicle #616: [1608.46816137    8.        ]
#
# gap: 3.19734888167858
# IDMVehicle #616: [1609.54767572    8.        ]
#
# gap: 3.1998030324421665
# IDMVehicle #616: [1610.62718532    8.        ]
#
# gap: 3.202244171426843
# IDMVehicle #616: [1611.70669015    8.        ]
#
# gap: 3.2046722724903436
# IDMVehicle #616: [1612.78619023    8.        ]
#
# gap: 3.207087310108152
# IDMVehicle #616: [1613.86568554    8.        ]
#
# gap: 3.209489259296263
# IDMVehicle #616: [1614.9451761    8.       ]
#
# gap: 3.2118780956817314
# IDMVehicle #616: [1616.02466189    8.        ]
#
# gap: 3.2142537953617847
# IDMVehicle #616: [1617.10414292    8.        ]
#
# gap: 3.216616335138001
# IDMVehicle #616: [1618.18361919    8.        ]
#
# gap: 3.2189656921749252
# IDMVehicle #616: [1619.26309069    8.        ]
#
# gap: 3.2213018453893536
# IDMVehicle #616: [1620.34255742    8.        ]
#
# gap: 3.2236247720659152
# IDMVehicle #616: [1621.42201938    8.        ]
#
# gap: 3.225934451149384
# IDMVehicle #616: [1622.50147658    8.        ]
#
# gap: 3.228230862072257
# IDMVehicle #616: [1623.580929    8.      ]
#
# gap: 3.230513984873162
# IDMVehicle #616: [1624.66037666    8.        ]
#
# gap: 3.232783800171913
# IDMVehicle #616: [1625.73981954    8.        ]
#
# gap: 3.235040289045517
# IDMVehicle #616: [1626.81925765    8.        ]
#
# gap: 3.2372834331657554
# IDMVehicle #616: [1627.89869098    8.        ]
#
# gap: 3.239513214672436
# IDMVehicle #616: [1628.97811953    8.        ]
#
# gap: 3.2417296162823304
# IDMVehicle #616: [1630.05754331    8.        ]
#
# gap: 3.2439326212993205
# IDMVehicle #616: [1631.13696231    8.        ]
#
# gap: 3.2461222137072916
# IDMVehicle #616: [1632.21637653    8.        ]
#
# gap: 3.2482983776759218
# IDMVehicle #616: [1633.29578597    8.        ]
#
# gap: 3.250461098048441
# IDMVehicle #616: [1634.37519062    8.        ]
#
# gap: 3.2526103602418317
# IDMVehicle #616: [1635.45459049    8.        ]
#
# gap: 3.2547461501590815
# IDMVehicle #616: [1636.53398558    8.        ]
#
# gap: 3.256868454251281
# IDMVehicle #616: [1637.61337588    8.        ]
#
# gap: 3.258977259439571
# IDMVehicle #616: [1638.6927614    8.       ]
#
# gap: 3.261072553213629
# IDMVehicle #616: [1639.77214213    8.        ]
#
# gap: 3.2631543235626177
# IDMVehicle #616: [1640.85151806    8.        ]
#
# gap: 3.2652225590097013
# IDMVehicle #616: [1641.93088921    8.        ]
#
# gap: 3.267277248533274
# IDMVehicle #616: [1643.01025557    8.        ]
#
# gap: 3.269318381708766
# IDMVehicle #616: [1644.08961713    8.        ]
#
# gap: 3.27134594859651
# IDMVehicle #616: [1645.1689739    8.       ]
#
# gap: 3.273359939714874
# IDMVehicle #616: [1646.24832588    8.        ]
#
# gap: 3.2753603461149856
# IDMVehicle #616: [1647.32767305    8.        ]
#
# gap: 3.277347159290607
# IDMVehicle #616: [1648.40701544    8.        ]
#
# gap: 3.2793203713035073
# IDMVehicle #616: [1649.48635302    8.        ]
#
# gap: 3.2812799746929464
# IDMVehicle #616: [1650.5656858    8.       ]
#
# gap: 3.2832259624428604
# IDMVehicle #616: [1651.64501378    8.        ]
#
# gap: 3.285158328092547
# IDMVehicle #616: [1652.72433696    8.        ]
#
# gap: 3.287077065816847
# IDMVehicle #616: [1653.80365534    8.        ]
#
# gap: 3.2889821700208612
# IDMVehicle #616: [1654.88296891    8.        ]
#
# gap: 3.290873635587804
# IDMVehicle #616: [1655.96227768    8.        ]
#
# gap: 3.2927514579230968
# IDMVehicle #616: [1657.04158164    8.        ]
#
# gap: 3.294615633007054
# IDMVehicle #616: [1658.12088079    8.        ]
#
# gap: 3.29646615728094
# IDMVehicle #616: [1659.20017513    8.        ]
#
# gap: 3.2983030275638328
# IDMVehicle #616: [1660.27946466    8.        ]
#
# gap: 3.3001262412090338
# IDMVehicle #616: [1661.35874938    8.        ]
#
# gap: 3.3019357960175926
# IDMVehicle #616: [1662.43802929    8.        ]
#
# gap: 3.303731690345728
# IDMVehicle #616: [1663.51730439    8.        ]
#
# gap: 3.3055139229330335
# IDMVehicle #616: [1664.59657467    8.        ]
#
# gap: 3.3072824929624955
# IDMVehicle #616: [1665.67584013    8.        ]
#
# gap: 3.3090374000396716
# IDMVehicle #616: [1666.75510078    8.        ]
#
# gap: 3.3107786442785283
# IDMVehicle #616: [1667.83435661    8.        ]
#
# gap: 3.312506226260849
# IDMVehicle #616: [1668.91360762    8.        ]
#
# gap: 3.3142201469842227
# IDMVehicle #616: [1669.9928538    8.       ]
#
# gap: 3.315920407904523
# IDMVehicle #616: [1671.07209517    8.        ]
#
# gap: 3.3176070109374107
# IDMVehicle #616: [1672.15133171    8.        ]
#
# gap: 3.319279958394712
# IDMVehicle #616: [1673.23056343    8.        ]
#
# gap: 3.3209392531050126
# IDMVehicle #616: [1674.30979033    8.        ]
#
# gap: 3.3225848983937505
# IDMVehicle #616: [1675.3890124    8.       ]
#
# gap: 3.324216897774254
# IDMVehicle #616: [1676.46822963    8.        ]
#
# gap: 3.3258352552879638
# IDMVehicle #616: [1677.54744205    8.        ]
#
# gap: 3.3274399754335757
# IDMVehicle #616: [1678.62664963    8.        ]
#
# gap: 3.3290310631602633
# IDMVehicle #616: [1679.70585238    8.        ]
#
# gap: 3.3306085238234546
# IDMVehicle #616: [1680.78505029    8.        ]
#
# gap: 3.3321723631664204
# IDMVehicle #616: [1681.86424338    8.        ]
#
# gap: 3.3337225874123604
# IDMVehicle #616: [1682.94343163    8.        ]
#
# gap: 3.335259203198328
# IDMVehicle #616: [1684.02261504    8.        ]
#
# gap: 3.336782217506319
# IDMVehicle #616: [1685.10179362    8.        ]
#
# gap: 3.3382916377099408
# IDMVehicle #616: [1686.18096736    8.        ]
#
# gap: 3.3397874716792124
# IDMVehicle #616: [1687.26013626    8.        ]
#
# gap: 3.3412697276271315
# IDMVehicle #616: [1688.33930032    8.        ]
#
# gap: 3.342738414173991
# IDMVehicle #616: [1689.41845954    8.        ]
#
# gap: 3.344193540360971
# IDMVehicle #616: [1690.49761391    8.        ]
#
# gap: 3.345635115607797
# IDMVehicle #616: [1691.57676344    8.        ]
#
# gap: 3.3470631497428798
# IDMVehicle #616: [1692.65590813    8.        ]
#
# gap: 3.3484776529728117
# IDMVehicle #616: [1693.73504797    8.        ]
#
# gap: 3.3498786358553208
# IDMVehicle #616: [1694.81418296    8.        ]
#
# gap: 3.351266109357038
# IDMVehicle #616: [1695.8933131    8.       ]
#
# gap: 3.3526400849395808
# IDMVehicle #616: [1696.9724384    8.       ]
#
# gap: 3.354000574254415
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb Cell 2' in <cell line: 14>()
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=12'>13</a> done = False
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=13'>14</a> while not done:
# ---> <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=14'>15</a>     env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=15'>16</a>     env.render()    # with manual control, these actions are ignored
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=16'>17</a> env.close()
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=8'>9</a> def step(self, action):
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=9'>10</a>     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=10'>11</a>     observation, reward, done, info = self.env.step(action)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=11'>12</a>     return observation, reward, done, info
#
# File ~/HighwayDRL/highway_env/envs/common/abstract.py:215, in AbstractEnv.step(self, action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=211'>212</a>     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=213'>214</a> self.steps += 1
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=214'>215</a> self._simulate(action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=216'>217</a> obs = self.observation_type.observe()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=217'>218</a> reward = self._reward(action)
#
# File ~/HighwayDRL/highway_env/envs/common/abstract.py:241, in AbstractEnv._simulate(self, action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=237'>238</a>     # Automatically render intermediate simulation steps if a viewer has been launched
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=238'>239</a>     # Ignored if the rendering is done offscreen
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=239'>240</a>     if frame < frames - 1:  # Last frame will be rendered through env.render() as usual
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=240'>241</a>         self._automatic_rendering()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=242'>243</a> self.enable_auto_render = False
#
# File ~/HighwayDRL/highway_env/envs/common/abstract.py:321, in AbstractEnv._automatic_rendering(self)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=318'>319</a>     self._monitor.video_recorder.capture_frame()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=319'>320</a> else:
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=320'>321</a>     self.render(self.rendering_mode)
#
# File ~/HighwayDRL/highway_env/envs/common/abstract.py:259, in AbstractEnv.render(self, mode)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=254'>255</a>     self.viewer = EnvViewer(self)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=256'>257</a> self.enable_auto_render = True
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=258'>259</a> self.viewer.display()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=260'>261</a> if not self.viewer.offscreen:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=261'>262</a>     self.viewer.handle_events()
#
# File ~/HighwayDRL/highway_env/envs/common/graphics.py:135, in EnvViewer.display(self)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/graphics.py?line=132'>133</a>     if self.env.config["real_time_rendering"]:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/graphics.py?line=133'>134</a>         self.clock.tick(self.env.config["simulation_frequency"])
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/graphics.py?line=134'>135</a>     pygame.display.flip()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/graphics.py?line=136'>137</a> if self.SAVE_IMAGES and self.directory:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/graphics.py?line=137'>138</a>     pygame.image.save(self.sim_surface, str(self.directory / "highway-env_{}.png".format(self.frame)))
#
# KeyboardInterrupt:
