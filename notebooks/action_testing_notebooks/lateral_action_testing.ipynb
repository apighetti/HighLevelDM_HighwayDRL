# %%
# %pip install .
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
import gym
import highway_env

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width": 1250,
    "simulation_frequency": 20
    
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored
env.close()
# Out:
# IDMVehicle #832: [276.41022479   5.94903983]
#
# gap: 2.087283061450375
# value: 2.087283061450375, target value: 2, throttle: -0.017456612290074957
# IDMVehicle #832: [277.37114113   5.77193301]
#
# gap: 2.072479827698335
# value: 2.072479827698335, target value: 2, throttle: -0.014495965539667033
# IDMVehicle #832: [278.33618029   5.60773108]
#
# gap: 2.0816886250116644
# value: 2.0816886250116644, target value: 2, throttle: -0.01633772500233288
# IDMVehicle #832: [279.30508535   5.45620234]
#
# gap: 2.0911690764835837
# value: 2.0911690764835837, target value: 2, throttle: -0.01823381529671675
# IDMVehicle #832: [280.27758461   5.31692273]
#
# gap: 2.1008445000953246
# value: 2.1008445000953246, target value: 2, throttle: -0.02016890001906493
# IDMVehicle #832: [281.25340851   5.18933722]
#
# gap: 2.110697134872666
# value: 2.110697134872666, target value: 2, throttle: -0.022139426974533194
# IDMVehicle #832: [282.2323003    5.07280698]
#
# gap: 2.12071018516344
# ...
