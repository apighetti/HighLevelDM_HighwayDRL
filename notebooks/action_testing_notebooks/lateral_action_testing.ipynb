# %%
import gym
import highway_env
import time
from stable_baselines3 import PPO
import pprint

N_AGENTS = 2
intelligent_agents = []

env = gym.make('dm-env-v0')
env.configure({
    "controlled_vehicles": N_AGENTS,
    "vehicles_count": 2,
    "screen_width":1500,
    "screen_height":250,
    "action": {
      "type": "MultiAgentAction",
    },
    "observation": {
      "type": "MultiAgentObservation"
    }
})
model = PPO.load('/home/pigo/projects/HighwayDRL/training_output/models/ppo_NEWTRAIN_cl2_6.5E+05_dm-env-v0_10-03_17-05-10')

for episode in range(3):
    obs = env.reset()
    done = truncated = False
    while not (done or truncated):
        pprint.pprint(obs)
        action = tuple(model.predict(obs_i) for obs_i in obs)
        env.render()
        next_obs, reward, done, truncated, info = env.step(action)



# env.reset()
# done = False
# while not done:
#     observation, reward, done, info = env.step(env.action_space.sample())
#     env.render()
    
    # if env.controlled_vehicles[0].lane_index[2]>0:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]-1)
    #     front_vehicle , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed
    #             overtake_gap = env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1

    # if env.controlled_vehicles[0].lane_index[2] + 1 < env.config["lanes_count"]:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]+1)
    #     _ , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap =  env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1
    # print(f"current overtakes: {overtake}")

env.close()
    # print(f"overall overtakes: {overtake}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-67e49ba9b8d9> in <module>
#      24
#      25 for episode in range(3):
# ---> 26     obs = env.reset()
#      27     done = truncated = False
#      28     while not (done or truncated):
#
# ~/miniconda3/envs/highway/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py in reset(self, **kwargs)
#      14     def reset(self, **kwargs):
#      15         self._has_reset = True
# ---> 16         return self.env.reset(**kwargs)
#
# ~/projects/HighwayDRL/highway_env/envs/common/abstract.py in reset(self)
#     185         """
#     186         self.update_metadata()
# --> 187         self.define_spaces()  # First, to set the controlled vehicle class depending on action space
#     188         self.time = self.steps = 0
#     189         self.done = False
#
# ~/projects/HighwayDRL/highway_env/envs/common/abstract.py in define_spaces(self)
#     127         Set the types and spaces of observation and action from config.
#     128         """
# --> 129         self.observation_type = observation_factory(self, self.config["observation"])
#     130         self.action_type = action_factory(self, self.config["action"])
#     131         self.observation_space = self.observation_type.space()
#
# ~/projects/HighwayDRL/highway_env/envs/common/observation.py in observation_factory(env, config)
#     636         return AttributesObservation(env, **config)
#     637     elif config["type"] == "MultiAgentObservation":
# --> 638         return MultiAgentObservation(env, **config)
#     639     elif config["type"] == "TupleObservation":
#     640         return TupleObservation(env, **config)
#
# TypeError: __init__() missing 1 required positional argument: 'observation_config'
