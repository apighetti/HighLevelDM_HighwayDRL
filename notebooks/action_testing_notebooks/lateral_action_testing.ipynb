# %%
# %pip install .
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
import gym
import highway_env
import time

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width": 1250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb Cell 2' in <cell line: 13>()
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=11'>12</a> done = False
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=12'>13</a> while not done:
# ---> <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=13'>14</a>     env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=14'>15</a>     env.render()    # with manual control, these actions are ignored
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=16'>17</a> env.close()
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=8'>9</a> def step(self, action):
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=9'>10</a>     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=10'>11</a>     observation, reward, done, info = self.env.step(action)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=11'>12</a>     return observation, reward, done, info
#
# File ~/HighwayDRL/highway_env/envs/common/abstract.py:215, in AbstractEnv.step(self, action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=211'>212</a>     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=213'>214</a> self.steps += 1
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=214'>215</a> self._simulate(action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=216'>217</a> obs = self.observation_type.observe()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=217'>218</a> reward = self._reward(action)
#
# File ~/HighwayDRL/highway_env/envs/common/abstract.py:234, in AbstractEnv._simulate(self, action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=228'>229</a> if action is not None \
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=229'>230</a>         and not self.config["manual_control"] \
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=230'>231</a>         and self.time % int(self.config["simulation_frequency"] // self.config["policy_frequency"]) == 0:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=231'>232</a>     self.action_type.act(action)
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=233'>234</a> self.road.act()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=234'>235</a> self.road.step(1 / self.config["simulation_frequency"])
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=235'>236</a> self.time += 1
#
# File ~/HighwayDRL/highway_env/road/road.py:324, in Road.act(self)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/road/road.py?line=321'>322</a> """Decide the actions of each entity on the road."""
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/road/road.py?line=322'>323</a> for vehicle in self.vehicles:
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/road/road.py?line=323'>324</a>     vehicle.act()
#
# File ~/HighwayDRL/highway_env/vehicle/behavior.py:96, in IDMVehicle.act(self, action)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/behavior.py?line=93'>94</a> if self.enable_lane_change:
#      <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/behavior.py?line=94'>95</a>     self.change_lane_policy()
# ---> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/behavior.py?line=95'>96</a> action['steering'] = self.steering_control(self.target_lane_index)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/behavior.py?line=96'>97</a> action['steering'] = np.clip(action['steering'], -self.MAX_STEERING_ANGLE, self.MAX_STEERING_ANGLE)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/behavior.py?line=98'>99</a> # Longitudinal: IDM
#
# File ~/HighwayDRL/highway_env/vehicle/controller.py:160, in ControlledVehicle.steering_control(self, target_lane_index)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/controller.py?line=157'>158</a> slip_angle = np.arcsin(np.clip(self.LENGTH / 2 / utils.not_zero(self.speed) * heading_rate_command, -1, 1))
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/controller.py?line=158'>159</a> steering_angle = np.arctan(2 * np.tan(slip_angle))
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/controller.py?line=159'>160</a> steering_angle = np.clip(steering_angle, -self.MAX_STEERING_ANGLE, self.MAX_STEERING_ANGLE)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/vehicle/controller.py?line=160'>161</a> return float(steering_angle)
#
# File <__array_function__ internals>:5, in clip(*args, **kwargs)
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2115, in clip(a, a_min, a_max, out, **kwargs)
#    <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=2045'>2046</a> @array_function_dispatch(_clip_dispatcher)
#    <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=2046'>2047</a> def clip(a, a_min, a_max, out=None, **kwargs):
#    <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=2047'>2048</a>     """
#    <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=2048'>2049</a>     Clip (limit) the values in an array.
#    <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=2049'>2050</a>
#    (...)
#    <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=2112'>2113</a>
#    <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=2113'>2114</a>     """
# -> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=2114'>2115</a>     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=53'>54</a>     return _wrapit(obj, method, *args, **kwds)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=55'>56</a> try:
# ---> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=56'>57</a>     return bound(*args, **kwds)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=57'>58</a> except TypeError:
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=58'>59</a>     # A TypeError occurs if the object does have such a method in its
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=59'>60</a>     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=63'>64</a>     # Call _wrapit from within the except clause to ensure a potential
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=64'>65</a>     # exception has a traceback chain.
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py?line=65'>66</a>     return _wrapit(obj, method, *args, **kwds)
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py:137, in _clip(a, min, max, out, casting, **kwargs)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=134'>135</a>     min = -float('inf')
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=135'>136</a>     using_deprecated_nan = True
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=136'>137</a> if _clip_dep_is_scalar_nan(max):
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=137'>138</a>     max = float('inf')
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=138'>139</a>     using_deprecated_nan = True
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py:97, in _clip_dep_is_scalar_nan(a)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=94'>95</a>     return False
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=95'>96</a> try:
# ---> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=96'>97</a>     return um.isnan(a)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=97'>98</a> except TypeError:
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/numpy/core/_methods.py?line=98'>99</a>     return False
#
# KeyboardInterrupt:
