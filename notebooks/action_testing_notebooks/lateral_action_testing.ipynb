# %%
# %pip install .
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
import gym
import highway_env
import time

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width": 1250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored

env.close()
# Out:
# reward: 0.009666666666666669, steps: 1 collision reward: -1.7, distance to t_duration: 0.008333333333333333
#
# reward: 0.03466666666666667, steps: 2 collision reward: -1.7, distance to t_duration: 0.016666666666666666
#
# reward: 0.05966666666666668, steps: 3 collision reward: -1.7, distance to t_duration: 0.025
#
# reward: 0.08466666666666667, steps: 4 collision reward: -1.7, distance to t_duration: 0.03333333333333333
#
# reward: 0.10966666666666666, steps: 5 collision reward: -1.7, distance to t_duration: 0.041666666666666664
#
# reward: 0.13466666666666668, steps: 6 collision reward: -1.7, distance to t_duration: 0.05
#
# reward: 0.15966666666666665, steps: 7 collision reward: -1.7, distance to t_duration: 0.058333333333333334
#
# reward: 0.18466666666666667, steps: 8 collision reward: -1.7, distance to t_duration: 0.06666666666666667
#
# reward: 0.20966666666666664, steps: 9 collision reward: -1.7, distance to t_duration: 0.075
#
# reward: 0.23466666666666666, steps: 10 collision reward: -1.7, distance to t_duration: 0.08333333333333333
#
# reward: 0.25966666666666666, steps: 11 collision reward: -1.7, distance to t_duration: 0.09166666666666666
#
# reward: 0.28466666666666673, steps: 12 collision reward: -1.7, distance to t_duration: 0.1
#
# reward: 0.3096666666666667, steps: 13 collision reward: -1.7, distance to t_duration: 0.10833333333333334
#
# reward: 0.33466666666666667, steps: 14 collision reward: -1.7, distance to t_duration: 0.11666666666666667
#
# reward: 0.3596666666666667, steps: 15 collision reward: -1.7, distance to t_duration: 0.125
#
# reward: 0.3846666666666667, steps: 16 collision reward: -1.7, distance to t_duration: 0.13333333333333333
#
# reward: 0.4096666666666667, steps: 17 collision reward: -1.7, distance to t_duration: 0.14166666666666666
#
# reward: 0.43466666666666665, steps: 18 collision reward: -1.7, distance to t_duration: 0.15
#
# reward: 0.45966666666666667, steps: 19 collision reward: -1.7, distance to t_duration: 0.15833333333333333
#
# reward: 0.48531243961849585, steps: 20 collision reward: -1.7, distance to t_duration: 0.16666666666666666
#
# reward: 0.511197478323682, steps: 21 collision reward: -1.7, distance to t_duration: 0.175
#
# reward: 0.5370183052177305, steps: 22 collision reward: -1.7, distance to t_duration: 0.18333333333333332
#
# reward: 0.5627750238255328, steps: 23 collision reward: -1.7, distance to t_duration: 0.19166666666666668
#
# reward: 0.5884677524576352, steps: 24 collision reward: -1.7, distance to t_duration: 0.2
#
# reward: 0.6140965831705691, steps: 25 collision reward: -1.7, distance to t_duration: 0.20833333333333334
#
# reward: 0.6396615730726954, steps: 26 collision reward: -1.7, distance to t_duration: 0.21666666666666667
#
# reward: 0.6651654446592474, steps: 27 collision reward: -1.7, distance to t_duration: 0.225
#
# reward: 0.6906080621082424, steps: 28 collision reward: -1.7, distance to t_duration: 0.23333333333333334
#
# reward: 0.7159854441681469, steps: 29 collision reward: -1.7, distance to t_duration: 0.24166666666666667
#
# reward: 0.7413020830779059, steps: 30 collision reward: -1.7, distance to t_duration: 0.25
#
# reward: 0.7665648673148161, steps: 31 collision reward: -1.7, distance to t_duration: 0.25833333333333336
#
# reward: 0.7917663542004801, steps: 32 collision reward: -1.7, distance to t_duration: 0.26666666666666666
#
# reward: 0.8169042040566561, steps: 33 collision reward: -1.7, distance to t_duration: 0.275
#
# reward: 0.8419819949008432, steps: 34 collision reward: -1.7, distance to t_duration: 0.2833333333333333
#
# reward: 0.8670035045589979, steps: 35 collision reward: -1.7, distance to t_duration: 0.2916666666666667
#
# reward: 0.8919714453639009, steps: 36 collision reward: -1.7, distance to t_duration: 0.3
#
# reward: 0.9168847509549647, steps: 37 collision reward: -1.7, distance to t_duration: 0.30833333333333335
#
# reward: 0.9417502421526909, steps: 38 collision reward: -1.7, distance to t_duration: 0.31666666666666665
#
# reward: 0.9665643744376652, steps: 39 collision reward: -1.7, distance to t_duration: 0.325
#
# reward: 0.9913282985781408, steps: 40 collision reward: -2.1, distance to t_duration: 0.3333333333333333
#
# reward: 1.0161465266346767, steps: 41 collision reward: -2.1, distance to t_duration: 0.3416666666666667
#
# reward: 1.0411465266346767, steps: 42 collision reward: -2.1, distance to t_duration: 0.35
#
# reward: 1.0656132764669668, steps: 43 collision reward: -2.1, distance to t_duration: 0.35833333333333334
#
# reward: 1.0892430967049114, steps: 44 collision reward: -2.1, distance to t_duration: 0.36666666666666664
#
# reward: 1.112895714130193, steps: 45 collision reward: -2.1, distance to t_duration: 0.375
#
# reward: 1.1366197348614693, steps: 46 collision reward: -2.1, distance to t_duration: 0.38333333333333336
#
# reward: 1.1604812326699707, steps: 47 collision reward: -2.1, distance to t_duration: 0.39166666666666666
#
# reward: 1.1845332211151722, steps: 48 collision reward: -2.1, distance to t_duration: 0.4
#
# reward: 1.208895663602658, steps: 49 collision reward: -2.1, distance to t_duration: 0.4083333333333333
#
# reward: 1.233895663602658, steps: 50 collision reward: -2.1, distance to t_duration: 0.4166666666666667
#
# reward: 1.2588956636026578, steps: 51 collision reward: -2.1, distance to t_duration: 0.425
#
# reward: 1.2838220878663928, steps: 52 collision reward: -2.1, distance to t_duration: 0.43333333333333335
#
# reward: 1.3087415462769603, steps: 53 collision reward: -2.1, distance to t_duration: 0.44166666666666665
#
# reward: 1.3337034191027906, steps: 54 collision reward: -2.1, distance to t_duration: 0.45
#
# reward: 1.3587056074322645, steps: 55 collision reward: -2.1, distance to t_duration: 0.4583333333333333
#
# reward: 1.383746394892249, steps: 56 collision reward: -2.1, distance to t_duration: 0.4666666666666667
#
# reward: 1.4088180149725884, steps: 57 collision reward: -2.1, distance to t_duration: 0.475
#
# reward: 1.4339237737127994, steps: 58 collision reward: -2.1, distance to t_duration: 0.48333333333333334
#
# reward: 1.459053676374397, steps: 59 collision reward: -2.1, distance to t_duration: 0.49166666666666664
#
# reward: 1.4842067060787296, steps: 60 collision reward: -2.1, distance to t_duration: 0.5
#
# reward: 1.5093803344301788, steps: 61 collision reward: -2.1, distance to t_duration: 0.5083333333333333
#
# reward: 1.5345676581530774, steps: 62 collision reward: -2.1, distance to t_duration: 0.5166666666666667
#
# reward: 1.5597657673317, steps: 63 collision reward: -2.1, distance to t_duration: 0.525
#
# reward: 1.5849706406864403, steps: 64 collision reward: -2.1, distance to t_duration: 0.5333333333333333
#
# reward: 1.6101786474158473, steps: 65 collision reward: -2.1, distance to t_duration: 0.5416666666666666
#
# reward: 1.6353865649580441, steps: 66 collision reward: -2.1, distance to t_duration: 0.55
#
# reward: 1.6605928723639805, steps: 67 collision reward: -2.1, distance to t_duration: 0.5583333333333333
#
# reward: 1.6857943817968108, steps: 68 collision reward: -2.1, distance to t_duration: 0.5666666666666667
#
# reward: 1.7109897839047579, steps: 69 collision reward: -2.1, distance to t_duration: 0.575
#
# reward: 1.7361844427991506, steps: 70 collision reward: -2.1, distance to t_duration: 0.5833333333333334
#
# reward: 1.7613770607142578, steps: 71 collision reward: -2.1, distance to t_duration: 0.5916666666666667
#
# reward: 1.7865654159754432, steps: 72 collision reward: -2.1, distance to t_duration: 0.6
#
# reward: 1.811747481662787, steps: 73 collision reward: -2.1, distance to t_duration: 0.6083333333333333
#
# reward: 1.8369217578425239, steps: 74 collision reward: -2.1, distance to t_duration: 0.6166666666666667
#
# reward: 1.8620862400669722, steps: 75 collision reward: -2.1, distance to t_duration: 0.625
#
# reward: 1.8872398681394913, steps: 76 collision reward: -2.1, distance to t_duration: 0.6333333333333333
#
# reward: 1.91238129896953, steps: 77 collision reward: -2.1, distance to t_duration: 0.6416666666666667
#
# reward: 1.9375098183567727, steps: 78 collision reward: -2.1, distance to t_duration: 0.65
#
# reward: 1.9626243190294326, steps: 79 collision reward: -2.1, distance to t_duration: 0.6583333333333333
#
# reward: 1.9877246210151982, steps: 80 collision reward: -2.5, distance to t_duration: 0.6666666666666666
#
# reward: 2.0128095171222955, steps: 81 collision reward: -2.5, distance to t_duration: 0.675
#
# reward: 2.037879338716106, steps: 82 collision reward: -2.5, distance to t_duration: 0.6833333333333333
#
# reward: 2.062934530298561, steps: 83 collision reward: -2.5, distance to t_duration: 0.6916666666666667
#
# reward: 2.0879741302220522, steps: 84 collision reward: -2.5, distance to t_duration: 0.7
#
# reward: 2.1129983329538695, steps: 85 collision reward: -2.5, distance to t_duration: 0.7083333333333334
#
# reward: 2.138007976634819, steps: 86 collision reward: -2.5, distance to t_duration: 0.7166666666666667
#
# reward: 2.163004324072727, steps: 87 collision reward: -2.5, distance to t_duration: 0.725
#
# reward: 2.187986067899965, steps: 88 collision reward: -2.5, distance to t_duration: 0.7333333333333333
#
# reward: 2.212953957682857, steps: 89 collision reward: -2.5, distance to t_duration: 0.7416666666666667
#
# reward: 2.237909424845301, steps: 90 collision reward: -2.5, distance to t_duration: 0.75
#
# reward: 2.262853808551452, steps: 91 collision reward: -2.5, distance to t_duration: 0.7583333333333333
#
# reward: 2.287787705939149, steps: 92 collision reward: -2.5, distance to t_duration: 0.7666666666666667
#
# reward: 2.312712196974777, steps: 93 collision reward: -2.5, distance to t_duration: 0.775
#
# reward: 2.337629097265566, steps: 94 collision reward: -2.5, distance to t_duration: 0.7833333333333333
#
# reward: 2.3625380865535415, steps: 95 collision reward: -2.5, distance to t_duration: 0.7916666666666666
#
# reward: 2.387440697306025, steps: 96 collision reward: -2.5, distance to t_duration: 0.8
#
# reward: 2.412338722293221, steps: 97 collision reward: -2.5, distance to t_duration: 0.8083333333333333
#
# reward: 2.4372332549277194, steps: 98 collision reward: -2.5, distance to t_duration: 0.8166666666666667
#
# reward: 2.46212565425036, steps: 99 collision reward: -2.5, distance to t_duration: 0.825
#
# reward: 2.4870172763457012, steps: 100 collision reward: -2.5, distance to t_duration: 0.8333333333333334
#
# reward: 2.5119093037060165, steps: 101 collision reward: -2.5, distance to t_duration: 0.8416666666666667
#
# reward: 2.5368030214584207, steps: 102 collision reward: -2.5, distance to t_duration: 0.85
#
# reward: 2.561699545290209, steps: 103 collision reward: -2.5, distance to t_duration: 0.8583333333333333
#
# reward: 2.586600105027235, steps: 104 collision reward: -2.5, distance to t_duration: 0.8666666666666667
#
# reward: 2.6115057509435013, steps: 105 collision reward: -2.5, distance to t_duration: 0.875
#
# reward: 2.6364171096874123, steps: 106 collision reward: -2.5, distance to t_duration: 0.8833333333333333
#
# reward: 2.661335336518938, steps: 107 collision reward: -2.5, distance to t_duration: 0.8916666666666667
#
# reward: 2.686261135798168, steps: 108 collision reward: -2.5, distance to t_duration: 0.9
#
# reward: 2.7111947076861442, steps: 109 collision reward: -2.5, distance to t_duration: 0.9083333333333333
#
# reward: 2.736136847634161, steps: 110 collision reward: -2.5, distance to t_duration: 0.9166666666666666
#
# reward: 2.7610877407159617, steps: 111 collision reward: -2.5, distance to t_duration: 0.925
#
# reward: 2.7860474506676303, steps: 112 collision reward: -2.5, distance to t_duration: 0.9333333333333333
#
# reward: 2.8110161334089705, steps: 113 collision reward: -2.5, distance to t_duration: 0.9416666666666667
#
# reward: 2.8359936106317747, steps: 114 collision reward: -2.5, distance to t_duration: 0.95
#
# reward: 2.860978685192146, steps: 115 collision reward: -2.5, distance to t_duration: 0.9583333333333334
#
# reward: 2.8859725361430337, steps: 116 collision reward: -2.5, distance to t_duration: 0.9666666666666667
#
# reward: 2.910974102569336, steps: 117 collision reward: -2.5, distance to t_duration: 0.975
#
# reward: 2.935983134154776, steps: 118 collision reward: -2.5, distance to t_duration: 0.9833333333333333
#
# reward: 2.960998510650626, steps: 119 collision reward: -2.5, distance to t_duration: 0.9916666666666667
#
# reward: 2.9860196028761865, steps: 120 collision reward: -3, distance to t_duration: 1.0
#
# reward: 3.011046201199093, steps: 121 collision reward: -2.5, distance to t_duration: 1.0083333333333333
#
# reward: 3.0360765410193236, steps: 122 collision reward: -2.5, distance to t_duration: 1.0166666666666666
#
# reward: 3.061110998610129, steps: 123 collision reward: -2.5, distance to t_duration: 1.025
#
# reward: 3.086148534109332, steps: 124 collision reward: -2.5, distance to t_duration: 1.0333333333333334
#
# reward: 3.1111880982291185, steps: 125 collision reward: -2.5, distance to t_duration: 1.0416666666666667
#
# reward: 3.1362290076795905, steps: 126 collision reward: -2.5, distance to t_duration: 1.05
#
# reward: 3.161270564184046, steps: 127 collision reward: -2.5, distance to t_duration: 1.0583333333333333
#
# reward: 3.186312048208905, steps: 128 collision reward: -2.5, distance to t_duration: 1.0666666666666667
#
# reward: 3.211352808599517, steps: 129 collision reward: -2.5, distance to t_duration: 1.075
#
# reward: 3.23639223173143, steps: 130 collision reward: -2.5, distance to t_duration: 1.0833333333333333
#
# reward: 3.2614297658020845, steps: 131 collision reward: -2.5, distance to t_duration: 1.0916666666666666
#
# reward: 3.2864648573852153, steps: 132 collision reward: -2.5, distance to t_duration: 1.1
#
# reward: 3.3114972087381096, steps: 133 collision reward: -2.5, distance to t_duration: 1.1083333333333334
#
# reward: 3.33652616847532, steps: 134 collision reward: -2.5, distance to t_duration: 1.1166666666666667
#
# reward: 3.3615513256592267, steps: 135 collision reward: -2.5, distance to t_duration: 1.125
#
# reward: 3.3868641520577256, steps: 136 collision reward: -2.5, distance to t_duration: 1.1333333333333333
#
# reward: 3.4104098021543434, steps: 137 collision reward: -2.5, distance to t_duration: 1.1416666666666666
#
# reward: 3.4359288291252077, steps: 138 collision reward: -2.5, distance to t_duration: 1.15
#
# reward: 3.461440087481221, steps: 139 collision reward: -2.5, distance to t_duration: 1.1583333333333334
#
# reward: 3.486876682754028, steps: 140 collision reward: -2.5, distance to t_duration: 1.1666666666666667
#
# reward: 3.5122606461202075, steps: 141 collision reward: -2.5, distance to t_duration: 1.175
#
# reward: 3.5375984758869934, steps: 142 collision reward: -2.5, distance to t_duration: 1.1833333333333333
#
# reward: 3.562882220310641, steps: 143 collision reward: -2.5, distance to t_duration: 1.1916666666666667
#
# reward: 3.588111752438033, steps: 144 collision reward: -2.5, distance to t_duration: 1.2
#
# reward: 3.6132919225536666, steps: 145 collision reward: -2.5, distance to t_duration: 1.2083333333333333
#
# reward: 3.6384225796832497, steps: 146 collision reward: -2.5, distance to t_duration: 1.2166666666666666
#
# reward: 3.6635052059665942, steps: 147 collision reward: -2.5, distance to t_duration: 1.225
#
# reward: 3.6885414309156523, steps: 148 collision reward: -2.5, distance to t_duration: 1.2333333333333334
#
# reward: 3.713536269877248, steps: 149 collision reward: -2.5, distance to t_duration: 1.2416666666666667
#
# reward: 3.738483256219195, steps: 150 collision reward: -2.5, distance to t_duration: 1.25
#
# reward: 3.763387701481337, steps: 151 collision reward: -2.5, distance to t_duration: 1.2583333333333333
#
# reward: 3.78825053349636, steps: 152 collision reward: -2.5, distance to t_duration: 1.2666666666666666
#
# reward: 3.813075086453473, steps: 153 collision reward: -2.5, distance to t_duration: 1.275
#
# reward: 3.837864586406077, steps: 154 collision reward: -2.5, distance to t_duration: 1.2833333333333334
#
# reward: 3.862618757724626, steps: 155 collision reward: -2.5, distance to t_duration: 1.2916666666666667
#
# reward: 3.8876010852777014, steps: 156 collision reward: -2.5, distance to t_duration: 1.3
#
# reward: 3.912601085277701, steps: 157 collision reward: -2.5, distance to t_duration: 1.3083333333333333
#
# reward: 3.9372782813998453, steps: 158 collision reward: -2.5, distance to t_duration: 1.3166666666666667
#
# reward: 3.9610508650357636, steps: 159 collision reward: -2.5, distance to t_duration: 1.325
#
# reward: 3.9848822889555926, steps: 160 collision reward: -2.5, distance to t_duration: 1.3333333333333333
#
# reward: 4.0088261148506845, steps: 161 collision reward: -2.1, distance to t_duration: 1.3416666666666666
#
# reward: 4.032929460267518, steps: 162 collision reward: -2.1, distance to t_duration: 1.35
#
# reward: 4.057723400522168, steps: 163 collision reward: -2.1, distance to t_duration: 1.3583333333333334
#
# reward: 4.082723400522167, steps: 164 collision reward: -2.1, distance to t_duration: 1.3666666666666667
#
# reward: 4.1077234005221674, steps: 165 collision reward: -2.1, distance to t_duration: 1.375
#
# reward: 4.132723400522168, steps: 166 collision reward: -2.1, distance to t_duration: 1.3833333333333333
#
# reward: 4.157643407309692, steps: 167 collision reward: -2.1, distance to t_duration: 1.3916666666666666
#
# reward: 4.182522711681921, steps: 168 collision reward: -2.1, distance to t_duration: 1.4
#
# reward: 4.207433932674773, steps: 169 collision reward: -2.1, distance to t_duration: 1.4083333333333334
#
# reward: 4.232372100264287, steps: 170 collision reward: -2.1, distance to t_duration: 1.4166666666666667
#
# reward: 4.2573433697755725, steps: 171 collision reward: -2.1, distance to t_duration: 1.425
#
# reward: 4.2823456171127505, steps: 172 collision reward: -2.1, distance to t_duration: 1.4333333333333333
#
# reward: 4.307374902749641, steps: 173 collision reward: -2.1, distance to t_duration: 1.4416666666666667
#
# reward: 4.332430102756302, steps: 174 collision reward: -2.1, distance to t_duration: 1.45
#
# reward: 4.357507691056734, steps: 175 collision reward: -2.1, distance to t_duration: 1.4583333333333333
#
# reward: 4.382606553016281, steps: 176 collision reward: -2.1, distance to t_duration: 1.4666666666666666
#
# reward: 4.407718363277073, steps: 177 collision reward: -2.1, distance to t_duration: 1.475
#
# reward: 4.434751451785581, steps: 178 collision reward: -2.1, distance to t_duration: 1.4833333333333334
#
# reward: 4.45975145178558, steps: 179 collision reward: -2.1, distance to t_duration: 1.4916666666666667
#
# reward: 4.484751451785581, steps: 180 collision reward: -2.1, distance to t_duration: 1.5
#
# reward: 4.509751451785581, steps: 181 collision reward: -2.1, distance to t_duration: 1.5083333333333333
#
# reward: 4.53675145178558, steps: 182 collision reward: -2.1, distance to t_duration: 1.5166666666666666
#
# reward: 4.561789405181614, steps: 183 collision reward: -2.1, distance to t_duration: 1.525
#
# reward: 4.58696761531609, steps: 184 collision reward: -2.1, distance to t_duration: 1.5333333333333334
#
# reward: 4.612141675121203, steps: 185 collision reward: -2.1, distance to t_duration: 1.5416666666666667
#
# reward: 4.637309519618373, steps: 186 collision reward: -2.1, distance to t_duration: 1.55
#
# reward: 4.662469562313507, steps: 187 collision reward: -2.1, distance to t_duration: 1.5583333333333333
#
# reward: 4.68762058471291, steps: 188 collision reward: -2.1, distance to t_duration: 1.5666666666666667
#
# reward: 4.712760684032138, steps: 189 collision reward: -2.1, distance to t_duration: 1.575
#
# reward: 4.73788913633924, steps: 190 collision reward: -2.1, distance to t_duration: 1.5833333333333333
#
# reward: 4.763005167460232, steps: 191 collision reward: -2.1, distance to t_duration: 1.5916666666666666
#
# reward: 4.788108499153406, steps: 192 collision reward: -2.1, distance to t_duration: 1.6
#
# reward: 4.813197963725849, steps: 193 collision reward: -2.1, distance to t_duration: 1.6083333333333334
#
# reward: 4.8382737454160685, steps: 194 collision reward: -2.1, distance to t_duration: 1.6166666666666667
#
# reward: 4.863334880978911, steps: 195 collision reward: -2.1, distance to t_duration: 1.625
#
# reward: 4.888770355973748, steps: 196 collision reward: -2.1, distance to t_duration: 1.6333333333333333
#
# reward: 4.914320722284914, steps: 197 collision reward: -2.1, distance to t_duration: 1.6416666666666666
#
# reward: 4.9378440007049536, steps: 198 collision reward: -2.1, distance to t_duration: 1.65
#
# reward: 4.963341747548501, steps: 199 collision reward: -2.1, distance to t_duration: 1.6583333333333334
#
# reward: 4.988706188745163, steps: 200 collision reward: -2.1, distance to t_duration: 1.6666666666666667
#
# reward: 5.013802318419219, steps: 201 collision reward: -1.7, distance to t_duration: 1.675
#
# reward: 5.038861055696292, steps: 202 collision reward: -1.7, distance to t_duration: 1.6833333333333333
#
# reward: 5.063883617162081, steps: 203 collision reward: -1.7, distance to t_duration: 1.6916666666666667
#
# reward: 5.088872178861665, steps: 204 collision reward: -1.7, distance to t_duration: 1.7
#
# reward: 5.113829158321842, steps: 205 collision reward: -1.7, distance to t_duration: 1.7083333333333333
#
# reward: 5.138749891472157, steps: 206 collision reward: -1.7, distance to t_duration: 1.7166666666666666
#
# reward: 5.163640026849432, steps: 207 collision reward: -1.7, distance to t_duration: 1.725
#
# reward: 5.188501355214887, steps: 208 collision reward: -1.7, distance to t_duration: 1.7333333333333334
#
# reward: 5.213336447711996, steps: 209 collision reward: -1.7, distance to t_duration: 1.7416666666666667
#
# reward: 5.238146565114758, steps: 210 collision reward: -1.7, distance to t_duration: 1.75
#
# reward: 5.2649650752421255, steps: 211 collision reward: -1.7, distance to t_duration: 1.7583333333333333
#
# reward: 3.5814964873089523, steps: 212 collision reward: -1.7, distance to t_duration: 1.7666666666666666
#
# reward: 3.5990842922807222, steps: 213 collision reward: -1.7, distance to t_duration: 1.775
#
# reward: 3.6214510035096885, steps: 214 collision reward: -1.7, distance to t_duration: 1.7833333333333334
#
# reward: 3.64551548984265, steps: 215 collision reward: -1.7, distance to t_duration: 1.7916666666666667
#
# reward: 3.6701831351723837, steps: 216 collision reward: -1.7, distance to t_duration: 1.8
#
# reward: 3.6950650614009994, steps: 217 collision reward: -1.7, distance to t_duration: 1.8083333333333333
#
# reward: 3.7200231139974096, steps: 218 collision reward: -1.7, distance to t_duration: 1.8166666666666667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aless\OneDrive\Desktop\Thesis_repo_new\HighwayDRL\notebooks\action_testing_notebooks\lateral_action_testing.ipynb Cell 2' in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=11'>12</a> done = False
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=12'>13</a> while not done:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=13'>14</a>     env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=14'>15</a>     env.render()    # with manual control, these actions are ignored
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=16'>17</a> env.close()
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:215, in AbstractEnv.step(self, action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=211'>212</a>     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=213'>214</a> self.steps += 1
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=214'>215</a> self._simulate(action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=216'>217</a> obs = self.observation_type.observe()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=217'>218</a> reward = self._reward(action)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:234, in AbstractEnv._simulate(self, action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=228'>229</a> if action is not None \
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=229'>230</a>         and not self.config["manual_control"] \
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=230'>231</a>         and self.time % int(self.config["simulation_frequency"] // self.config["policy_frequency"]) == 0:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=231'>232</a>     self.action_type.act(action)
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=233'>234</a> self.road.act()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=234'>235</a> self.road.step(1 / self.config["simulation_frequency"])
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=235'>236</a> self.time += 1
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\road\road.py:324, in Road.act(self)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=321'>322</a> """Decide the actions of each entity on the road."""
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=322'>323</a> for vehicle in self.vehicles:
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=323'>324</a>     vehicle.act()
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\vehicle\behavior.py:95, in IDMVehicle.act(self, action)
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=92'>93</a> self.follow_road()
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=93'>94</a> if self.enable_lane_change:
# ---> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=94'>95</a>     self.change_lane_policy()
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=95'>96</a> action['steering'] = self.steering_control(self.target_lane_index)
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=96'>97</a> action['steering'] = np.clip(action['steering'], -self.MAX_STEERING_ANGLE, self.MAX_STEERING_ANGLE)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\vehicle\behavior.py:212, in IDMVehicle.change_lane_policy(self)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=209'>210</a>     continue
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=210'>211</a> # Does the MOBIL model recommend a lane change?
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=211'>212</a> if self.mobil(lane_index):
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=212'>213</a>     self.target_lane_index = lane_index
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\vehicle\behavior.py:229, in IDMVehicle.mobil(self, lane_index)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=226'>227</a> new_preceding, new_following = self.road.neighbour_vehicles(self, lane_index)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=227'>228</a> new_following_a = self.acceleration(ego_vehicle=new_following, front_vehicle=new_preceding)
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=228'>229</a> new_following_pred_a = self.acceleration(ego_vehicle=new_following, front_vehicle=self)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=229'>230</a> if new_following_pred_a < -self.LANE_CHANGE_MAX_BRAKING_IMPOSED:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=230'>231</a>     return False
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\vehicle\behavior.py:151, in IDMVehicle.acceleration(self, ego_vehicle, front_vehicle, rear_vehicle)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=146'>147</a> acceleration = self.COMFORT_ACC_MAX * (
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=147'>148</a>         1 - np.power(max(ego_vehicle.speed, 0) / ego_target_speed, self.DELTA))
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=149'>150</a> if front_vehicle:
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=150'>151</a>     d = ego_vehicle.lane_distance_to(front_vehicle)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=151'>152</a>     acceleration -= self.COMFORT_ACC_MAX * \
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=152'>153</a>         np.power(self.desired_gap(ego_vehicle, front_vehicle) / utils.not_zero(d), 2)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/behavior.py?line=153'>154</a> return acceleration
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\vehicle\objects.py:164, in RoadObject.lane_distance_to(self, other, lane)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/objects.py?line=161'>162</a> if not lane:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/objects.py?line=162'>163</a>     lane = self.lane
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/objects.py?line=163'>164</a> return lane.local_coordinates(other.position)[0] - lane.local_coordinates(self.position)[0]
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\road\lane.py:185, in StraightLane.local_coordinates(self, position)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/lane.py?line=182'>183</a> def local_coordinates(self, position: np.ndarray) -> Tuple[float, float]:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/lane.py?line=183'>184</a>     delta = position - self.start
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/lane.py?line=184'>185</a>     longitudinal = np.dot(delta, self.direction)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/lane.py?line=185'>186</a>     lateral = np.dot(delta, self.direction_lateral)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/lane.py?line=186'>187</a>     return float(longitudinal), float(lateral)
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
