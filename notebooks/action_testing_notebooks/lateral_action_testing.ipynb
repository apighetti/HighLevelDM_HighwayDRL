# %%
# %pip install .
# Out:
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the '/Users/fornerispighetti/HighwayDRL/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import gym
import highway_env
import time

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width": 1250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored

env.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb Cell 2' in <cell line: 13>()
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=11'>12</a> done = False
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=12'>13</a> while not done:
# ---> <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=13'>14</a>     env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=14'>15</a>     env.render()    # with manual control, these actions are ignored
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=16'>17</a> env.close()
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=8'>9</a> def step(self, action):
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=9'>10</a>     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=10'>11</a>     observation, reward, done, info = self.env.step(action)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=11'>12</a>     return observation, reward, done, info
#
# File ~/HighwayDRL/highway_env/envs/common/abstract.py:218, in AbstractEnv.step(self, action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=214'>215</a> self._simulate(action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=216'>217</a> obs = self.observation_type.observe()
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=217'>218</a> reward = self._reward(action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=218'>219</a> terminal = self._is_terminal()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/common/abstract.py?line=219'>220</a> info = self._info(obs, action)
#
# File ~/HighwayDRL/highway_env/envs/dm_env.py:185, in DecisionMakingEnv._reward(self, action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=178'>179</a> collision_index = int(utils.lmap(abs(self.steps - self.config['duration']), [0,self.config['duration']], [3,0]))
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=180'>181</a> # Use forward speed rather than speed, see https://github.com/eleurent/highway-env/issues/268
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=181'>182</a> # forward_speed = self.vehicle.speed * np.cos(self.vehicle.heading)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=182'>183</a> # scaled_speed = utils.lmap(forward_speed, self.config["reward_speed_range"], [0, 1])
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=184'>185</a> reward = COL_REWARDS[collision_index] * self.vehicle.crashed \
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=185'>186</a>     + self.config["distance_to_tv_reward"] * speed_diff \
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=186'>187</a>     + self.config["not_in_right_lane_reward"] * (1 - (lane / max(len(neighbours) - 1, 1))) \
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=187'>188</a>     + self.config["distance_reward"] * km_travelled
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=188'>189</a>   # + self.config["high_speed_reward"] * np.clip(scaled_speed, 0, 1)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=189'>190</a>
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=190'>191</a> # reward = utils.lmap(reward,
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=191'>192</a> #                   [self.config["distance_to_tv_reward"],
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=192'>193</a> #                    self.config["not_in_right_lane_reward"]],
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=193'>194</a> #                   [0, 1])
#     <a href='file:///Users/fornerispighetti/HighwayDRL/highway_env/envs/dm_env.py?line=195'>196</a> reward = 0 if not self.vehicle.on_road else reward
#
# IndexError: list index out of range
