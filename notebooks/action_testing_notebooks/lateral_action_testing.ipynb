# %%
import gym
import highway_env
import time

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width":1500,
    "screen_height":250
    
})

env.reset()
done = False
while not done:
    observation, reward, done, info = env.step(env.action_space.sample())
    env.render()
    
    # if env.controlled_vehicles[0].lane_index[2]>0:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]-1)
    #     front_vehicle , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed
    #             overtake_gap = env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1

    # if env.controlled_vehicles[0].lane_index[2] + 1 < env.config["lanes_count"]:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]+1)
    #     _ , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap =  env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1
    # print(f"current overtakes: {overtake}")

env.close()
    # print(f"overall overtakes: {overtake}")
# Out:
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.06550325334262486,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.03100650668524973
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.12530002429602688,
# dense rewards:
# 	rml reward: 0.2,
# 	high speed reward: 0.05060004859205378
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.12530002429602688,
# dense rewards:
# 	rml reward: 0.2,
# 	high speed reward: 0.05060004859205378
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.09999999999999998,
# dense rewards:
# 	rml reward: 0.2,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.18011496477153935,
# dense rewards:
# 	rml reward: 0.2,
# 	high speed reward: 0.16022992954307871
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2292252692876708,
# dense rewards:
# 	rml reward: 0.2,
# 	high speed reward: 0.25845053857534167
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2582177834134417,
# dense rewards:
# 	rml reward: 0.2,
# 	high speed reward: 0.3164355668268835
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2753336592691276,
# dense rewards:
# 	rml reward: 0.2,
# 	high speed reward: 0.35066731853825533
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.23541945703947295,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.3708389140789459
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2413923034705348,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.3827846069410697
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2449184032622137,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.38983680652442754
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.24700005392649657,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.39400010785299316
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2482289668172583,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.39645793363451676
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.24895446169447027,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.3979089233889406
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2493827612271848,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.39876552245436964
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.24963561000046441,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.3992712200009289
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2497848805395747,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.39956976107914954
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.24987300314961253,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.39974600629922513
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2499250267736054,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.3998500535472109
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2499557391804688,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.39991147836093766
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.2499738704036123,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.3999477408072247
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.14386239581632596,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.187724791632652
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04999999999999999,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-859b1cb97679> in <module>
#      14 done = False
#      15 while not done:
# ---> 16     observation, reward, done, info = env.step(env.action_space.sample())
#      17     env.render()
#      18
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\gym\wrappers\order_enforcing.py in step(self, action)
#       9     def step(self, action):
#      10         assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11         observation, reward, done, info = self.env.step(action)
#      12         return observation, reward, done, info
#      13
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in step(self, action)
#     214
#     215         self.steps += 1
# --> 216         self._simulate(action)
#     217
#     218         obs = self.observation_type.observe()
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in _simulate(self, action)
#     240             # Ignored if the rendering is done offscreen
#     241             if frame < frames - 1:  # Last frame will be rendered through env.render() as usual
# --> 242                 self._automatic_rendering()
#     243
#     244         self.enable_auto_render = False
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in _automatic_rendering(self)
#     321                 self._monitor.video_recorder.capture_frame()
#     322             else:
# --> 323                 self.render(self.rendering_mode)
#     324
#     325     def simplify(self) -> 'AbstractEnv':
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in render(self, mode)
#     258         self.enable_auto_render = True
#     259
# --> 260         self.viewer.display()
#     261
#     262         if not self.viewer.offscreen:
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\graphics.py in display(self)
#     127             offscreen=self.offscreen)
#     128
# --> 129         ObservationGraphics.display(self.env.observation_type, self.sim_surface)
#     130
#     131         if not self.offscreen:
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\graphics.py in display(cls, obs, sim_surface)
#     237             cls.display_grid(obs, sim_surface)
#     238         else: # Display vehicle speeds for testing purposes
# --> 239             myFont = pygame.font.SysFont("Arial", 18)
#     240
#     241             egoDisplay = myFont.render("Ego vehicle speed: "+str(round(obs.observer_vehicle.speed*3.6, 2))+" km/h", 1, (255, 255, 255))
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pygame\sysfont.py in SysFont(name, size, bold, italic, constructor)
#     472         set_italic = True
#     473
# --> 474     return constructor(fontname, size, set_bold, set_italic)
#     475
#     476
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pygame\sysfont.py in font_constructor(fontpath, size, bold, italic)
#     389     """
#     390
# --> 391     font = Font(fontpath, size)
#     392     if bold:
#     393         font.set_bold(True)
#
# KeyboardInterrupt:
