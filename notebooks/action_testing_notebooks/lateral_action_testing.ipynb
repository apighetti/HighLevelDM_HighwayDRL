# %%
import gym
import highway_env
import time

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width":1500,
    "screen_height":250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored

env.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\aless\OneDrive\Desktop\Thesis_repo_new\HighwayDRL\notebooks\action_testing_notebooks\lateral_action_testing.ipynb Cell 1' in <cell line: 14>()
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000000?line=12'>13</a> done = False
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000000?line=13'>14</a> while not done:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000000?line=14'>15</a>     env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000000?line=15'>16</a>     env.render()    # with manual control, these actions are ignored
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/notebooks/action_testing_notebooks/lateral_action_testing.ipynb#ch0000000?line=17'>18</a> env.close()
#
# File c:\Users\aless\anaconda3\lib\site-packages\gym\wrappers\order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       9 def step(self, action):
#      10     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11     observation, reward, done, info = self.env.step(action)
#      12     return observation, reward, done, info
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:218, in AbstractEnv.step(self, action)
#     215 self._simulate(action)
#     217 obs = self.observation_type.observe()
# --> 218 reward = self._reward(action)
#     219 terminal = self._is_terminal()
#     220 info = self._info(obs, action)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\dm_env.py:238, in DecisionMakingEnv._reward(self, action)
#     230     # + self.config["distance_to_tv_reward"] * speed_diff \
#     231     # + self.config["distance_reward"] * km_travelled
#     232     # + self.config["distance_to_tv_reward"] * speed_diff \
#     234 reward = utils.lmap(reward,
#     235                   [self.config["not_in_right_lane_reward"],
#     236                    self.config["high_speed_reward"]],
#     237                   [0, 1])
# --> 238 reward += COL_REWARDS[collision_index] * self.vehicle.crashed
#     239 reward = 0 if not self.vehicle.on_road else reward
#     240 # print(f"\nreward: {reward}, \ndense rewards:\n\ttarget velocity reward: {self.config['distance_to_tv_reward'] * speed_diff},\n\tnot in RL reward:{self.config['not_in_right_lane_reward'] * (1 - (lane / max(len(neighbours) - 1, 1)))},\n\tduration reward: {self.config['distance_reward'] * km_travelled} \
#     241 #     \nsparse rewards:\n\tcollision reward: {COL_REWARDS[collision_index]}")
#     242
#     243 # print(f"\nmapped overall reward: {reward}, \ndense rewards:\n\tnot in RL reward:{self.config['not_in_right_lane_reward'] * (1 - (lane / max(len(neighbours) - 1, 1)))}, \n\thigh speed reward: {self.config['high_speed_reward']}\
#     244 #     \nsparse rewards:\n\tcollision reward: {self.config['collision_reward']}")
#
# IndexError: list index out of range
