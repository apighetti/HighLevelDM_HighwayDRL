# -0.0 35.99999216235198
# -0.0 35.99999387124953
# -0.0 35.999995207544124
# -0.0 35.999996252477004
# -0.0 35.99999706957581
# -0.0 35.99999770851681
# -0.0 35.99999820814501
# -0.0 35.99999859883576
# -0.0 35.99999890434147
# -0.0 35.999999143235605
# -0.0 35.99999933004198
# -0.0 35.999999476117644
# -0.0 35.99999959034339
# -0.0 35.99999967966371
# -0.0 35.999999749508895
# -0.0 35.999999804125224
# -0.0 35.99999984683318
# -0.0 35.99999988022922
# -0.0 35.99999990634369
# -0.0 35.99999992676423
# -0.0 35.99999994273234
# -0.0 35.999999955218804
# -0.0 35.99999996498277
# -0.0 35.99999997261782
# -0.0 35.99999997858816
# -0.0 35.99999998325672
# -0.0 35.999999986907376
# -0.0 35.99999998976205
# -0.0 35.999999991994315
# -0.0 35.99999999373985
# -0.0 35.99999999510479
# -0.0 35.99999999617213
# -0.0 35.999999997006746
# -0.0 35.99999999765938
# -0.0 35.99999999816971
# -0.0 35.99999999856878
# -0.0 35.99999999888084
# -0.0 35.99999999912485
# -0.0 35.99999999931567
# -0.0 35.999999999464876
# -0.0 35.99999999958155
# -0.0 35.99999999967279
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f3001d4c6f6a> in <module>
#      15
#      16 while not done:
# ---> 17     env.step(env.action_space.sample())
#      18     env.render()
#      19
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\gym\wrappers\order_enforcing.py in step(self, action)
#       9     def step(self, action):
#      10         assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11         observation, reward, done, info = self.env.step(action)
#      12         return observation, reward, done, info
#      13
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in step(self, action)
#     216         self._simulate(action)
#     217
# --> 218         obs = self.observation_type.observe()
#     219         reward = self._reward(action)
#     220         terminal = self._is_terminal()
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\observation.py in observe(self)
#     204
#     205         # Add ego-vehicle
# --> 206         df = pd.DataFrame.from_records([self.observer_vehicle.to_dict()])[self.features]
#     207         # Add nearby traffic
#     208         close_vehicles = self.env.road.close_vehicles_to(self.observer_vehicle,
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3468             indexer = np.where(indexer)[0]
#    3469
# -> 3470         data = self._take_with_is_copy(indexer, axis=1)
#    3471
#    3472         if is_single_key:
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3626         See the docstring of `take` for full explanation of the parameters.
#    3627         """
# -> 3628         result = self.take(indices=indices, axis=axis)
#    3629         # Maybe set copy if we didn't actually change the index.
#    3630         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3613         self._consolidate_inplace()
#    3614
# -> 3615         new_data = self._mgr.take(
#    3616             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3617         )
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify)
#     863
#     864         new_labels = self.axes[axis].take(indexer)
# --> 865         return self.reindex_indexer(
#     866             new_axis=new_labels,
#     867             indexer=indexer,
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     674
#     675         if axis == 0:
# --> 676             new_blocks = self._slice_take_blocks_ax0(
#     677                 indexer, fill_value=fill_value, only_slice=only_slice
#     678             )
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice)
#     765         else:
#     766             blknos = algos.take_nd(
# --> 767                 self.blknos, slobj, fill_value=-1, allow_fill=allow_fill
#     768             )
#     769             blklocs = algos.take_nd(
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pandas\core\internals\managers.py in blknos(self)
#     168         if self._blknos is None:
#     169             # Note: these can be altered by other BlockManager methods.
# --> 170             self._rebuild_blknos_and_blklocs()
#     171
#     172         return self._blknos
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     234             rl = blk.mgr_locs
#     235             new_blknos[rl.indexer] = blkno
# --> 236             new_blklocs[rl.indexer] = np.arange(len(rl))
#     237
#     238         if (new_blknos == -1).any():
#
# KeyboardInterrupt:
