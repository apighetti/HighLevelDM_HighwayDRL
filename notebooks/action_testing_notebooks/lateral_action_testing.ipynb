# %%
import gym
import highway_env
import time

env = gym.make('multipleO-dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width":1500,
    "screen_height":250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()
    
    # if env.controlled_vehicles[0].lane_index[2]>0:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]-1)
    #     front_vehicle , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap = env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1

    # if env.controlled_vehicles[0].lane_index[2] + 1 < env.config["lanes_count"]:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]+1)
    #     _ , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap =  env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1
    # print(f"current overtakes: {overtake}")

env.close()
    # print(f"overall overtakes: {overtake}")
# Out:
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3333333333333333,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.0
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.09662452749563696,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.05797471649738219
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.3301394537804564,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.19808367226827386
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.46799614182793103,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.2807976850967587
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.5493805277491669,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3296283166495002
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.5974262074020381,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3584557244412229
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.625790214910086,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3754741289460517
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6425350487375866,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.38552102924255205
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.652420445215184,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3914522671291105
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6582563385137377,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39495380310824263
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6617015873380288,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3970209524028173
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6637355072289588,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39824130433737537
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.664936242018725,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39896174521123506
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6656451018129496,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3993870610877698
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6660635807411428,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39963814844468576
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6663106318713805,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3997863791228284
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6664564797428987,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3998738878457393
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6665425817639882,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39992554905839295
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6665934125231803,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39995604751390823
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666234207163373,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39997405242980244
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666411362033938,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999846817220364
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.666651594629864,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999095677791846
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.666657768814287,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999466128857225
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666614137749707,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999968482649825
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666635655957572,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999981393574544
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666648359339307,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999890156035844
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666655858844308,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999993515306585
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.666666028621462,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999961717287724
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666662899934863,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999997739960918
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666664442957695,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999998665774617
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.666666535388894,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999992123333644
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666665891661764,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999534997059
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666209138645,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999997254831876
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666396562695,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999837937618
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666507209437,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999043256623
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666572530285,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999435181716
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666611092782,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999666556696
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666633858358,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999803150155
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666647298124,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999988378875
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666655232344,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999993139407
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666659916353,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999995949812
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666662681578,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999997608948
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.666666666431405,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999998588431
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666665277784,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999991666707
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666665846723,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999508035
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666182612,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999709568
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666380902,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999828541
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666497959,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999898776
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666567072,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999999402436
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666607872,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999964724
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666631952,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999979172
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666646195,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999987717
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666654587,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999999927527
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666659536,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999999957225
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.666666666666245,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999999974706
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.666666666666417,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999998503
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666665197,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999999119
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666665798,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999999994795
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666666153,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999999996927
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666666358,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999999998154
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666666476,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.39999999999998864
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666666556,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666666556,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666666556,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666666556,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.6666666666666556,
# dense rewards:
# 	rml reward: 0.0, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9694418652636763,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3816651191582059
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9996291460270318,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.39977748761621923
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999994803849116,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.399999688230947
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.999999999998905,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.399999999999343
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999972666,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999983601
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.99999999999998,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.39999999999998814
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
#
# reward: 0.9999999999999889,
# dense rewards:
# 	rml reward: 0.2, high speed rew: 0.3999999999999934
# sparse rewards:
# 	collision reward: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8175cd6df2ed> in <module>
#      13 done = False
#      14 while not done:
# ---> 15     env.step(env.action_space.sample())
#      16     env.render()
#      17
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\gym\wrappers\order_enforcing.py in step(self, action)
#       9     def step(self, action):
#      10         assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11         observation, reward, done, info = self.env.step(action)
#      12         return observation, reward, done, info
#      13
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in step(self, action)
#     217
#     218         obs = self.observation_type.observe()
# --> 219         reward = self._reward(action)
#     220         terminal = self._is_terminal()
#     221         info = self._info(obs, action)
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\multipleO_dm_env.py in _reward(self, action)
#     214             reward += self.collision_reward
#     215
# --> 216         print(f"\nreward: {reward}, \ndense rewards:\n\trml reward: {self.rml_reward}, high speed rew: {self.high_speed_reward}\
#     217             \nsparse rewards:\n\tcollision reward: {self.collision_reward}")
#     218         reward = 0 if not self.vehicle.on_road else reward
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
