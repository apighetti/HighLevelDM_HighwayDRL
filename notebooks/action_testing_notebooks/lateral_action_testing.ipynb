# %%
import gym
import highway_env
import time

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width":1500,
    "screen_height":250
})

env.reset()
done = False
while not done:
    observation, reward, done, info = env.step(env.action_space.sample())
    print(observation.shape)
    env.render()
    
    # if env.controlled_vehicles[0].lane_index[2]>0:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]-1)
    #     front_vehicle , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap = env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1

    # if env.controlled_vehicles[0].lane_index[2] + 1 < env.config["lanes_count"]:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]+1)
    #     _ , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap =  env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1
    # print(f"current overtakes: {overtake}")

env.close()
    # print(f"overall overtakes: {overtake}")
# Out:
# (25,)
# (25,)
# (25,)
# (25,)
# (25,)
# (25,)
# (25,)
# (25,)
# (25,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-737a70b19d32> in <module>
#      13 done = False
#      14 while not done:
# ---> 15     observation, reward, done, info = env.step(env.action_space.sample())
#      16     print(observation.shape)
#      17     env.render()
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\gym\wrappers\order_enforcing.py in step(self, action)
#       9     def step(self, action):
#      10         assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11         observation, reward, done, info = self.env.step(action)
#      12         return observation, reward, done, info
#      13
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in step(self, action)
#     214
#     215         self.steps += 1
# --> 216         self._simulate(action)
#     217
#     218         obs = self.observation_type.observe()
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in _simulate(self, action)
#     234
#     235             self.road.act()
# --> 236             self.road.step(1 / self.config["simulation_frequency"])
#     237             self.time += 1
#     238
#
# c:\users\pigo\desktop\highwaydrl\highway_env\road\road.py in step(self, dt)
#     334         for i, vehicle in enumerate(self.vehicles):
#     335             for other in self.vehicles[i+1:]:
# --> 336                 vehicle.handle_collisions(other, dt)
#     337             for other in self.objects:
#     338                 vehicle.handle_collisions(other, dt)
#
# c:\users\pigo\desktop\highwaydrl\highway_env\vehicle\objects.py in handle_collisions(self, other, dt)
#      80         if not (self.collidable and other.collidable):
#      81             return
# ---> 82         intersecting, will_intersect, transition = self._is_colliding(other, dt)
#      83         if will_intersect:
#      84             if self.solid and other.solid:
#
# c:\users\pigo\desktop\highwaydrl\highway_env\vehicle\objects.py in _is_colliding(self, other, dt)
#     101     def _is_colliding(self, other, dt):
#     102         # Fast spherical pre-check
# --> 103         if np.linalg.norm(other.position - self.position) > self.diagonal + self.speed * dt:
#     104             return False, False, np.zeros(2,)
#     105         # Accurate rectangular check
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2528                 sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2529             else:
# -> 2530                 sqnorm = dot(x, x)
#    2531             ret = sqrt(sqnorm)
#    2532             if keepdims:
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
