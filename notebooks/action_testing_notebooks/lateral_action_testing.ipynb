# %%
import gym
import highway_env
import time

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width":1500,
    "screen_height":250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    print(env.vehicle.position)
    env.render()
    
    # if env.controlled_vehicles[0].lane_index[2]>0:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]-1)
    #     front_vehicle , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap = env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1

    # if env.controlled_vehicles[0].lane_index[2] + 1 < env.config["lanes_count"]:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]+1)
    #     _ , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap =  env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1
    # print(f"current overtakes: {overtake}")

env.close()
    # print(f"overall overtakes: {overtake}")
# Out:
# /home/utente1/anaconda3/envs/RLenv/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment __root__/HandManipulateBlockRotateZ-v1
#   logger.warn("Overriding environment {}".format(id))
# /home/utente1/anaconda3/envs/RLenv/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment __root__/HandManipulateBlockRotateZDense-v1
#   logger.warn("Overriding environment {}".format(id))
# [128.44172558   8.        ]
# [153.30473689   8.        ]
# [178.11745501   8.        ]
# [202.89992766   8.        ]
# [227.6642112   8.       ]
# [251.79628482   8.        ]
# [271.54945404   8.        ]
# [286.35668506   8.        ]
# [298.80383418   8.        ]
# [311.90020878   8.        ]
# [326.41183591   8.        ]
# [342.58492236   8.        ]
# [360.30327034   8.        ]
# [379.22825401   8.        ]
# [398.92930319   8.        ]
# [418.98699546   8.        ]
# [438.99542584   8.        ]
# [458.58012139   8.        ]
# [477.74941981   8.        ]
# [496.62895467   7.69869751]
# [517.84490409   4.46795311]
# [544.04908634   4.02751526]
# [572.21297712   4.00113578]
# [599.35281188   4.00004775]
# [623.482859     4.00000314]
# [645.63118181   1.6563668 ]
# [6.71993718e+02 1.21714229e-01]
# [7.02305644e+02 4.12498623e-03]
# [ 7.34947892e+02 -1.57283038e-05]
# [ 7.68421243e+02 -1.01151510e-05]
# [ 7.98578920e+02 -7.86184796e-07]
# [ 8.23795224e+02 -6.27184689e-08]
# [ 8.45103610e+02 -6.14319245e-09]
# [ 8.64372816e+02 -6.70060138e-10]
# [ 8.82882234e+02 -7.55949632e-11]
# [ 9.01259516e+02 -8.53510792e-12]
# [ 9.19681243e+02 -9.58133595e-13]
# [937.84989008   2.7390633 ]
# [956.29944146   3.85167373]
# [974.79292543   3.98335574]
# [993.28704171   3.99813856]
# [1011.47536679    6.55622969]
# [1029.9781758     7.82962831]
# [1051.8047966    7.9861672]
# [1078.55952771    7.99935027]
# [1109.0682729     7.99998906]
# [1141.01568492    8.0000007 ]
# [1170.45136124    8.00000008]
# [1195.61574182    7.15504559]
# [1222.45710133    4.30994238]
# [1253.14597343    4.01262849]
# [1286.0119169     4.00008542]
# [1.31997470e+03 7.88147616e-01]
# [1.35435437e+03 3.98275223e-02]
# [ 1.37209158e+03 -3.05568213e-02]
# [ 1.37836174e+03 -5.91605341e-02]
# [ 1.38058931e+03 -6.93224140e-02]
# [ 1.38138068e+03 -7.29325678e-02]
# [ 1.38166183e+03 -7.42151268e-02]
# [ 1.38176171e+03 -7.46707744e-02]
# [ 1.38179719e+03 -7.48326497e-02]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 15
#      13 done = False
#      14 while not done:
# ---> 15     env.step(env.action_space.sample())
#      16     print(env.vehicle.position)
#      17     env.render()
#
# File ~/anaconda3/envs/RLenv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       9 def step(self, action):
#      10     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11     observation, reward, done, info = self.env.step(action)
#      12     return observation, reward, done, info
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/envs/common/abstract.py:216, in AbstractEnv.step(self, action)
#     213     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     215 self.steps += 1
# --> 216 self._simulate(action)
#     218 obs = self.observation_type.observe()
#     219 reward = self._reward(action)
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/envs/common/abstract.py:235, in AbstractEnv._simulate(self, action)
#     230 if action is not None \
#     231         and not self.config["manual_control"] \
#     232         and self.time % int(self.config["simulation_frequency"] // self.config["policy_frequency"]) == 0:
#     233     self.action_type.act(action)
# --> 235 self.road.act()
#     236 self.road.step(1 / self.config["simulation_frequency"])
#     237 self.time += 1
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/road/road.py:324, in Road.act(self)
#     322 """Decide the actions of each entity on the road."""
#     323 for vehicle in self.vehicles:
# --> 324     vehicle.act()
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/vehicle/controller.py:421, in DecisionMakingVehicle.act(self, action)
#     419         self.current_action = "RML"
#     420 else:
# --> 421     super().act(action)
#     422     return
#     423 super().act()
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/vehicle/controller.py:261, in MDPVehicle.act(self, action)
#     259     self.speed_index = self.speed_to_index(self.speed) - 5
#     260 else:
# --> 261     super().act(action)
#     263 self.speed_index = int(np.clip(self.speed_index, 0, self.target_speeds.size - 1))
#     264 self.target_speed = self.index_to_speed(self.speed_index)
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/vehicle/controller.py:112, in ControlledVehicle.act(self, action)
#     108         self.target_lane_index = target_lane_index
#     110 if self.phy_action:
#     111     action = self.phy_action if action == "ACC" else \
# --> 112         {"steering": self.steering_control(self.target_lane_index),
#     113           "acceleration": self.phy_action["acceleration"]}     # our defined action
#     114     # print(f"phy_action output: {action}")
#     115 else:
#     116     action = {"steering": self.steering_control(self.target_lane_index),
#     117           "acceleration": self.speed_control(self.target_speed)}
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/vehicle/controller.py:157, in ControlledVehicle.steering_control(self, target_lane_index)
#     155 slip_angle = np.arcsin(np.clip(self.LENGTH / 2 / utils.not_zero(self.speed) * heading_rate_command, -1, 1))
#     156 steering_angle = np.arctan(2 * np.tan(slip_angle))
# --> 157 steering_angle = np.clip(steering_angle, -self.MAX_STEERING_ANGLE, self.MAX_STEERING_ANGLE)
#     158 return float(steering_angle)
#
# File <__array_function__ internals>:180, in clip(*args, **kwargs)
#
# File ~/anaconda3/envs/RLenv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2152, in clip(a, a_min, a_max, out, **kwargs)
#    2083 @array_function_dispatch(_clip_dispatcher)
#    2084 def clip(a, a_min, a_max, out=None, **kwargs):
#    2085     """
#    2086     Clip (limit) the values in an array.
#    2087
#    (...)
#    2150
#    2151     """
# -> 2152     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File ~/anaconda3/envs/RLenv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# File ~/anaconda3/envs/RLenv/lib/python3.8/site-packages/numpy/core/_methods.py:137, in _clip(a, min, max, out, casting, **kwargs)
#     135     min = -float('inf')
#     136     using_deprecated_nan = True
# --> 137 if _clip_dep_is_scalar_nan(max):
#     138     max = float('inf')
#     139     using_deprecated_nan = True
#
# File ~/anaconda3/envs/RLenv/lib/python3.8/site-packages/numpy/core/_methods.py:93, in _clip_dep_is_scalar_nan(a)
#      91 def _clip_dep_is_scalar_nan(a):
#      92     # guarded to protect circular imports
# ---> 93     from numpy.core.fromnumeric import ndim
#      94     if ndim(a) != 0:
#      95         return False
#
# KeyboardInterrupt:
