# %%
import gym
import highway_env
import time

env = gym.make('multipleO-dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width":1500,
    "screen_height":250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()
    
    # if env.controlled_vehicles[0].lane_index[2]>0:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]-1)
    #     front_vehicle , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap = env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1

    # if env.controlled_vehicles[0].lane_index[2] + 1 < env.config["lanes_count"]:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]+1)
    #     _ , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap =  env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1
    # print(f"current overtakes: {overtake}")

env.close()
    # print(f"overall overtakes: {overtake}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8175cd6df2ed> in <module>
#      14 while not done:
#      15     env.step(env.action_space.sample())
# ---> 16     env.render()
#      17
#      18     # if env.controlled_vehicles[0].lane_index[2]>0:
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in render(self, mode)
#     258         self.enable_auto_render = True
#     259
# --> 260         self.viewer.display()
#     261
#     262         if not self.viewer.offscreen:
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\graphics.py in display(self)
#      99
#     100         self.sim_surface.move_display_window_to(self.window_position())
# --> 101         RoadGraphics.display(self.env.road, self.sim_surface)
#     102
#     103         if self.vehicle_trajectory:
#
# c:\users\pigo\desktop\highwaydrl\highway_env\road\graphics.py in display(road, surface)
#     239             for _to in road.network.graph[_from].keys():
#     240                 for l in road.network.graph[_from][_to]:
# --> 241                     LaneGraphics.display(l, surface)
#     242
#     243     @staticmethod
#
# c:\users\pigo\desktop\highwaydrl\highway_env\road\graphics.py in display(cls, lane, surface)
#     124         """
#     125         stripes_count = int(2 * (surface.get_height() + surface.get_width()) / (cls.STRIPE_SPACING * surface.scaling))
# --> 126         s_origin, _ = lane.local_coordinates(surface.origin)
#     127         s0 = (int(s_origin) // cls.STRIPE_SPACING - stripes_count // 2) * cls.STRIPE_SPACING
#     128         for side in range(2):
#
# c:\users\pigo\desktop\highwaydrl\highway_env\road\lane.py in local_coordinates(self, position)
#     184         delta = position - self.start
#     185         longitudinal = np.dot(delta, self.direction)
# --> 186         lateral = np.dot(delta, self.direction_lateral)
#     187         return float(longitudinal), float(lateral)
#     188
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
