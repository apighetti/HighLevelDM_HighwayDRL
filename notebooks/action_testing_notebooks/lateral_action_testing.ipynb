# %%
import gym
import highway_env
import time

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width":1500,
    "screen_height":250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()
    
    # if env.controlled_vehicles[0].lane_index[2]>0:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]-1)
    #     front_vehicle , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap = env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1

    # if env.controlled_vehicles[0].lane_index[2] + 1 < env.config["lanes_count"]:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]+1)
    #     _ , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap =  env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1
    # print(f"current overtakes: {overtake}")

env.close()
    # print(f"overall overtakes: {overtake}")
# Out:
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.010000000000000002,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.023484307511853333,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.11742153755926665
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04182842933154367,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.20914214665771833
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0187415256622252,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.043707628311126005
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.021264212296127075,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.05632106148063537
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.021582836881368576,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.05791418440684287
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.02158412364040364,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.05792061820201819
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.03643281981976392,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.13216409909881957
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.05837634701452696,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.24188173507263477
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.07133081814655384,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.3066540907327692
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0736595727543921,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.3182978637719605
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.07496165896586245,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.2748082948293122
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.07625040984389123,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.28125204921945607
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.058479585745627484,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.19239792872813744
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.0,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020393744592303736,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.10196872296151867
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.04481125945560582,
# dense rewards:
# 	rml reward: 0.0,
# 	high speed reward: 0.22405629727802912
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.05683783543837867,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.23418917719189333
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.06065063533340729,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.25325317666703645
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.060700179193875575,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.25350089596937786
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.060700274075056015,
# dense rewards:
# 	rml reward: 0.05,
# 	high speed reward: 0.2535013703752801
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.06635575685906361,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.23177878429531804
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: 0.020000000000000004,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: 0,
# 	2:  0
#
# reward: -0.98,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: -1,
# 	2:  -1
#
# reward: -0.98,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: -1,
# 	2:  -1
#
# reward: -0.98,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: -1,
# 	2:  -1
#
# reward: -0.98,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: -1,
# 	2:  -1
#
# reward: -0.98,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: -1,
# 	2:  -1
#
# reward: -0.98,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: -1,
# 	2:  -1
#
# reward: -0.98,
# dense rewards:
# 	rml reward: 0.1,
# 	high speed reward: 0.0
# sparse rewards:
# 	collision reward 1: -1,
# 	2:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1614de795133> in <module>
#      13 done = False
#      14 while not done:
# ---> 15     env.step(env.action_space.sample())
#      16     env.render()
#      17
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\gym\wrappers\order_enforcing.py in step(self, action)
#       9     def step(self, action):
#      10         assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11         observation, reward, done, info = self.env.step(action)
#      12         return observation, reward, done, info
#      13
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in step(self, action)
#     217
#     218         obs = self.observation_type.observe()
# --> 219         reward = self._reward(action)
#     220         terminal = self._is_terminal()
#     221         info = self._info(obs, action)
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\dm_env.py in _reward(self, action)
#     193             #     + self.collision_reward
#     194
# --> 195         print(f"\nreward: {reward}, \ndense rewards:\n\trml reward: {self.rml_reward},\n\thigh speed reward: {self.high_speed_reward}\
#     196             \nsparse rewards:\n\tcollision reward 1: {self.collision_reward}, \n\t2: ", self.config["collision_reward"] * self.vehicle.crashed)
#     197
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
