# %%
import gym
import highway_env
import time

env = gym.make('jam-dm-env-v0')
env.configure({
    "manual_control": True,
    "screen_width":1500,
    "screen_height":250
})

env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()
    
    # if env.controlled_vehicles[0].lane_index[2]>0:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]-1)
    #     front_vehicle , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap = env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1

    # if env.controlled_vehicles[0].lane_index[2] + 1 < env.config["lanes_count"]:
    #     l_i = (env.controlled_vehicles[0].lane_index[0], env.controlled_vehicles[0].lane_index[1], env.controlled_vehicles[0].lane_index[2]+1)
    #     _ , rear_vehicle = env.road.neighbour_vehicles(env.controlled_vehicles[0], l_i)
        
    #     if rear_vehicle is not None:
    #         if env.controlled_vehicles[0].speed > rear_vehicle.speed:
    #             overtake_gap =  env.controlled_vehicles[0].position[0] - rear_vehicle.position[0]
    #             if overtake_gap < 25:
    #                 overtake += 1
    # print(f"current overtakes: {overtake}")

env.close()
    # print(f"overall overtakes: {overtake}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-80485ec73321> in <module>
#      13 done = False
#      14 while not done:
# ---> 15     env.step(env.action_space.sample())
#      16     env.render()
#      17
#
# c:\Users\pigo\miniconda3\envs\highway\lib\site-packages\gym\wrappers\order_enforcing.py in step(self, action)
#       9     def step(self, action):
#      10         assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11         observation, reward, done, info = self.env.step(action)
#      12         return observation, reward, done, info
#      13
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in step(self, action)
#     214
#     215         self.steps += 1
# --> 216         self._simulate(action)
#     217
#     218         obs = self.observation_type.observe()
#
# c:\users\pigo\desktop\highwaydrl\highway_env\envs\common\abstract.py in _simulate(self, action)
#     233                 self.action_type.act(action)
#     234
# --> 235             self.road.act()
#     236             self.road.step(1 / self.config["simulation_frequency"])
#     237             self.time += 1
#
# c:\users\pigo\desktop\highwaydrl\highway_env\road\road.py in act(self)
#     322         """Decide the actions of each entity on the road."""
#     323         for vehicle in self.vehicles:
# --> 324             vehicle.act()
#     325
#     326     def step(self, dt: float) -> None:
#
# c:\users\pigo\desktop\highwaydrl\highway_env\vehicle\behavior.py in act(self, action)
#     100
#     101         # Longitudinal: IDM
# --> 102         front_vehicle, rear_vehicle = self.road.neighbour_vehicles(self, self.lane_index)
#     103         action['acceleration'] = self.acceleration(ego_vehicle=self,
#     104                                                    front_vehicle=front_vehicle,
#
# c:\users\pigo\desktop\highwaydrl\highway_env\road\road.py in neighbour_vehicles(self, vehicle, lane_index)
#     359             if v is not vehicle and not isinstance(v, Landmark):  # self.network.is_connected_road(v.lane_index,
#     360                 # lane_index, same_lane=True):
# --> 361                 s_v, lat_v = lane.local_coordinates(v.position)
#     362                 if not lane.on_lane(v.position, s_v, lat_v, margin=1):
#     363                     continue
#
# c:\users\pigo\desktop\highwaydrl\highway_env\road\lane.py in local_coordinates(self, position)
#     184         delta = position - self.start
#     185         longitudinal = np.dot(delta, self.direction)
# --> 186         lateral = np.dot(delta, self.direction_lateral)
#     187         return float(longitudinal), float(lateral)
#     188
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
