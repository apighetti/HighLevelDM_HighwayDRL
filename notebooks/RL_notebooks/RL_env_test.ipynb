# %% [markdown]
# # Exploitation notebook

# %%
import gym
import highway_env
from stable_baselines3 import PPO
# from sb3_contrib import RecurrentPPO


# Visualisation
import sys
sys.path.append('/home/utente1/Desktop/PighettiForneris/HighwayDRL')
#from scripts.utils import record_videos
from ipywidgets import interact, widgets
import glob

ABS_PATH = '/home/utente1/Desktop/PighettiForneris/HighwayDRL'
# Out:
# /home/utente1/anaconda3/envs/RLenv/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment __root__/HandManipulateBlockRotateZ-v1
#   logger.warn("Overriding environment {}".format(id))
# /home/utente1/anaconda3/envs/RLenv/lib/python3.8/site-packages/gym/envs/registration.py:216: UserWarning: WARN: Overriding environment __root__/HandManipulateBlockRotateZDense-v1
#   logger.warn("Overriding environment {}".format(id))

# %% [markdown]
# ### Choose the environment to exploit the model in

# %%
env_id = widgets.Text()
def f(input_env):
    env_id.value = str(input_env)
interact(f, input_env=['dm-env-v0','acc-dm-env-v0','jam-dm-env-v0','overtaken-dm-env-v0','singleO-dm-env-v0','multipleO-dm-env-v0'])
# Out:
# interactive(children=(Dropdown(description='input_env', options=('dm-env-v0', 'acc-dm-env-v0', 'jam-dm-env-v0'…
# <function __main__.f(input_env)>

# %% [markdown]
# ### Choose the model

# %%
model_id = widgets.Text()
def m(input_model):
    model_id.value = str(input_model)
interact(m, input_model=glob.glob(f"{ABS_PATH}/training_output/models/*.zip"))
# Out:
# interactive(children=(Dropdown(description='input_model', options=('/home/utente1/Desktop/PighettiForneris/Hig…
# <function __main__.m(input_model)>

# %%
env = gym.make(env_id.value)
env.configure({
    "screen_width":1500,
    "screen_height":250
})

print(model_id.value)
# env = record_videos(env, path=f"{ABS_PATH}/exploitation/videos/{env_id.value}")

model = PPO.load("/home/utente1/Desktop/PighettiForneris/HighwayDRL/training_output/checkpoints/dm_rl_callback_45000_steps")

for episode in range(3):

    obs, done = env.reset(), False

    while not done:

        action, _ = model.predict(obs, deterministic=True)
        env.render()
        obs, reward, done, info = env.step(action)

env.close()
# Out:
# /home/utente1/Desktop/PighettiForneris/HighwayDRL/training_output/models/ppo_RL_UBUNTU_1.0E+05_multipleO-dm-env-v0_14-09_18-56-00.zip
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 20
#      18         action, _ = model.predict(obs, deterministic=True)
#      19         env.render()
# ---> 20         obs, reward, done, info = env.step(action)
#      22 env.close()
#
# File ~/anaconda3/envs/RLenv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       9 def step(self, action):
#      10     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11     observation, reward, done, info = self.env.step(action)
#      12     return observation, reward, done, info
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/envs/common/abstract.py:216, in AbstractEnv.step(self, action)
#     213     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     215 self.steps += 1
# --> 216 self._simulate(action)
#     218 obs = self.observation_type.observe()
#     219 reward = self._reward(action)
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/envs/common/abstract.py:233, in AbstractEnv._simulate(self, action)
#     228 for frame in range(frames):
#     229     # Forward action to the vehicle
#     230     if action is not None \
#     231             and not self.config["manual_control"] \
#     232             and self.time % int(self.config["simulation_frequency"] // self.config["policy_frequency"]) == 0:
# --> 233         self.action_type.act(action)
#     235     self.road.act()
#     236     self.road.step(1 / self.config["simulation_frequency"])
#
# File ~/Desktop/PighettiForneris/HighwayDRL/highway_env/envs/common/action.py:323, in DecisionMakingAction.act(self, action)
#     322 def act(self, action: int) -> None:
# --> 323     self.controlled_vehicle.act(self.actions[action])
#
# TypeError: unhashable type: 'numpy.ndarray'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
