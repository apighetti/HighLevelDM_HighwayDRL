# %% [markdown]
# # Exploitation notebook

# %%
import gym
import highway_env
from stable_baselines3 import PPO

# Visualisation
import sys
sys.path.append('/Users/fornerispighetti/HighwayDRL')
from scripts.utils import record_videos
from ipywidgets import interact, widgets
import glob

ABS_PATH = '/Users/fornerispighetti/HighwayDRL'

# %% [markdown]
# ### Choose the environment to exploit the model in

# %%
env_id = widgets.Text()
def f(input_env):
    env_id.value = str(input_env)
interact(f, input_env=['dm-env-v0','acc-dm-env-v0','jam-dm-env-v0','overtaken-dm-env-v0','singleO-dm-env-v0','multipleO-dm-env-v0'])
# Out:
# interactive(children=(Dropdown(description='input_env', options=('dm-env-v0', 'acc-dm-env-v0', 'jam-dm-env-v0'…
# <function __main__.f(input_env)>

# %% [markdown]
# ### Choose the model

# %%
model_id = widgets.Text()
def m(input_model):
    model_id.value = str(input_model)
interact(m, input_model=glob.glob(f"{ABS_PATH}/training_output/models/*.zip"))
# Out:
# interactive(children=(Dropdown(description='input_model', options=('/Users/fornerispighetti/HighwayDRL/trainin…
# <function __main__.m(input_model)>

# %%
env = gym.make(env_id.value)
env.configure({
    "screen_width":1500,
    "screen_height":250,
    "duration": 80
})
env = record_videos(env, path=f"{ABS_PATH}/exploitation/videos/{env_id.value}")

model = PPO.load(model_id.value)


for episode in range(3):

    obs, done = env.reset(), False

    while not done:

        action, _ = model.predict(obs, deterministic=True)
        env.render()
        obs, reward, done, info = env.step(action)

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1e5d4e25e22f> in <module>
#      18         action, _ = model.predict(obs, deterministic=True)
#      19         env.render()
# ---> 20         obs, reward, done, info = env.step(action)
#      21
#      22 env.close()
#
# ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitor.py in step(self, action)
#      47     def step(self, action):
#      48         self._before_step(action)
# ---> 49         observation, reward, done, info = self.env.step(action)
#      50         done = self._after_step(observation, reward, done, info)
#      51
#
# ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py in step(self, action)
#      11     def step(self, action):
#      12         assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 13         observation, reward, done, info = self.env.step(action)
#      14         return observation, reward, done, info
#      15
#
# ~/HighwayDRL/highway_env/envs/common/abstract.py in step(self, action)
#     213
#     214         self.steps += 1
# --> 215         self._simulate(action)
#     216
#     217         obs = self.observation_type.observe()
#
# ~/HighwayDRL/highway_env/envs/common/abstract.py in _simulate(self, action)
#     239             # Ignored if the rendering is done offscreen
#     240             if frame < frames - 1:  # Last frame will be rendered through env.render() as usual
# --> 241                 self._automatic_rendering()
#     242
#     243         self.enable_auto_render = False
#
# ~/HighwayDRL/highway_env/envs/common/abstract.py in _automatic_rendering(self)
#     317
#     318             if self._monitor and self._monitor.video_recorder:
# --> 319                 self._monitor.video_recorder.capture_frame()
#     320             else:
#     321                 self.render(self.rendering_mode)
#
# ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitoring/video_recorder.py in capture_frame(self)
#     126
#     127         render_mode = "ansi" if self.ansi_mode else "rgb_array"
# --> 128         frame = self.env.render(mode=render_mode)
#     129
#     130         if frame is None:
#
# ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     284
#     285     def render(self, mode="human", **kwargs):
# --> 286         return self.env.render(mode, **kwargs)
#     287
#     288     def close(self):
#
# ~/HighwayDRL/highway_env/envs/common/abstract.py in render(self, mode)
#     257         self.enable_auto_render = True
#     258
# --> 259         self.viewer.display()
#     260
#     261         if not self.viewer.offscreen:
#
# ~/HighwayDRL/highway_env/envs/common/graphics.py in display(self)
#     133             if self.env.config["real_time_rendering"]:
#     134                 self.clock.tick(self.env.config["simulation_frequency"])
# --> 135             pygame.display.flip()
#     136
#     137         if self.SAVE_IMAGES and self.directory:
#
# KeyboardInterrupt:
