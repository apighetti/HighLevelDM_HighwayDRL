# %% [markdown]
# # Exploitation notebook

# %%
import gym
import highway_env
from stable_baselines3 import PPO

# Visualisation
import sys
sys.path.append('C:/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/')     
from ipywidgets import interact, widgets
import glob

ABS_PATH = 'C:/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/'

# %% [markdown]
# ### Choose the environment to exploit the model in

# %%
env_id = widgets.Text()
def f(input_env):
    env_id.value = str(input_env)
interact(f, input_env=['dm-env-v0','acc-dm-env-v0','jam-dm-env-v0','overtaken-dm-env-v0','singleO-dm-env-v0','multipleO-dm-env-v0'])
# Out:
# interactive(children=(Dropdown(description='input_env', options=('dm-env-v0', 'acc-dm-env-v0', 'jam-dm-env-v0'…
# <function __main__.f(input_env)>

# %% [markdown]
# ### Choose the model

# %%
model_id = widgets.Text()
def m(input_model):
    model_id.value = str(input_model)
interact(m, input_model=glob.glob(f"{ABS_PATH}/training_output/models/*.zip"))
# Out:
# interactive(children=(Dropdown(description='input_model', options=('/Users/fornerispighetti/HighwayDRL/trainin…
# <function __main__.m(input_model)>

# %%
env = gym.make(env_id.value)
env.configure({
    "screen_width":1500,
    "screen_height":250,
    "duration": 80
})

model = PPO.load(model_id.value)


for episode in range(3):

    obs, done = env.reset(), False

    while not done:

        action, _ = model.predict(obs, deterministic=True)
        env.render()
        obs, reward, done, info = env.step(action)

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/fornerispighetti/HighwayDRL/notebooks/RL_notebooks/RL_env_test.ipynb Cell 7' in <cell line: 12>()
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/RL_notebooks/RL_env_test.ipynb#ch0000003?line=17'>18</a>         action, _ = model.predict(obs, deterministic=True)
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/RL_notebooks/RL_env_test.ipynb#ch0000003?line=18'>19</a>         env.render()
# ---> <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/RL_notebooks/RL_env_test.ipynb#ch0000003?line=19'>20</a>         obs, reward, done, info = env.step(action)
#      <a href='vscode-notebook-cell:/Users/fornerispighetti/HighwayDRL/notebooks/RL_notebooks/RL_env_test.ipynb#ch0000003?line=21'>22</a> env.close()
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitor.py:48, in Monitor.step(self, action)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitor.py?line=45'>46</a> def step(self, action):
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitor.py?line=46'>47</a>     self._before_step(action)
# ---> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitor.py?line=47'>48</a>     observation, reward, done, info = self.env.step(action)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitor.py?line=48'>49</a>     done = self._after_step(observation, reward, done, info)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitor.py?line=50'>51</a>     return observation, reward, done, info
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=8'>9</a> def step(self, action):
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=9'>10</a>     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=10'>11</a>     observation, reward, done, info = self.env.step(action)
#      <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py?line=11'>12</a>     return observation, reward, done, info
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:215, in AbstractEnv.step(self, action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=211'>212</a>     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=213'>214</a> self.steps += 1
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=214'>215</a> self._simulate(action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=216'>217</a> obs = self.observation_type.observe()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=217'>218</a> reward = self._reward(action)
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:241, in AbstractEnv._simulate(self, action)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=237'>238</a>     # Automatically render intermediate simulation steps if a viewer has been launched
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=238'>239</a>     # Ignored if the rendering is done offscreen
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=239'>240</a>     if frame < frames - 1:  # Last frame will be rendered through env.render() as usual
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=240'>241</a>         self._automatic_rendering()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=242'>243</a> self.enable_auto_render = False
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:319, in AbstractEnv._automatic_rendering(self)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=315'>316</a> if self.viewer is not None and self.enable_auto_render:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=317'>318</a>     if self._monitor and self._monitor.video_recorder:
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=318'>319</a>         self._monitor.video_recorder.capture_frame()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=319'>320</a>     else:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=320'>321</a>         self.render(self.rendering_mode)
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitoring/video_recorder.py:132, in VideoRecorder.capture_frame(self)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitoring/video_recorder.py?line=128'>129</a> logger.debug("Capturing video frame: path=%s", self.path)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitoring/video_recorder.py?line=130'>131</a> render_mode = "ansi" if self.ansi_mode else "rgb_array"
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitoring/video_recorder.py?line=131'>132</a> frame = self.env.render(mode=render_mode)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitoring/video_recorder.py?line=133'>134</a> if frame is None:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/wrappers/monitoring/video_recorder.py?line=134'>135</a>     if self._async:
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/gym/core.py:295, in Wrapper.render(self, mode, **kwargs)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/core.py?line=293'>294</a> def render(self, mode="human", **kwargs):
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/gym/core.py?line=294'>295</a>     return self.env.render(mode, **kwargs)
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:259, in AbstractEnv.render(self, mode)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=254'>255</a>     self.viewer = EnvViewer(self)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=256'>257</a> self.enable_auto_render = True
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=258'>259</a> self.viewer.display()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=260'>261</a> if not self.viewer.offscreen:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/abstract.py?line=261'>262</a>     self.viewer.handle_events()
#
# File ~/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/graphics.py:135, in EnvViewer.display(self)
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/graphics.py?line=132'>133</a>     if self.env.config["real_time_rendering"]:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/graphics.py?line=133'>134</a>         self.clock.tick(self.env.config["simulation_frequency"])
# --> <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/graphics.py?line=134'>135</a>     pygame.display.flip()
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/graphics.py?line=136'>137</a> if self.SAVE_IMAGES and self.directory:
#     <a href='file:///Users/fornerispighetti/HighwayDRL/.venv/lib/python3.8/site-packages/highway_env/envs/common/graphics.py?line=137'>138</a>     pygame.image.save(self.sim_surface, str(self.directory / "highway-env_{}.png".format(self.frame)))
#
# KeyboardInterrupt:
