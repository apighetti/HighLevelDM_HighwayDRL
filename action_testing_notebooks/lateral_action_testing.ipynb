# %%
# %pip install .

# %%
import gym
import highway_env

env = gym.make('dm-env-v0')
env.configure({
    "manual_control": True,
    "simulation_frequency": 50,
    "screen_width": 1250
})
env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored
# Out:
# RIGHTMOSTLANE ON
# RIGHTMOSTLANE OFF
# ACC ON
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE ON
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE OFF
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE ON
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE OFF
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE ON
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE OFF
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE ON
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE OFF
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE ON
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE OFF
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# RIGHTMOSTLANE ON
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
#
# 0.02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aless\OneDrive\Desktop\Thesis_repo_new\HighwayDRL\action_testing_notebooks\lateral_action_testing.ipynb Cell 2' in <cell line: 12>()
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=10'>11</a> done = False
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=11'>12</a> while not done:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=12'>13</a>     env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/lateral_action_testing.ipynb#ch0000001?line=13'>14</a>     env.render()
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:215, in AbstractEnv.step(self, action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=211'>212</a>     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=213'>214</a> self.steps += 1
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=214'>215</a> self._simulate(action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=216'>217</a> obs = self.observation_type.observe()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=217'>218</a> reward = self._reward(action)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:235, in AbstractEnv._simulate(self, action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=231'>232</a>     self.action_type.act(action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=233'>234</a> self.road.act()
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=234'>235</a> self.road.step(1 / self.config["simulation_frequency"])
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=235'>236</a> self.time += 1
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=237'>238</a> # Automatically render intermediate simulation steps if a viewer has been launched
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=238'>239</a> # Ignored if the rendering is done offscreen
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\road\road.py:333, in Road.step(self, dt)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=326'>327</a> """
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=327'>328</a> Step the dynamics of each entity on the road.
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=328'>329</a>
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=329'>330</a> :param dt: timestep [s]
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=330'>331</a> """
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=331'>332</a> for vehicle in self.vehicles:
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=332'>333</a>     vehicle.step(dt)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=333'>334</a> for i, vehicle in enumerate(self.vehicles):
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/road.py?line=334'>335</a>     for other in self.vehicles[i+1:]:
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\vehicle\controller.py:613, in DecisionMakingVehicle.step(self, dt)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/controller.py?line=609'>610</a> def step(self, dt: float) -> None:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/controller.py?line=611'>612</a>     if(self.acc_flag):
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/controller.py?line=612'>613</a>         print(f"\n{dt}")
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/controller.py?line=613'>614</a>         self.tactical_dm("ACC")
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/controller.py?line=614'>615</a>     # elif(self.ovtk_flag):
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/controller.py?line=615'>616</a>     #     self.tactical_dm("OVERTAKE")
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=528'>529</a> is_child = (not self._is_master_process())
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=529'>530</a> # only touch the buffer in the IO thread to avoid races
# --> <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=530'>531</a> self.pub_thread.schedule(lambda: self._buffer.write(string))
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=531'>532</a> if is_child:
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=532'>533</a>     # mp.Pool cannot be trusted to flush promptly (or ever),
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=533'>534</a>     # and this helps.
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=534'>535</a>     if self._subprocess_flush_pending:
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:216, in IOPubThread.schedule(self, f)
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=213'>214</a>     self._events.append(f)
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=214'>215</a>     # wake event thread (message content is ignored)
# --> <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=215'>216</a>     self._event_pipe.send(b'')
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=216'>217</a> else:
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/ipykernel/iostream.py?line=217'>218</a>     f()
#
# File ~\anaconda3\lib\site-packages\zmq\sugar\socket.py:416, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/zmq/sugar/socket.py?line=412'>413</a>         data = zmq.Frame(data, track=track, copy=copy or None,
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/zmq/sugar/socket.py?line=413'>414</a>                          copy_threshold=self.copy_threshold)
#     <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/zmq/sugar/socket.py?line=414'>415</a>     data.group = group
# --> <a href='file:///c%3A/Users/aless/anaconda3/lib/site-packages/zmq/sugar/socket.py?line=415'>416</a> return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:728, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:775, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:242, in zmq.backend.cython.socket._send_copy()
#
# File ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
