# %%
# %pip install -e ..

# %%
import gym
import highway_env
import time

env = gym.make('acc-dm-v0')
env.configure({
    "manual_control": True,
    "simulation_frequency": 50,
    "screen_width": 1250
    })
env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aless\OneDrive\Desktop\Thesis_repo_new\HighwayDRL\action_testing_notebooks\acc_action_testing.ipynb Cell 2' in <cell line: 12>()
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/acc_action_testing.ipynb#ch0000001?line=10'>11</a> done = False
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/acc_action_testing.ipynb#ch0000001?line=11'>12</a> while not done:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/acc_action_testing.ipynb#ch0000001?line=12'>13</a>     env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/acc_action_testing.ipynb#ch0000001?line=13'>14</a>     env.render()
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:215, in AbstractEnv.step(self, action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=211'>212</a>     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=213'>214</a> self.steps += 1
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=214'>215</a> self._simulate(action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=216'>217</a> obs = self.observation_type.observe()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=217'>218</a> reward = self._reward(action)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:241, in AbstractEnv._simulate(self, action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=237'>238</a>     # Automatically render intermediate simulation steps if a viewer has been launched
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=238'>239</a>     # Ignored if the rendering is done offscreen
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=239'>240</a>     if frame < frames - 1:  # Last frame will be rendered through env.render() as usual
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=240'>241</a>         self._automatic_rendering()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=242'>243</a> self.enable_auto_render = False
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:321, in AbstractEnv._automatic_rendering(self)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=318'>319</a>     self._monitor.video_recorder.capture_frame()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=319'>320</a> else:
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=320'>321</a>     self.render(self.rendering_mode)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:259, in AbstractEnv.render(self, mode)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=254'>255</a>     self.viewer = EnvViewer(self)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=256'>257</a> self.enable_auto_render = True
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=258'>259</a> self.viewer.display()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=260'>261</a> if not self.viewer.offscreen:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=261'>262</a>     self.viewer.handle_events()
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\graphics.py:101, in EnvViewer.display(self)
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=97'>98</a>     return
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=99'>100</a> self.sim_surface.move_display_window_to(self.window_position())
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=100'>101</a> RoadGraphics.display(self.env.road, self.sim_surface)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=102'>103</a> if self.vehicle_trajectory:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=103'>104</a>     VehicleGraphics.display_trajectory(
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=104'>105</a>         self.vehicle_trajectory,
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=105'>106</a>         self.sim_surface,
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=106'>107</a>         offscreen=self.offscreen)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\road\graphics.py:241, in RoadGraphics.display(road, surface)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=238'>239</a> for _to in road.network.graph[_from].keys():
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=239'>240</a>     for l in road.network.graph[_from][_to]:
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=240'>241</a>         LaneGraphics.display(l, surface)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\road\graphics.py:130, in LaneGraphics.display(cls, lane, surface)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=127'>128</a> for side in range(2):
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=128'>129</a>     if lane.line_types[side] == LineType.STRIPED:
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=129'>130</a>         cls.striped_line(lane, surface, stripes_count, s0, side)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=130'>131</a>     elif lane.line_types[side] == LineType.CONTINUOUS:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=131'>132</a>         cls.continuous_curve(lane, surface, stripes_count, s0, side)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\road\graphics.py:148, in LaneGraphics.striped_line(cls, lane, surface, stripes_count, longitudinal, side)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=135'>136</a> @classmethod
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=136'>137</a> def striped_line(cls, lane: AbstractLane, surface: WorldSurface, stripes_count: int, longitudinal: float,
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=137'>138</a>                  side: int) -> None:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=138'>139</a>     """
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=139'>140</a>     Draw a striped line on one side of a lane, on a surface.
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=140'>141</a>
#    (...)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=145'>146</a>     :param side: which side of the road to draw [0:left, 1:right]
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=146'>147</a>     """
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=147'>148</a>     starts = longitudinal + np.arange(stripes_count) * cls.STRIPE_SPACING
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=148'>149</a>     ends = longitudinal + np.arange(stripes_count) * cls.STRIPE_SPACING + cls.STRIPE_LENGTH
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=149'>150</a>     lats = [(side - 0.5) * lane.width_at(s) for s in starts]
#
# KeyboardInterrupt:
