# %%
# %pip install -e ..

# %%
import gym
import highway_env

env = gym.make('acc-dm-v0')
env.configure({
    "manual_control": True,
    "simulation_frequency": 50,
    "screen_width": 1250
    })
env.reset()
done = False
while not done:
    env.step(env.action_space.sample())
    env.render()    # with manual control, these actions are ignored
# Out:
# ACC ON
# My speed: 25.26315782088401
# Params:
#  my speed: 25.263
#  front_vehicle_speed: 23.299
#  current distance: 10.743
#  current acceleration: -0.8756964354025698
# Params:
#  my speed: 25.263
#  front_vehicle_speed: 23.299
#  current distance: 10.703
#  current acceleration: -0.8760733108559626
# Params:
#  my speed: 25.246
#  front_vehicle_speed: 23.299
#  current distance: 10.664
#  current acceleration: -0.8721345965374627
# Params:
#  my speed: 25.228
#  front_vehicle_speed: 23.299
#  current distance: 10.625
#  current acceleration: -0.8681899660112374
# Params:
#  my speed: 25.211
#  front_vehicle_speed: 23.299
#  current distance: 10.587
#  current acceleration: -0.8642606945068881
# Params:
#  my speed: 25.193
#  front_vehicle_speed: 23.299
#  current distance: 10.548
#  current acceleration: -0.8603468366553396
# Params:
#  my speed: 25.176
#  front_vehicle_speed: 23.299
#  current distance: 10.51
#  current acceleration: -0.8564483420767921
# Params:
#  my speed: 25.159
#  front_vehicle_speed: 23.299
#  current distance: 10.473
#  current acceleration: -0.852565159897028
# Params:
#  my speed: 25.142
#  front_vehicle_speed: 23.299
#  current distance: 10.436
#  current acceleration: -0.8486972392674047
# Params:
#  my speed: 25.125
#  front_vehicle_speed: 23.299
#  current distance: 10.399
#  current acceleration: -0.8448445293699475
# Params:
#  my speed: 25.108
#  front_vehicle_speed: 23.299
#  current distance: 10.362
#  current acceleration: -0.8410069794198377
# Params:
#  my speed: 25.091
#  front_vehicle_speed: 23.299
#  current distance: 10.326
#  current acceleration: -0.8371845386678589
# Params:
#  my speed: 25.074
#  front_vehicle_speed: 23.299
#  current distance: 10.29
#  current acceleration: -0.8333771564027864
# Params:
#  my speed: 25.057
#  front_vehicle_speed: 23.299
#  current distance: 10.255
#  current acceleration: -0.8295847819537427
# Params:
#  my speed: 25.041
#  front_vehicle_speed: 23.299
#  current distance: 10.22
#  current acceleration: -0.8258073646925174
# Params:
#  my speed: 25.024
#  front_vehicle_speed: 23.299
#  current distance: 10.185
#  current acceleration: -0.8220448540358266
# Params:
#  my speed: 25.007
#  front_vehicle_speed: 23.299
#  current distance: 10.15
#  current acceleration: -0.8182971994475541
# Params:
#  my speed: 24.991
#  front_vehicle_speed: 23.299
#  current distance: 10.116
#  current acceleration: -0.8145643504409378
# Params:
#  my speed: 24.975
#  front_vehicle_speed: 23.299
#  current distance: 10.082
#  current acceleration: -0.8108462565807251
# Params:
#  my speed: 24.958
#  front_vehicle_speed: 23.299
#  current distance: 10.049
#  current acceleration: -0.8071428674852776
# Params:
#  my speed: 24.942
#  front_vehicle_speed: 23.299
#  current distance: 10.015
#  current acceleration: -0.8034541328286504
# Params:
#  my speed: 24.926
#  front_vehicle_speed: 23.299
#  current distance: 9.983
#  current acceleration: -0.7997800023426294
# Params:
#  my speed: 24.91
#  front_vehicle_speed: 23.299
#  current distance: 9.95
#  current acceleration: -0.796120425818721
# Params:
#  my speed: 24.894
#  front_vehicle_speed: 23.299
#  current distance: 9.918
#  current acceleration: -0.7924753531101175
# Params:
#  my speed: 24.878
#  front_vehicle_speed: 23.299
#  current distance: 9.886
#  current acceleration: -0.7888447341336224
# Params:
#  my speed: 24.862
#  front_vehicle_speed: 23.299
#  current distance: 9.854
#  current acceleration: -0.7852285188715291
# Params:
#  my speed: 24.846
#  front_vehicle_speed: 23.299
#  current distance: 9.823
#  current acceleration: -0.7816266573734765
# Params:
#  my speed: 24.831
#  front_vehicle_speed: 23.299
#  current distance: 9.792
#  current acceleration: -0.778039099758267
# Params:
#  my speed: 24.815
#  front_vehicle_speed: 23.299
#  current distance: 9.761
#  current acceleration: -0.7744657962156393
# Params:
#  my speed: 24.799
#  front_vehicle_speed: 23.299
#  current distance: 9.731
#  current acceleration: -0.7709066970080214
# Params:
#  my speed: 24.784
#  front_vehicle_speed: 23.299
#  current distance: 9.701
#  current acceleration: -0.7673617524722315
# Params:
#  my speed: 24.769
#  front_vehicle_speed: 23.299
#  current distance: 9.671
#  current acceleration: -0.7638309130211657
# Params:
#  my speed: 24.753
#  front_vehicle_speed: 23.299
#  current distance: 9.642
#  current acceleration: -0.7603141291454346
# Params:
#  my speed: 24.738
#  front_vehicle_speed: 23.299
#  current distance: 9.613
#  current acceleration: -0.7568113514149755
# Params:
#  my speed: 24.723
#  front_vehicle_speed: 23.299
#  current distance: 9.584
#  current acceleration: -0.7533225304806296
# Params:
#  my speed: 24.708
#  front_vehicle_speed: 23.299
#  current distance: 9.556
#  current acceleration: -0.7498476170756896
# Params:
#  my speed: 24.693
#  front_vehicle_speed: 23.299
#  current distance: 9.528
#  current acceleration: -0.7463865620174154
# Params:
#  my speed: 24.678
#  front_vehicle_speed: 23.299
#  current distance: 9.5
#  current acceleration: -0.7429393162085074
# Params:
#  my speed: 24.663
#  front_vehicle_speed: 23.299
#  current distance: 9.472
#  current acceleration: -0.7395058306385688
# Params:
#  my speed: 24.648
#  front_vehicle_speed: 23.299
#  current distance: 9.445
#  current acceleration: -0.736086056385522
# Params:
#  my speed: 24.633
#  front_vehicle_speed: 23.299
#  current distance: 9.418
#  current acceleration: -0.7326799446169946
# Params:
#  my speed: 24.618
#  front_vehicle_speed: 23.299
#  current distance: 9.391
#  current acceleration: -0.7292874465916938
# Params:
#  my speed: 24.604
#  front_vehicle_speed: 23.299
#  current distance: 9.365
#  current acceleration: -0.7259085136607196
# Params:
#  my speed: 24.589
#  front_vehicle_speed: 23.299
#  current distance: 9.339
#  current acceleration: -0.7225430972688851
# Params:
#  my speed: 24.574
#  front_vehicle_speed: 23.299
#  current distance: 9.313
#  current acceleration: -0.719191148955976
# Params:
#  my speed: 24.56
#  front_vehicle_speed: 23.299
#  current distance: 9.287
#  current acceleration: -0.7158526203580062
# Params:
#  my speed: 24.546
#  front_vehicle_speed: 23.299
#  current distance: 9.262
#  current acceleration: -0.7125274632084277
# Params:
#  my speed: 24.531
#  front_vehicle_speed: 23.299
#  current distance: 9.237
#  current acceleration: -0.7092156293393304
# Params:
#  my speed: 24.517
#  front_vehicle_speed: 23.299
#  current distance: 9.212
#  current acceleration: -0.7059170706825951
# Params:
#  my speed: 24.503
#  front_vehicle_speed: 23.299
#  current distance: 9.188
#  current acceleration: -0.7026317392710363
# Params:
#  my speed: 24.489
#  front_vehicle_speed: 23.299
#  current distance: 9.164
#  current acceleration: -0.6993595872395075
# Params:
#  my speed: 24.475
#  front_vehicle_speed: 23.299
#  current distance: 9.14
#  current acceleration: -0.6961005668259901
# Params:
#  my speed: 24.461
#  front_vehicle_speed: 23.299
#  current distance: 9.117
#  current acceleration: -0.692854630372649
# Params:
#  my speed: 24.447
#  front_vehicle_speed: 23.299
#  current distance: 9.093
#  current acceleration: -0.6896217303268615
# Params:
#  my speed: 24.433
#  front_vehicle_speed: 23.299
#  current distance: 9.07
#  current acceleration: -0.6864018192422344
# Params:
#  my speed: 24.419
#  front_vehicle_speed: 23.299
#  current distance: 9.048
#  current acceleration: -0.6831948497795759
# Params:
#  my speed: 24.405
#  front_vehicle_speed: 23.299
#  current distance: 9.025
#  current acceleration: -0.6800007747078618
# Params:
#  my speed: 24.392
#  front_vehicle_speed: 23.299
#  current distance: 9.003
#  current acceleration: -0.6768195469051708
# Params:
#  my speed: 24.378
#  front_vehicle_speed: 23.299
#  current distance: 8.981
#  current acceleration: -0.6736511193595901
# Params:
#  my speed: 24.365
#  front_vehicle_speed: 23.299
#  current distance: 8.96
#  current acceleration: -0.6704954451701062
# Params:
#  my speed: 24.351
#  front_vehicle_speed: 23.299
#  current distance: 8.938
#  current acceleration: -0.6673524775474726
# Params:
#  my speed: 24.338
#  front_vehicle_speed: 23.299
#  current distance: 8.917
#  current acceleration: -0.6642221698150463
# Params:
#  my speed: 24.324
#  front_vehicle_speed: 23.299
#  current distance: 8.897
#  current acceleration: -0.6611044754096135
# Params:
#  my speed: 24.311
#  front_vehicle_speed: 23.299
#  current distance: 8.876
#  current acceleration: -0.6579993478821827
# Params:
#  my speed: 24.298
#  front_vehicle_speed: 23.299
#  current distance: 8.856
#  current acceleration: -0.6549067408987619
# Params:
#  my speed: 24.285
#  front_vehicle_speed: 23.299
#  current distance: 8.836
#  current acceleration: -0.6518266082411162
# Params:
#  my speed: 24.272
#  front_vehicle_speed: 23.299
#  current distance: 8.816
#  current acceleration: -0.6487589038075003
# Params:
#  my speed: 24.259
#  front_vehicle_speed: 23.299
#  current distance: 8.797
#  current acceleration: -0.6457035816133688
# Params:
#  my speed: 24.246
#  front_vehicle_speed: 23.299
#  current distance: 8.778
#  current acceleration: -0.64266059579207
# Params:
#  my speed: 24.233
#  front_vehicle_speed: 23.299
#  current distance: 8.759
#  current acceleration: -0.6396299005955208
# Params:
#  my speed: 24.22
#  front_vehicle_speed: 23.299
#  current distance: 8.74
#  current acceleration: -0.6366114503948545
# Params:
#  my speed: 24.207
#  front_vehicle_speed: 23.299
#  current distance: 8.721
#  current acceleration: -0.6336051996810615
# Params:
#  my speed: 24.194
#  front_vehicle_speed: 23.299
#  current distance: 8.703
#  current acceleration: -0.6306111030655892
# Params:
#  my speed: 24.182
#  front_vehicle_speed: 23.299
#  current distance: 8.685
#  current acceleration: -0.6276291152809516
# Params:
#  my speed: 24.169
#  front_vehicle_speed: 23.299
#  current distance: 8.668
#  current acceleration: -0.6246591911812971
# Params:
#  my speed: 24.156
#  front_vehicle_speed: 23.299
#  current distance: 8.65
#  current acceleration: -0.621701285742966
# Params:
#  my speed: 24.144
#  front_vehicle_speed: 23.299
#  current distance: 8.633
#  current acceleration: -0.6187553540650315
# Params:
#  my speed: 24.132
#  front_vehicle_speed: 23.299
#  current distance: 8.616
#  current acceleration: -0.6158213513698207
# Params:
#  my speed: 24.119
#  front_vehicle_speed: 23.299
#  current distance: 8.6
#  current acceleration: -0.6128992330034189
# Params:
#  my speed: 24.107
#  front_vehicle_speed: 23.299
#  current distance: 8.583
#  current acceleration: -0.6099889544361536
# Params:
#  my speed: 24.095
#  front_vehicle_speed: 23.299
#  current distance: 8.567
#  current acceleration: -0.6070904712630698
# Params:
#  my speed: 24.082
#  front_vehicle_speed: 23.299
#  current distance: 8.551
#  current acceleration: -0.604203739204372
# Params:
#  my speed: 24.07
#  front_vehicle_speed: 23.299
#  current distance: 8.535
#  current acceleration: -0.601328714105871
# Params:
#  my speed: 24.058
#  front_vehicle_speed: 23.299
#  current distance: 8.52
#  current acceleration: -0.5984653519393979
# Params:
#  my speed: 24.046
#  front_vehicle_speed: 23.299
#  current distance: 8.505
#  current acceleration: -0.5956136088032088
# Params:
#  my speed: 24.034
#  front_vehicle_speed: 23.299
#  current distance: 8.49
#  current acceleration: -0.5927734409223745
# Params:
#  my speed: 24.022
#  front_vehicle_speed: 23.299
#  current distance: 8.475
#  current acceleration: -0.589944804649149
# Params:
#  my speed: 24.01
#  front_vehicle_speed: 23.299
#  current distance: 8.461
#  current acceleration: -0.5871276564633299
# Params:
#  my speed: 23.999
#  front_vehicle_speed: 23.299
#  current distance: 8.446
#  current acceleration: -0.5843219529725968
# Params:
#  my speed: 23.987
#  front_vehicle_speed: 23.299
#  current distance: 8.432
#  current acceleration: -0.5815276509128436
# Params:
#  my speed: 23.975
#  front_vehicle_speed: 23.299
#  current distance: 8.419
#  current acceleration: -0.5787447071484852
# Params:
#  my speed: 23.964
#  front_vehicle_speed: 23.299
#  current distance: 8.405
#  current acceleration: -0.5759730786727618
# Params:
#  my speed: 23.952
#  front_vehicle_speed: 23.299
#  current distance: 8.392
#  current acceleration: -0.5732127226080153
# Params:
#  my speed: 23.94
#  front_vehicle_speed: 23.299
#  current distance: 8.379
#  current acceleration: -0.5704635962059706
# Params:
#  my speed: 23.929
#  front_vehicle_speed: 23.299
#  current distance: 8.366
#  current acceleration: -0.5677256568479799
# Params:
#  my speed: 23.918
#  front_vehicle_speed: 23.299
#  current distance: 8.353
#  current acceleration: -0.5649988620452734
# Params:
#  my speed: 23.906
#  front_vehicle_speed: 23.299
#  current distance: 8.341
#  current acceleration: -0.5622831694391872
# Params:
#  my speed: 23.895
#  front_vehicle_speed: 23.299
#  current distance: 8.329
#  current acceleration: -0.5595785368013806
# Params:
#  my speed: 23.884
#  front_vehicle_speed: 23.299
#  current distance: 8.317
#  current acceleration: -0.5568849220340394
# Params:
#  my speed: 23.873
#  front_vehicle_speed: 23.299
#  current distance: 8.305
#  current acceleration: -0.5542022831700688
# Params:
#  my speed: 23.861
#  front_vehicle_speed: 23.299
#  current distance: 8.294
#  current acceleration: -0.5515305783732682
# Params:
#  my speed: 23.85
#  front_vehicle_speed: 23.299
#  current distance: 8.282
#  current acceleration: -0.5488697659385067
# Params:
#  my speed: 23.839
#  front_vehicle_speed: 23.299
#  current distance: 8.271
#  current acceleration: -0.5462198042918681
# Params:
#  my speed: 23.828
#  front_vehicle_speed: 23.299
#  current distance: 8.261
#  current acceleration: -0.5435806519908043
# Params:
#  my speed: 23.817
#  front_vehicle_speed: 23.299
#  current distance: 8.25
#  current acceleration: -0.5409522677242601
# Params:
#  my speed: 23.806
#  front_vehicle_speed: 23.299
#  current distance: 8.24
#  current acceleration: -0.5383346103127923
# Params:
#  my speed: 23.796
#  front_vehicle_speed: 23.299
#  current distance: 8.229
#  current acceleration: -0.5357276387086851
# Params:
#  my speed: 23.785
#  front_vehicle_speed: 23.299
#  current distance: 8.22
#  current acceleration: -0.5331313119960457
# Params:
#  my speed: 23.774
#  front_vehicle_speed: 23.299
#  current distance: 8.21
#  current acceleration: -0.5305455893908922
# Params:
#  my speed: 23.764
#  front_vehicle_speed: 23.299
#  current distance: 8.2
#  current acceleration: -0.5279704302412269
# Params:
#  my speed: 23.753
#  front_vehicle_speed: 23.299
#  current distance: 8.191
#  current acceleration: -0.5254057940271084
# Params:
#  my speed: 23.742
#  front_vehicle_speed: 23.299
#  current distance: 8.182
#  current acceleration: -0.5228516403607064
# Params:
#  my speed: 23.732
#  front_vehicle_speed: 23.299
#  current distance: 8.173
#  current acceleration: -0.5203079289863438
# Params:
#  my speed: 23.721
#  front_vehicle_speed: 23.299
#  current distance: 8.164
#  current acceleration: -0.5177746197805377
# Params:
#  my speed: 23.711
#  front_vehicle_speed: 23.299
#  current distance: 8.156
#  current acceleration: -0.5152516727520262
# Params:
#  my speed: 23.701
#  front_vehicle_speed: 23.299
#  current distance: 8.148
#  current acceleration: -0.5127390480417826
# Params:
#  my speed: 23.69
#  front_vehicle_speed: 23.299
#  current distance: 8.14
#  current acceleration: -0.5102367059230245
# Params:
#  my speed: 23.68
#  front_vehicle_speed: 23.299
#  current distance: 8.132
#  current acceleration: -0.5077446068012137
# Params:
#  my speed: 23.67
#  front_vehicle_speed: 23.299
#  current distance: 8.124
#  current acceleration: -0.5052627112140468
# Params:
#  my speed: 23.66
#  front_vehicle_speed: 23.299
#  current distance: 8.117
#  current acceleration: -0.5027909798314306
# Params:
#  my speed: 23.65
#  front_vehicle_speed: 23.299
#  current distance: 8.11
#  current acceleration: -0.5003293734554598
# Params:
#  my speed: 23.64
#  front_vehicle_speed: 23.299
#  current distance: 8.103
#  current acceleration: -0.4978778530203809
# Params:
#  my speed: 23.63
#  front_vehicle_speed: 23.299
#  current distance: 8.096
#  current acceleration: -0.49543637959254316
# Params:
#  my speed: 23.62
#  front_vehicle_speed: 23.299
#  current distance: 8.089
#  current acceleration: -0.493004914370348
# Params:
#  my speed: 23.61
#  front_vehicle_speed: 23.299
#  current distance: 8.083
#  current acceleration: -0.4905834186841873
# Params:
#  my speed: 23.6
#  front_vehicle_speed: 23.299
#  current distance: 8.076
#  current acceleration: -0.4881718539963792
# Params:
#  my speed: 23.59
#  front_vehicle_speed: 23.299
#  current distance: 8.07
#  current acceleration: -0.485770181901084
# Params:
#  my speed: 23.58
#  front_vehicle_speed: 23.299
#  current distance: 8.065
#  current acceleration: -0.4833783641242262
# Params:
#  my speed: 23.571
#  front_vehicle_speed: 23.299
#  current distance: 8.059
#  current acceleration: -0.4809963625233993
# Params:
#  my speed: 23.561
#  front_vehicle_speed: 23.299
#  current distance: 8.054
#  current acceleration: -0.4786241390877688
# Params:
#  my speed: 23.551
#  front_vehicle_speed: 23.299
#  current distance: 8.048
#  current acceleration: -0.47626165593795955
# Params:
#  my speed: 23.542
#  front_vehicle_speed: 23.299
#  current distance: 8.043
#  current acceleration: -0.4739088753259568
# Params:
#  my speed: 23.532
#  front_vehicle_speed: 23.299
#  current distance: 8.038
#  current acceleration: -0.47156575963497593
# Params:
#  my speed: 23.523
#  front_vehicle_speed: 23.299
#  current distance: 8.034
#  current acceleration: -0.46923227137933066
# Params:
#  my speed: 23.513
#  front_vehicle_speed: 23.299
#  current distance: 8.029
#  current acceleration: -0.466908373204315
# Params:
#  my speed: 23.504
#  front_vehicle_speed: 23.299
#  current distance: 8.025
#  current acceleration: -0.46459402788604887
# Params:
#  my speed: 23.494
#  front_vehicle_speed: 23.299
#  current distance: 8.021
#  current acceleration: -0.4622891983313393
# Params:
#  my speed: 23.485
#  front_vehicle_speed: 23.299
#  current distance: 8.017
#  current acceleration: -0.4599938475775256
# Params:
#  my speed: 23.476
#  front_vehicle_speed: 23.299
#  current distance: 8.013
#  current acceleration: -0.4577079387923261
# Params:
#  my speed: 23.467
#  front_vehicle_speed: 23.299
#  current distance: 8.01
#  current acceleration: -0.45543143527366214
# Params:
#  my speed: 23.458
#  front_vehicle_speed: 23.299
#  current distance: 8.006
#  current acceleration: -0.4531643004494995
# Params:
#  my speed: 23.448
#  front_vehicle_speed: 23.299
#  current distance: 8.003
#  current acceleration: -0.45090649787766723
# Params:
#  my speed: 23.439
#  front_vehicle_speed: 23.299
#  current distance: 8.0
#  current acceleration: -0.44865799124567285
# Params:
#  my speed: 23.43
#  front_vehicle_speed: 23.299
#  current distance: 7.997
#  current acceleration: -0.44641874437051865
# Params:
#  my speed: 23.421
#  front_vehicle_speed: 23.299
#  current distance: 7.995
#  current acceleration: -0.4441887211985118
# Params:
#  my speed: 23.413
#  front_vehicle_speed: 23.299
#  current distance: 7.992
#  current acceleration: -0.4419678858050613
# Params:
#  my speed: 23.404
#  front_vehicle_speed: 23.299
#  current distance: 7.99
#  current acceleration: -0.43975620239447677
# Params:
#  my speed: 23.395
#  front_vehicle_speed: 23.299
#  current distance: 7.988
#  current acceleration: -0.43755363529976166
# Params:
#  my speed: 23.386
#  front_vehicle_speed: 23.299
#  current distance: 7.986
#  current acceleration: -0.43536014898239994
# Params:
#  my speed: 23.377
#  front_vehicle_speed: 23.299
#  current distance: 7.984
#  current acceleration: -0.4331757080321341
# Params:
#  my speed: 23.369
#  front_vehicle_speed: 23.299
#  current distance: 7.983
#  current acceleration: -0.4310002771667498
# Params:
#  my speed: 23.36
#  front_vehicle_speed: 23.299
#  current distance: 7.981
#  current acceleration: -0.42883382123184155
# Params:
#  my speed: 23.351
#  front_vehicle_speed: 23.299
#  current distance: 7.98
#  current acceleration: -0.42667630520058897
# Params:
#  my speed: 23.343
#  front_vehicle_speed: 23.299
#  current distance: 7.979
#  current acceleration: -0.4245276941735132
# Params:
#  my speed: 23.334
#  front_vehicle_speed: 23.299
#  current distance: 7.978
#  current acceleration: -0.4223879533782404
# Params:
#  my speed: 23.326
#  front_vehicle_speed: 23.299
#  current distance: 7.977
#  current acceleration: -0.420257048169258
# Params:
#  my speed: 23.317
#  front_vehicle_speed: 23.299
#  current distance: 7.977
#  current acceleration: -0.4181349440276594
# Params:
#  my speed: 23.309
#  front_vehicle_speed: 23.299
#  current distance: 7.976
#  current acceleration: -0.41602160656090403
# Params:
#  my speed: 23.3
#  front_vehicle_speed: 23.299
#  current distance: 7.976
#  current acceleration: -0.41391700150254784
# Params:
#  my speed: 23.292
#  front_vehicle_speed: 23.299
#  current distance: 7.976
#  current acceleration: -0.4118210947119927
# Params:
#  my speed: 23.284
#  front_vehicle_speed: 23.299
#  current distance: 7.976
#  current acceleration: -0.40973385217421276
# Params:
#  my speed: 23.276
#  front_vehicle_speed: 23.299
#  current distance: 7.977
#  current acceleration: -0.4076552399994976
# Params:
#  my speed: 23.267
#  front_vehicle_speed: 23.299
#  current distance: 7.977
#  current acceleration: -0.4055852244231689
# Params:
#  my speed: 23.259
#  front_vehicle_speed: 23.299
#  current distance: 7.978
#  current acceleration: -0.40352377180531973
# Params:
#  my speed: 23.251
#  front_vehicle_speed: 23.299
#  current distance: 7.978
#  current acceleration: -0.40147084863052074
# Params:
#  my speed: 23.243
#  front_vehicle_speed: 23.299
#  current distance: 7.979
#  current acceleration: -0.3994264215075527
# Params:
#  my speed: 23.235
#  front_vehicle_speed: 23.299
#  current distance: 7.981
#  current acceleration: -0.3973904571691156
# Params:
#  my speed: 23.227
#  front_vehicle_speed: 23.299
#  current distance: 7.982
#  current acceleration: -0.39536292247153715
# Params:
#  my speed: 23.219
#  front_vehicle_speed: 23.299
#  current distance: 7.983
#  current acceleration: -0.39334378439449147
# Params:
#  my speed: 23.211
#  front_vehicle_speed: 23.299
#  current distance: 7.985
#  current acceleration: -0.391333010040697
# Params:
#  my speed: 23.203
#  front_vehicle_speed: 23.299
#  current distance: 7.987
#  current acceleration: -0.3893305666356234
# Params:
#  my speed: 23.196
#  front_vehicle_speed: 23.299
#  current distance: 7.988
#  current acceleration: -0.38733642152719294
# Params:
#  my speed: 23.188
#  front_vehicle_speed: 23.299
#  current distance: 7.991
#  current acceleration: -0.3853505421854747
# Params:
#  my speed: 23.18
#  front_vehicle_speed: 23.299
#  current distance: 7.993
#  current acceleration: -0.3833728962023847
# Params:
#  my speed: 23.172
#  front_vehicle_speed: 23.299
#  current distance: 7.995
#  current acceleration: -0.3814034512913761
# Params:
#  my speed: 23.165
#  front_vehicle_speed: 23.299
#  current distance: 7.998
#  current acceleration: -0.37944217528712854
# Params:
#  my speed: 23.157
#  front_vehicle_speed: 23.299
#  current distance: 8.0
#  current acceleration: -0.37748903614523655
# Params:
#  my speed: 23.149
#  front_vehicle_speed: 23.299
#  current distance: 8.003
#  current acceleration: -0.3755440019418921
# Params:
#  my speed: 23.142
#  front_vehicle_speed: 23.299
#  current distance: 8.006
#  current acceleration: -0.37360704087357754
# Params:
#  my speed: 23.134
#  front_vehicle_speed: 23.299
#  current distance: 8.009
#  current acceleration: -0.3716781212567355
# Params:
#  my speed: 23.127
#  front_vehicle_speed: 23.299
#  current distance: 8.013
#  current acceleration: -0.36975721152744945
# Params:
#  my speed: 23.119
#  front_vehicle_speed: 23.299
#  current distance: 8.016
#  current acceleration: -0.36784428024112525
# Params:
#  my speed: 23.112
#  front_vehicle_speed: 23.299
#  current distance: 8.02
#  current acceleration: -0.3659392960721647
# Params:
#  my speed: 23.105
#  front_vehicle_speed: 23.299
#  current distance: 8.023
#  current acceleration: -0.3640422278136307
# Params:
#  my speed: 23.097
#  front_vehicle_speed: 23.299
#  current distance: 8.027
#  current acceleration: -0.3621530443769272
# Params:
#  my speed: 23.09
#  front_vehicle_speed: 23.299
#  current distance: 8.031
#  current acceleration: -0.360271714791463
# Params:
#  my speed: 23.083
#  front_vehicle_speed: 23.299
#  current distance: 8.035
#  current acceleration: -0.358398208204323
# Params:
#  my speed: 23.076
#  front_vehicle_speed: 23.299
#  current distance: 8.04
#  current acceleration: -0.35653249387992636
# Params:
#  my speed: 23.068
#  front_vehicle_speed: 23.299
#  current distance: 8.044
#  current acceleration: -0.35467454119969877
# Params:
#  my speed: 23.061
#  front_vehicle_speed: 23.299
#  current distance: 8.049
#  current acceleration: -0.352824319661727
# Params:
#  my speed: 23.054
#  front_vehicle_speed: 23.299
#  current distance: 8.054
#  current acceleration: -0.35098179888042536
# Params:
#  my speed: 23.047
#  front_vehicle_speed: 23.299
#  current distance: 8.058
#  current acceleration: -0.3491469485861898
# Params:
#  my speed: 23.04
#  front_vehicle_speed: 23.299
#  current distance: 8.063
#  current acceleration: -0.34731973862506316
# Params:
#  my speed: 23.033
#  front_vehicle_speed: 23.299
#  current distance: 8.069
#  current acceleration: -0.34550013895837894
# Params:
#  my speed: 23.026
#  front_vehicle_speed: 23.299
#  current distance: 8.074
#  current acceleration: -0.3436881196624314
# Params:
#  my speed: 23.019
#  front_vehicle_speed: 23.299
#  current distance: 8.079
#  current acceleration: -0.3418836509281148
# Params:
#  my speed: 23.012
#  front_vehicle_speed: 23.299
#  current distance: 8.085
#  current acceleration: -0.34008670306058864
# Params:
#  my speed: 23.006
#  front_vehicle_speed: 23.299
#  current distance: 8.091
#  current acceleration: -0.33829724647891857
# Params:
#  my speed: 22.999
#  front_vehicle_speed: 23.299
#  current distance: 8.097
#  current acceleration: -0.3365152517157327
# Params:
#  my speed: 22.992
#  front_vehicle_speed: 23.299
#  current distance: 8.103
#  current acceleration: -0.33474068941686974
# Params:
#  my speed: 22.985
#  front_vehicle_speed: 23.299
#  current distance: 8.109
#  current acceleration: -0.3329735303410253
# Params:
#  my speed: 22.979
#  front_vehicle_speed: 23.299
#  current distance: 8.115
#  current acceleration: -0.3312137453594016
# Params:
#  my speed: 22.972
#  front_vehicle_speed: 23.299
#  current distance: 8.121
#  current acceleration: -0.32946130545535135
# Params:
#  my speed: 22.965
#  front_vehicle_speed: 23.299
#  current distance: 8.128
#  current acceleration: -0.32771618172402095
# Params:
#  my speed: 22.959
#  front_vehicle_speed: 23.299
#  current distance: 8.135
#  current acceleration: -0.325978345372005
# Params:
#  my speed: 22.952
#  front_vehicle_speed: 23.299
#  current distance: 8.141
#  current acceleration: -0.32424776771697583
# Params:
#  my speed: 22.946
#  front_vehicle_speed: 23.299
#  current distance: 8.148
#  current acceleration: -0.32252442018733896
# Params:
#  my speed: 22.939
#  front_vehicle_speed: 23.299
#  current distance: 8.155
#  current acceleration: -0.32080827432186376
# Params:
#  my speed: 22.933
#  front_vehicle_speed: 23.299
#  current distance: 8.163
#  current acceleration: -0.3190993017693383
# Params:
#  my speed: 22.926
#  front_vehicle_speed: 23.299
#  current distance: 8.17
#  current acceleration: -0.3173974742881991
# Params:
#  my speed: 22.92
#  front_vehicle_speed: 23.299
#  current distance: 8.177
#  current acceleration: -0.3157027637461757
# Params:
#  my speed: 22.914
#  front_vehicle_speed: 23.299
#  current distance: 8.185
#  current acceleration: -0.31401514211993387
# Params:
#  my speed: 22.907
#  front_vehicle_speed: 23.299
#  current distance: 8.193
#  current acceleration: -0.3123345814947054
# Params:
#  my speed: 22.901
#  front_vehicle_speed: 23.299
#  current distance: 8.2
#  current acceleration: -0.3106610540639382
# Params:
#  my speed: 22.895
#  front_vehicle_speed: 23.299
#  current distance: 8.208
#  current acceleration: -0.3089945321289289
# Params:
#  my speed: 22.889
#  front_vehicle_speed: 23.299
#  current distance: 8.216
#  current acceleration: -0.3073349880984594
# Params:
#  my speed: 22.882
#  front_vehicle_speed: 23.299
#  current distance: 8.225
#  current acceleration: -0.3056823944884396
# Params:
#  my speed: 22.876
#  front_vehicle_speed: 23.299
#  current distance: 8.233
#  current acceleration: -0.304036723921538
# Params:
#  my speed: 22.87
#  front_vehicle_speed: 23.299
#  current distance: 8.241
#  current acceleration: -0.30239794912682527
# Params:
#  my speed: 22.864
#  front_vehicle_speed: 23.299
#  current distance: 8.25
#  current acceleration: -0.3007660429394099
# Params:
#  my speed: 22.858
#  front_vehicle_speed: 23.299
#  current distance: 8.259
#  current acceleration: -0.29914097830007036
# Params:
#  my speed: 22.852
#  front_vehicle_speed: 23.299
#  current distance: 8.267
#  current acceleration: -0.29752272825489423
# Params:
#  my speed: 22.846
#  front_vehicle_speed: 23.299
#  current distance: 8.276
#  current acceleration: -0.2959112659549168
# Params:
#  my speed: 22.84
#  front_vehicle_speed: 23.299
#  current distance: 8.285
#  current acceleration: -0.2943065646557558
# Params:
#  my speed: 22.834
#  front_vehicle_speed: 23.299
#  current distance: 8.295
#  current acceleration: -0.2927085977172439
# Params:
#  my speed: 22.828
#  front_vehicle_speed: 23.299
#  current distance: 8.304
#  current acceleration: -0.29111733860307243
# Params:
#  my speed: 22.822
#  front_vehicle_speed: 23.299
#  current distance: 8.313
#  current acceleration: -0.289532760880416
# Params:
#  my speed: 22.817
#  front_vehicle_speed: 23.299
#  current distance: 8.323
#  current acceleration: -0.2879548382195807
# Params:
#  my speed: 22.811
#  front_vehicle_speed: 23.299
#  current distance: 8.333
#  current acceleration: -0.2863835443936291
# Params:
#  my speed: 22.805
#  front_vehicle_speed: 23.299
#  current distance: 8.342
#  current acceleration: -0.2848188532780255
# Params:
#  my speed: 22.799
#  front_vehicle_speed: 23.299
#  current distance: 8.352
#  current acceleration: -0.2832607388502695
# Params:
#  my speed: 22.794
#  front_vehicle_speed: 23.299
#  current distance: 8.362
#  current acceleration: -0.281709175189524
# Params:
#  my speed: 22.788
#  front_vehicle_speed: 23.299
#  current distance: 8.372
#  current acceleration: -0.2801641364762669
# Params:
#  my speed: 22.782
#  front_vehicle_speed: 23.299
#  current distance: 8.382
#  current acceleration: -0.27862559699191436
# Params:
#  my speed: 22.777
#  front_vehicle_speed: 23.299
#  current distance: 8.393
#  current acceleration: -0.27709353111846247
# Params:
#  my speed: 22.771
#  front_vehicle_speed: 23.299
#  current distance: 8.403
#  current acceleration: -0.27556791333812447
# Params:
#  my speed: 22.766
#  front_vehicle_speed: 23.299
#  current distance: 8.414
#  current acceleration: -0.27404871823296817
# Params:
#  my speed: 22.76
#  front_vehicle_speed: 23.299
#  current distance: 8.424
#  current acceleration: -0.2725359204845501
# Params:
#  my speed: 22.755
#  front_vehicle_speed: 23.299
#  current distance: 8.435
#  current acceleration: -0.27102949487356365
# Params:
#  my speed: 22.749
#  front_vehicle_speed: 23.299
#  current distance: 8.446
#  current acceleration: -0.2695294162794576
# Params:
#  my speed: 22.744
#  front_vehicle_speed: 23.299
#  current distance: 8.457
#  current acceleration: -0.2680356596800959
# Params:
#  my speed: 22.738
#  front_vehicle_speed: 23.299
#  current distance: 8.468
#  current acceleration: -0.2665482001513825
# Params:
#  my speed: 22.733
#  front_vehicle_speed: 23.299
#  current distance: 8.479
#  current acceleration: -0.26506701286690415
# Params:
#  my speed: 22.728
#  front_vehicle_speed: 23.299
#  current distance: 8.491
#  current acceleration: -0.2635920730975716
# Params:
#  my speed: 22.722
#  front_vehicle_speed: 23.299
#  current distance: 8.502
#  current acceleration: -0.2621233562112629
# Params:
#  my speed: 22.717
#  front_vehicle_speed: 23.299
#  current distance: 8.514
#  current acceleration: -0.26066083767244896
# Params:
#  my speed: 22.712
#  front_vehicle_speed: 23.299
#  current distance: 8.525
#  current acceleration: -0.25920449304185134
# Params:
#  my speed: 22.707
#  front_vehicle_speed: 23.299
#  current distance: 8.537
#  current acceleration: -0.2577542979760755
# Params:
#  my speed: 22.701
#  front_vehicle_speed: 23.299
#  current distance: 8.549
#  current acceleration: -0.256310228227255
# Params:
#  my speed: 22.696
#  front_vehicle_speed: 23.299
#  current distance: 8.561
#  current acceleration: -0.25487225964268945
# Params:
#  my speed: 22.691
#  front_vehicle_speed: 23.299
#  current distance: 8.573
#  current acceleration: -0.253440368164492
# Params:
#  my speed: 22.686
#  front_vehicle_speed: 23.299
#  current distance: 8.585
#  current acceleration: -0.25201452982923145
# Params:
#  my speed: 22.681
#  front_vehicle_speed: 23.299
#  current distance: 8.597
#  current acceleration: -0.2505947207675735
# Params:
#  my speed: 22.676
#  front_vehicle_speed: 23.299
#  current distance: 8.61
#  current acceleration: -0.24918091720393332
# Params:
#  my speed: 22.671
#  front_vehicle_speed: 23.299
#  current distance: 8.622
#  current acceleration: -0.24777309545610915
# Params:
#  my speed: 22.666
#  front_vehicle_speed: 23.299
#  current distance: 8.635
#  current acceleration: -0.24637123193493538
# Params:
#  my speed: 22.661
#  front_vehicle_speed: 23.299
#  current distance: 8.647
#  current acceleration: -0.24497530314392668
# Params:
#  my speed: 22.656
#  front_vehicle_speed: 23.299
#  current distance: 8.66
#  current acceleration: -0.24358528567892723
# Params:
#  my speed: 22.651
#  front_vehicle_speed: 23.299
#  current distance: 8.673
#  current acceleration: -0.24220115622775595
# Params:
#  my speed: 22.646
# ...
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.417
#  current acceleration: 0.0004159276430004688
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.417
#  current acceleration: 0.0004155273227912648
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.418
#  current acceleration: 0.0004151273887875728
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.418
#  current acceleration: 0.0004147278406141375
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.418
#  current acceleration: 0.0004143286778968136
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.418
#  current acceleration: 0.00041392990026145604
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.418
#  current acceleration: 0.00041353150734058097
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.418
#  current acceleration: 0.0004131334987533819
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.419
#  current acceleration: 0.00041273587413459545
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.419
#  current acceleration: 0.00041233863310896623
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.419
#  current acceleration: 0.00041194177530456955
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.419
#  current acceleration: 0.00041154530034615
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.419
#  current acceleration: 0.0004111492078662238
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.419
#  current acceleration: 0.00041075349749175594
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.42
#  current acceleration: 0.0004103581688574831
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.42
#  current acceleration: 0.000409963221593701
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.42
#  current acceleration: 0.0004095686553240441
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.42
#  current acceleration: 0.0004091744696843591
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.42
#  current acceleration: 0.0004087806643060521
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.42
#  current acceleration: 0.0004083872388171983
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.421
#  current acceleration: 0.0004079941928536446
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.421
#  current acceleration: 0.000407601526042356
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.421
#  current acceleration: 0.0004072092380191794
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.421
#  current acceleration: 0.00040681732841885143
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.421
#  current acceleration: 0.00040642579687388825
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.421
#  current acceleration: 0.00040603464301680603
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.422
#  current acceleration: 0.0004056438664779005
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.422
#  current acceleration: 0.0004052534668941288
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.422
#  current acceleration: 0.0004048634439068888
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.422
#  current acceleration: 0.0004044737971398149
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.422
#  current acceleration: 0.000404084526238746
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.423
#  current acceleration: 0.0004036956308306472
# Params:
#  my speed: 23.29
#  front_vehicle_speed: 23.299
#  current distance: 46.423
#  current acceleration: 0.0004033071105580266
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aless\OneDrive\Desktop\Thesis_repo_new\HighwayDRL\action_testing_notebooks\acc_action_testing.ipynb Cell 2' in <cell line: 12>()
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/acc_action_testing.ipynb#ch0000001?line=10'>11</a> done = False
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/acc_action_testing.ipynb#ch0000001?line=11'>12</a> while not done:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/acc_action_testing.ipynb#ch0000001?line=12'>13</a>     env.step(env.action_space.sample())
#      <a href='vscode-notebook-cell:/c%3A/Users/aless/OneDrive/Desktop/Thesis_repo_new/HighwayDRL/action_testing_notebooks/acc_action_testing.ipynb#ch0000001?line=13'>14</a>     env.render()
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:215, in AbstractEnv.step(self, action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=211'>212</a>     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=213'>214</a> self.steps += 1
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=214'>215</a> self._simulate(action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=216'>217</a> obs = self.observation_type.observe()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=217'>218</a> reward = self._reward(action)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:241, in AbstractEnv._simulate(self, action)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=237'>238</a>     # Automatically render intermediate simulation steps if a viewer has been launched
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=238'>239</a>     # Ignored if the rendering is done offscreen
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=239'>240</a>     if frame < frames - 1:  # Last frame will be rendered through env.render() as usual
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=240'>241</a>         self._automatic_rendering()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=242'>243</a> self.enable_auto_render = False
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:321, in AbstractEnv._automatic_rendering(self)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=318'>319</a>     self._monitor.video_recorder.capture_frame()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=319'>320</a> else:
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=320'>321</a>     self.render(self.rendering_mode)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\abstract.py:259, in AbstractEnv.render(self, mode)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=254'>255</a>     self.viewer = EnvViewer(self)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=256'>257</a> self.enable_auto_render = True
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=258'>259</a> self.viewer.display()
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=260'>261</a> if not self.viewer.offscreen:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/abstract.py?line=261'>262</a>     self.viewer.handle_events()
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\envs\common\graphics.py:121, in EnvViewer.display(self)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=117'>118</a>         else:
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=118'>119</a>             self.screen.blit(self.agent_surface, (self.config["screen_width"], 0))
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=120'>121</a> RoadGraphics.display_traffic(
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=121'>122</a>     self.env.road,
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=122'>123</a>     self.sim_surface,
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=123'>124</a>     simulation_frequency=self.env.config["simulation_frequency"],
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=124'>125</a>     offscreen=self.offscreen)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=126'>127</a> ObservationGraphics.display(self.env.observation_type, self.sim_surface)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/envs/common/graphics.py?line=128'>129</a> if not self.offscreen:
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\road\graphics.py:258, in RoadGraphics.display_traffic(road, surface, simulation_frequency, offscreen)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=255'>256</a>         VehicleGraphics.display_history(v, surface, simulation=simulation_frequency, offscreen=offscreen)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=256'>257</a> for v in road.vehicles:
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/road/graphics.py?line=257'>258</a>     VehicleGraphics.display(v, surface, offscreen=offscreen)
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\vehicle\graphics.py:100, in VehicleGraphics.display(cls, vehicle, surface, transparent, offscreen, label, draw_roof)
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=95'>96</a> if not offscreen:
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=96'>97</a>     # convert_alpha throws errors in offscreen mode
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=97'>98</a>     # see https://stackoverflow.com/a/19057853
#      <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=98'>99</a>     vehicle_surface = pygame.Surface.convert_alpha(vehicle_surface)
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=99'>100</a> cls.blit_rotate(surface, vehicle_surface, position, np.rad2deg(-h))
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=101'>102</a> # Label
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=102'>103</a> if label:
#
# File c:\users\aless\onedrive\desktop\thesis_repo_new\highwaydrl\highway_env\vehicle\graphics.py:130, in VehicleGraphics.blit_rotate(surf, image, pos, angle, origin_pos, show_rect)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=127'>128</a> origin = (pos[0] - origin_pos[0] + min_box[0] - pivot_move[0], pos[1] - origin_pos[1] - max_box[1] + pivot_move[1])
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=128'>129</a> # get a rotated image
# --> <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=129'>130</a> rotated_image = pygame.transform.rotate(image, angle)
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=130'>131</a> # rotate and blit the image
#     <a href='file:///c%3A/users/aless/onedrive/desktop/thesis_repo_new/highwaydrl/highway_env/vehicle/graphics.py?line=131'>132</a> surf.blit(rotated_image, origin)
#
# KeyboardInterrupt:
